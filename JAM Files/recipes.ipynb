# %%
import json, requests
from pprint import pprint
import pandas as pd
#from config import api_key
import numpy as np
import random
api_key = "98a9fecd7a39494a9b003ddd357ba362"

# %%
recipe_base = f"https://api.spoonacular.com/recipes/"
recipe_url_tail = "/information?includeNutrition=true"
# recipe_url_base =f"https://api.spoonacular.com/recipes/information?includeNutrition=true/"
recipe_id = "66135"
recipe_query = f"{recipe_base}{recipe_id}{recipe_url_tail}&apiKey={api_key}"
print(recipe_query)
# Out:
# https://api.spoonacular.com/recipes/66135/information?includeNutrition=true&apiKey=98a9fecd7a39494a9b003ddd357ba362

# %%
s = requests.Session()
response = s.get(recipe_query).json()
# ## pretty print the response 
#pprint(response)
# # response

# %%
nutrient = response['nutrition']['nutrients']

# %%
# ingredients = list(range(len(response['nutrition']['ingredients'])))
# ingredients

# for i in ingredients:
#     names = response['nutrition']['ingredients'][i]['name']
#     print(names)

# Extract desired data from the stored json response 
# summary = response['summary']
# title = response['title']
# prepTime = response['readyInMinutes']
# image = response['image']
# pairedWine = response['winePairing']['pairedWines']
# pairingDesc = response['winePairing']['pairingText']
# id_number = response['id']
# serving = response['servings']
# likes = response['aggregateLikes']
# sourceurl = response['sourceUrl']
# nutrition = response['nutrition']['caloricBreakdown']
# nutrition

# food_names = response['nutrition']['ingredients'][i for i in ingredients]['name']

# %%
# url_base = f"https://api.spoonacular.com/recipes/"
# url_tail = "/information?includeNutrition=true"
# key = f"&apiKey={api_key}"

# for num in random_num:
#     params = f'{num}'

#     response = s.get(url_base + params + url_tail + key).json()

# %%
# # create empty dataframe to collect dish pairings from list of wines 
# columns = ['Recipe_ID']
# recipe_df = pd.DataFrame(columns=columns)
# recipe_df
# dish_pairing_df['wine'] = wine_selections
# dish_pairing_df

# %%
# # build a list of random ID numbers to test API call
# recipe_num = [random.randrange(1,200000,1) for i in range(5)]
# recipe_num

# %%
# create a function for the lists, divide by 150, set in a try/catch statement

# %%
# recipe_df['Recipe_ID'] = recipe_num
# recipe_df

# %%
# recipe_df['Spoon_ID'] = ''
# recipe_df['Title'] = ''
# recipe_df['PrepTime'] = ''
# recipe_df['Summary'] = ''
# recipe_df['CaloricBreakdown'] = ''
# recipe_df['Servings'] = ''
# recipe_df['Likes'] = ''
# recipe_df['SourceURL'] = ''
# recipe_df['ImageURL'] = ''
# recipe_df['WinePairing'] = ''
# recipe_df['WineDescription'] = ''
# recipe_df

# %%
url_base = f"https://api.spoonacular.com/recipes/"
url_tail = "/information?includeNutrition=true"
key = f"&apiKey={api_key}"

# recipe_query = f"{url_base}{meal_id}{recipe_url_tail}&apiKey={key}"

s = requests.Session()
# response = s.get(recipe_query).json()
# response

# %%
# columns = ["Spoon_ID","Title","PrepTime","Summary","CaloricBreakdown","Servings","Likes","SourceURL","ImageURL","WinePairing","WineDescription"]
# nutrition = []
# recipe_df = pd.DataFrame(columns=columns)

# recipe_df["Recipe_ID"]=recipe_num

# for index, row in recipe_df.iterrows():
#     meal_id = row['Recipe_ID']
#     params = f'{meal_id}'

#     response = s.get(url_base + params + url_tail + key).json()  
#     if response.status_code=200:
#         recipe_data=response.json()
    
#     try:
#         recipe_df.at[index,"Spoon_ID"] = response['id'] 
#         recipe_df.at[index,"Title"] = response['title']
#         recipe_df.at[index,"PrepTime"] = response['readyInMinutes']
#         recipe_df.at[index,"Summary"] = response['summary']
#         recipe_df.at[index,"CaloricBreakdown"] = response['nutrition']['caloricBreakdown']
#         recipe_df.at[index,"Servings"] = response['servings']
#         recipe_df.at[index,"Likes"] = response['aggregateLikes']
#         recipe_df.at[index,"SourceURL"] = response['sourceURL']
#         recipe_df.at[index,"ImageURL"] = response['image']
#         recipe_df.at[index,"WinePairing"] = response['winePairing']['pairedWines']
#         recipe_df.at[index,"WineDescription"] = response['winePairing']['pairingText']
#         nutrition.append(response['nutrition']['caloricBreakdown'])

#     except (KeyError, IndexError, ValueError):
#         recipe_df.at[index,"Spoon_ID"] = "ID does not exist"
#         recipe_df.at[index,"Title"] = "no title available"
#         recipe_df.at[index,"PrepTime"] = "no prep time available"
#         recipe_df.at[index,"Summary"] = "no summary avaialble"
#         recipe_df.at[index,"CaloricBreakdown"] = "no calorie information available"
#         recipe_df.at[index,"Servings"] = "no servings available"
#         recipe_df.at[index,"Likes"] = "noone likes this dish"
#         recipe_df.at[index,"SourceURL"] = "no source URL available"
#         recipe_df.at[index,"ImageURL"] = "no image URL available"
#         recipe_df.at[index,"WinePairing"] = "no wine pairing available"
#         recipe_df.at[index,"WineDescription"] = "no wine description available"

# %%
# recipe_df['CaloricBreakdown'] = nutrition
# recipe_df

# %%
# build a list of random ID numbers to fetch a variety of recipes from API call 
# this was done because consecutive ID numbers retrieves recipes of the same main ingredient
recipe_num= [random.randrange(1,200000,1) for i in range(6000)]
recipe_num
print(len(recipe_num))
res = []
[res.append(x) for x in recipe_num if x not in res]
print(len(res))
# Out:
# 6000
# 5913

# %%
## create a function that divides the recipe id list 'res' into sets of 150 for API calls
## This function was not successful
# def divide_my_list(recipe_id_list):
#     api_id_list = np.array_split(recipe_id_list, 40)
    
#     for id_list in api_id_list:
#         print(list(id_list))

# %%
# create a function that divides the recipe id list 'res' into sets of 150 for API calls
def divide_list(l, n): 
    
    # looping till length l 
    for i in range(0, len(l), n):  
        yield l[i:i + n] 

n = 150  
x = list(divide_list(res, n)) 
recipe_list_1 = x[0]
len(recipe_list_1)
# Out:
# 150

# %%
data = []

import numpy as np
import time
# Recipe Dataframe Components
rec_data_comps = ['id', 'title', 'readyInMinutes', 'nutrition>caloricBreakdown>percentProtein', 'nutrition>caloricBreakdown>percentFat','nutrition>caloricBreakdown>percentCarbs','nutrition'>'nutrients','servings','image','sourceUrl','summary',
                  'aggregateLikes','spoonacularScore','winePairing>pairedWines', 'winePairing>pairingText']
def rec_comp_check(comp, recipe_data):
    try:
        comp_path = comp.split(">")
        for c in comp_path:
            recipe_data = recipe_data[c]
        datum = recipe_data
    except:
        datum = np.nan
    return datum
for num in recipe_list_1: # may need to fix what you iterate over

    params = f'{num}'
    response = s.get(url_base + params + url_tail + key)
    if response.status_code == 200:
        recipe_data = response.json()
        my_big_dict ={"My ID": num}
        for comp in rec_data_comps:
            my_big_dict[comp] = rec_comp_check(comp, recipe_data)
        data.append(my_big_dict)
    else:
        print(f'{num} failed to return a good API response')
        print(response)
pd.DataFrame(data)
# Out:
# 156268 failed to return a good API response
# <Response [404]>
# 126015 failed to return a good API response
# <Response [404]>
# 99264 failed to return a good API response
# <Response [404]>
# 151335 failed to return a good API response
# <Response [404]>
# 97409 failed to return a good API response
# <Response [404]>
# 19932 failed to return a good API response
# <Response [404]>
# 19358 failed to return a good API response
# <Response [404]>
# 70425 failed to return a good API response
# <Response [404]>
# 109339 failed to return a good API response
# <Response [404]>
# 61612 failed to return a good API response
# <Response [404]>
# 45862 failed to return a good API response
# <Response [404]>
# 75805 failed to return a good API response
# <Response [404]>
# 150043 failed to return a good API response
# <Response [404]>
# 151301 failed to return a good API response
# <Response [404]>
# 123935 failed to return a good API response
# <Response [404]>
# 34955 failed to return a good API response
# <Response [404]>
# 157688 failed to return a good API response
# <Response [404]>
# 153640 failed to return a good API response
# <Response [404]>
# 127570 failed to return a good API response
# <Response [404]>
# 44979 failed to return a good API response
# <Response [404]>
# 179725 failed to return a good API response
# <Response [404]>
# 151373 failed to return a good API response
# <Response [404]>
# 151053 failed to return a good API response
# <Response [404]>
# 57328 failed to return a good API response
# <Response [404]>
# 151165 failed to return a good API response
# <Response [404]>
# 151026 failed to return a good API response
# <Response [404]>
# 151461 failed to return a good API response
# <Response [404]>
# 135480 failed to return a good API response
# <Response [404]>
# 110972 failed to return a good API response
# <Response [404]>
#       My ID      id                                              title  \
# 0    178499  178499                        Impossibly Easy Pumpkin Pie
# 1     94049   94049           Kentucky Fried Chicken Original Coleslaw
# 2    184884  184884                                  Tangy Steak Salad
# 3     64115   64115                  Carrot Cupcakes with Orange Icing
# 4    163779  163779  Patricia Wells's Crunchy Asparagus and Snow Pe...
# ..      ...     ...                                                ...
# 116  110299  110299           Roast Beef Dinner Enchiladas (Lite-Bleu)
# 117   76772   76772  Pasta with Mussels and Beans: Penne con Cozze ...
# 118  191009  191009                                   Strawberry Lassi
# 119   55730   55730                Giblet Gravy With Fresh Cranberries
# 120   75496   75496                            Grilled Turkey Meatloaf
#
#      readyInMinutes  nutrition>caloricBreakdown>percentProtein  \
# 0               260                                      11.63
# 1               260                                       2.89
# 2                17                                      52.95
# 3              1500                                       4.50
# 4                45                                      20.21
# ..              ...                                        ...
# 116              30                                      31.80
# 117             840                                      26.18
# 118              10                                      13.06
# 119              45                                       9.81
# 120              45                                      38.85
#
#      nutrition>caloricBreakdown>percentFat  \
# 0                                    33.39
# 1                                    63.85
# 2                                    36.17
# 3                                    38.17
# 4                                    68.12
# ..                                     ...
# 116                                  32.99
# 117                                  29.92
# 118                                   9.21
# 119                                   9.36
# 120                                  52.51
#
#      nutrition>caloricBreakdown>percentCarbs  True  servings  \
# 0                                      54.98   NaN         6
# 1                                      33.26   NaN         6
# 2                                      10.88   NaN         4
# 3                                      57.33   NaN        12
# 4                                      11.67   NaN         4
# ..                                       ...   ...       ...
# 116                                    35.21   NaN         4
# 117                                    43.90   NaN         8
# 118                                    77.73   NaN         5
# 119                                    80.83   NaN         8
# 120                                     8.64   NaN         8
#
#                                                  image  \
# 0    https://spoonacular.com/recipeImages/178499-55...
# 1    https://spoonacular.com/recipeImages/94049-556...
# 2    https://spoonacular.com/recipeImages/184884-55...
# 3    https://spoonacular.com/recipeImages/64115-556...
# 4    https://spoonacular.com/recipeImages/163779-55...
# ..                                                 ...
# 116  https://spoonacular.com/recipeImages/110299-55...
# 117  https://spoonacular.com/recipeImages/76772-556...
# 118  https://spoonacular.com/recipeImages/191009-55...
# 119  https://spoonacular.com/recipeImages/55730-556...
# 120  https://spoonacular.com/recipeImages/75496-556...
#
#                                              sourceUrl  \
# 0    https://www.bettycrocker.com/recipes/impossibl...
# 1    http://www.food.com/recipe/kentucky-fried-chic...
# 2    https://www.bettycrocker.com/recipes/tangy-ste...
# 3    http://www.epicurious.com/recipes/food/views/C...
# 4    http://www.chow.com/recipes/29756-patricia-wel...
# ..                                                 ...
# 116  http://www.food.com/recipe/roast-beef-dinner-e...
# 117  http://www.foodnetwork.com/recipes/mario-batal...
# 118  http://www.epicurious.com:80/recipes/food/view...
# 119  http://www.food52.com/recipes/7457_giblet_grav...
# 120  http://www.familyfreshcooking.com/2009/07/29/g...
#
#                                                summary  aggregateLikes  \
# 0    Impossibly Easy Pumpkin Pie is a <b>gluten fre...             925
# 1    Kentucky Fried Chicken Original Coleslaw might...              29
# 2    Tangy Steak Salad might be just the main cours...              24
# 3    The recipe Carrot Cupcakes with Orange Icing i...               0
# 4    Patricia Wells's Crunchy Asparagus and Snow Pe...               0
# ..                                                 ...             ...
# 116  The recipe Roast Beef Dinner Enchiladas (Lite-...               0
# 117  Need a <b>dairy free and pescatarian main cour...               0
# 118  Strawberry Lassi might be just the beverage yo...               0
# 119  You can never have too many sauce recipes, so ...               0
# 120  You can never have too many main course recipe...               1
#
#      spoonacularScore                   winePairing>pairedWines  \
# 0                46.0                                       NaN
# 1                31.0     [riesling, sparkling wine, zinfandel]
# 2                95.0  [merlot, cabernet sauvignon, pinot noir]
# 3                31.0                                        []
# 4                68.0                                       NaN
# ..                ...                                       ...
# 116              83.0    [riesling, sparkling rose, pinot noir]
# 117              87.0                                        []
# 118              54.0  [riesling, gewurztraminer, chenin blanc]
# 119              55.0                                       NaN
# 120              48.0                                       NaN
#
#                                winePairing>pairingText
# 0                                                  NaN
# 1    Southern works really well with Riesling, Spar...
# 2    Steak works really well with Merlot, Cabernet ...
# 3
# 4                                                  NaN
# ..                                                 ...
# 116  Riesling, Sparkling rosé, and Pinot Noir are m...
# 117  No one wine will suit every pasta dish. Pasta ...
# 118  Asian works really well with Riesling, Gewurzt...
# 119                                                NaN
# 120                                                NaN
#
# [121 rows x 16 columns]

# %%
dataFrame_1 = pd.DataFrame(data)
dataFrame_1
# Out:
#       My ID      id                                              title  \
# 0    178499  178499                        Impossibly Easy Pumpkin Pie
# 1     94049   94049           Kentucky Fried Chicken Original Coleslaw
# 2    184884  184884                                  Tangy Steak Salad
# 3     64115   64115                  Carrot Cupcakes with Orange Icing
# 4    163779  163779  Patricia Wells's Crunchy Asparagus and Snow Pe...
# ..      ...     ...                                                ...
# 116  110299  110299           Roast Beef Dinner Enchiladas (Lite-Bleu)
# 117   76772   76772  Pasta with Mussels and Beans: Penne con Cozze ...
# 118  191009  191009                                   Strawberry Lassi
# 119   55730   55730                Giblet Gravy With Fresh Cranberries
# 120   75496   75496                            Grilled Turkey Meatloaf
#
#      readyInMinutes  nutrition>caloricBreakdown>percentProtein  \
# 0               260                                      11.63
# 1               260                                       2.89
# 2                17                                      52.95
# 3              1500                                       4.50
# 4                45                                      20.21
# ..              ...                                        ...
# 116              30                                      31.80
# 117             840                                      26.18
# 118              10                                      13.06
# 119              45                                       9.81
# 120              45                                      38.85
#
#      nutrition>caloricBreakdown>percentFat  \
# 0                                    33.39
# 1                                    63.85
# 2                                    36.17
# 3                                    38.17
# 4                                    68.12
# ..                                     ...
# 116                                  32.99
# 117                                  29.92
# 118                                   9.21
# 119                                   9.36
# 120                                  52.51
#
#      nutrition>caloricBreakdown>percentCarbs  True  servings  \
# 0                                      54.98   NaN         6
# 1                                      33.26   NaN         6
# 2                                      10.88   NaN         4
# 3                                      57.33   NaN        12
# 4                                      11.67   NaN         4
# ..                                       ...   ...       ...
# 116                                    35.21   NaN         4
# 117                                    43.90   NaN         8
# 118                                    77.73   NaN         5
# 119                                    80.83   NaN         8
# 120                                     8.64   NaN         8
#
#                                                  image  \
# 0    https://spoonacular.com/recipeImages/178499-55...
# 1    https://spoonacular.com/recipeImages/94049-556...
# 2    https://spoonacular.com/recipeImages/184884-55...
# 3    https://spoonacular.com/recipeImages/64115-556...
# 4    https://spoonacular.com/recipeImages/163779-55...
# ..                                                 ...
# 116  https://spoonacular.com/recipeImages/110299-55...
# 117  https://spoonacular.com/recipeImages/76772-556...
# 118  https://spoonacular.com/recipeImages/191009-55...
# 119  https://spoonacular.com/recipeImages/55730-556...
# 120  https://spoonacular.com/recipeImages/75496-556...
#
#                                              sourceUrl  \
# 0    https://www.bettycrocker.com/recipes/impossibl...
# 1    http://www.food.com/recipe/kentucky-fried-chic...
# 2    https://www.bettycrocker.com/recipes/tangy-ste...
# 3    http://www.epicurious.com/recipes/food/views/C...
# 4    http://www.chow.com/recipes/29756-patricia-wel...
# ..                                                 ...
# 116  http://www.food.com/recipe/roast-beef-dinner-e...
# 117  http://www.foodnetwork.com/recipes/mario-batal...
# 118  http://www.epicurious.com:80/recipes/food/view...
# 119  http://www.food52.com/recipes/7457_giblet_grav...
# 120  http://www.familyfreshcooking.com/2009/07/29/g...
#
#                                                summary  aggregateLikes  \
# 0    Impossibly Easy Pumpkin Pie is a <b>gluten fre...             925
# 1    Kentucky Fried Chicken Original Coleslaw might...              29
# 2    Tangy Steak Salad might be just the main cours...              24
# 3    The recipe Carrot Cupcakes with Orange Icing i...               0
# 4    Patricia Wells's Crunchy Asparagus and Snow Pe...               0
# ..                                                 ...             ...
# 116  The recipe Roast Beef Dinner Enchiladas (Lite-...               0
# 117  Need a <b>dairy free and pescatarian main cour...               0
# 118  Strawberry Lassi might be just the beverage yo...               0
# 119  You can never have too many sauce recipes, so ...               0
# 120  You can never have too many main course recipe...               1
#
#      spoonacularScore                   winePairing>pairedWines  \
# 0                46.0                                       NaN
# 1                31.0     [riesling, sparkling wine, zinfandel]
# 2                95.0  [merlot, cabernet sauvignon, pinot noir]
# 3                31.0                                        []
# 4                68.0                                       NaN
# ..                ...                                       ...
# 116              83.0    [riesling, sparkling rose, pinot noir]
# 117              87.0                                        []
# 118              54.0  [riesling, gewurztraminer, chenin blanc]
# 119              55.0                                       NaN
# 120              48.0                                       NaN
#
#                                winePairing>pairingText
# 0                                                  NaN
# 1    Southern works really well with Riesling, Spar...
# 2    Steak works really well with Merlot, Cabernet ...
# 3
# 4                                                  NaN
# ..                                                 ...
# 116  Riesling, Sparkling rosé, and Pinot Noir are m...
# 117  No one wine will suit every pasta dish. Pasta ...
# 118  Asian works really well with Riesling, Gewurzt...
# 119                                                NaN
# 120                                                NaN
#
# [121 rows x 16 columns]

# %%
dataFrame_1.to_csv(r'Recipes_1.csv',index=False)

# %%
import pymongo

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define the 'classDB' database in Mongo
db = client.local

# %%
recipes = db.Recipe

# %%
print(recipes)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'local'), 'Recipe')

# %%
from flask import Flask
from flask_pymongo import PyMongo

app = Flask(__name__)
app.config["MONGO_URI"] = "mongodb://localhost:27017/local"
mongo = PyMongo(app)

# %%
@app.route("/")
def home_page():
    online_users = mongo.db.users.find({"online": True})
    return render_template("index.html",
        online_users=online_users)
