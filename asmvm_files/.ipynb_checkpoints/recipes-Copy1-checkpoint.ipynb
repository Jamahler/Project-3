# %%
import json, requests
from pprint import pprint
import pandas as pd
from config import api_key
import numpy as np
import random

# %%
recipe_base = f"https://api.spoonacular.com/recipes/"
recipe_url_tail = "/information?includeNutrition=true"
# recipe_url_base =f"https://api.spoonacular.com/recipes/information?includeNutrition=true/"
recipe_id = "66135"
recipe_query = f"{recipe_base}{recipe_id}{recipe_url_tail}&apiKey={api_key}"
print(recipe_query)
# Out:
# https://api.spoonacular.com/recipes/66135/information?includeNutrition=true&apiKey=655b2ca78d0b4f769402f9bd14d4064a

# %%
s = requests.Session()
response = s.get(recipe_query).json()
## pretty print the response 
pprint(response)
# response
# Out:
# {'aggregateLikes': 0,
#  'analyzedInstructions': [],
#  'cheap': False,
#  'creditsText': None,
#  'cuisines': [],
#  'dairyFree': False,
#  'diets': ['gluten free', 'lacto ovo vegetarian'],
#  'dishTypes': ['lunch', 'main course', 'main dish', 'dinner'],
#  'extendedIngredients': [{'aisle': 'Baking',
#                           'amount': 1.0,
#                           'consistency': 'solid',
#                           'id': 18371,
#                           'image': 'white-powder.jpg',
#                           'measures': {'metric': {'amount': 1.0,
#                                                   'unitLong': 'teaspoon',
#                                                   'unitShort': 'tsp'},
#                                        'us': {'amount': 1.0,
#                                               'unitLong': 'teaspoon',
#                                               'unitShort': 'tsp'}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'aluminum free baking powder',
#                           'original': '1 tsp. aluminum-free baking powder',
#                           'originalName': 'aluminum-free baking powder',
#                           'originalString': '1 tsp. aluminum-free baking '
#                                             'powder',
#                           'unit': 'tsp'},
#                          {'aisle': 'Canned and Jarred',
#                           'amount': 2.0,
#                           'consistency': 'solid',
#                           'id': 9019,
#                           'image': 'applesauce.png',
#                           'measures': {'metric': {'amount': 2.0,
#                                                   'unitLong': 'Tbsps',
#                                                   'unitShort': 'Tbsps'},
#                                        'us': {'amount': 2.0,
#                                               'unitLong': 'Tbsps',
#                                               'unitShort': 'Tbsps'}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'applesauce',
#                           'original': '2 Tbsp. applesauce (replaced 2 Tbsp. '
#                                       'butter)',
#                           'originalName': 'applesauce (replaced 2 Tbsp. '
#                                           'butter)',
#                           'originalString': '2 Tbsp. applesauce (replaced 2 '
#                                             'Tbsp. butter)',
#                           'unit': 'Tbsp'},
#                          {'aisle': 'Baking',
#                           'amount': 0.5,
#                           'consistency': 'solid',
#                           'id': 18372,
#                           'image': 'white-powder.jpg',
#                           'measures': {'metric': {'amount': 0.5,
#                                                   'unitLong': 'teaspoons',
#                                                   'unitShort': 'tsps'},
#                                        'us': {'amount': 0.5,
#                                               'unitLong': 'teaspoons',
#                                               'unitShort': 'tsps'}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'baking soda',
#                           'original': '½ tsp. baking soda',
#                           'originalName': 'baking soda',
#                           'originalString': '½ tsp. baking soda',
#                           'unit': 'tsp'},
#                          {'aisle': 'Baking',
#                           'amount': 0.5,
#                           'consistency': 'solid',
#                           'id': 19335,
#                           'image': 'sugar-in-bowl.png',
#                           'measures': {'metric': {'amount': 118.294,
#                                                   'unitLong': 'milliliters',
#                                                   'unitShort': 'ml'},
#                                        'us': {'amount': 0.5,
#                                               'unitLong': 'cups',
#                                               'unitShort': 'cups'}},
#                           'meta': ['raw',
#                                    'white',
#                                    'organic',
#                                    '(replaced 1 cup sugar)'],
#                           'metaInformation': ['raw',
#                                               'white',
#                                               'organic',
#                                               '(replaced 1 cup sugar)'],
#                           'name': 'cane sugar',
#                           'original': '½ cup organic raw cane sugar or Sucanat '
#                                       '(replaced 1 cup white sugar)',
#                           'originalName': 'organic raw cane sugar or Sucanat '
#                                           '(replaced 1 cup white sugar)',
#                           'originalString': '½ cup organic raw cane sugar or '
#                                             'Sucanat (replaced 1 cup white '
#                                             'sugar)',
#                           'unit': 'cup'},
#                          {'aisle': 'Milk, Eggs, Other Dairy',
#                           'amount': 2.0,
#                           'consistency': 'solid',
#                           'id': 1124,
#                           'image': 'egg-white.jpg',
#                           'measures': {'metric': {'amount': 2.0,
#                                                   'unitLong': '',
#                                                   'unitShort': ''},
#                                        'us': {'amount': 2.0,
#                                               'unitLong': '',
#                                               'unitShort': ''}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'egg whites',
#                           'original': '2 egg whites',
#                           'originalName': 'egg whites',
#                           'originalString': '2 egg whites',
#                           'unit': ''},
#                          {'aisle': 'Health Foods;Baking',
#                           'amount': 1.0,
#                           'consistency': 'solid',
#                           'id': 12220,
#                           'image': 'flax-seeds.png',
#                           'measures': {'metric': {'amount': 1.0,
#                                                   'unitLong': 'Tbsp',
#                                                   'unitShort': 'Tbsp'},
#                                        'us': {'amount': 1.0,
#                                               'unitLong': 'Tbsp',
#                                               'unitShort': 'Tbsp'}},
#                           'meta': ['mixed',
#                                    'with 3 tbsp. water (replaced 1 large egg)'],
#                           'metaInformation': ['mixed',
#                                               'with 3 tbsp. water (replaced 1 '
#                                               'large egg)'],
#                           'name': 'ground flax seed',
#                           'original': '1 Tbsp. ground flax seed mixed with 3 '
#                                       'Tbsp. water (replaced 1 large egg)',
#                           'originalName': 'ground flax seed mixed with 3 Tbsp. '
#                                           'water (replaced 1 large egg)',
#                           'originalString': '1 Tbsp. ground flax seed mixed '
#                                             'with 3 Tbsp. water (replaced 1 '
#                                             'large egg)',
#                           'unit': 'Tbsp'},
#                          {'aisle': 'Produce',
#                           'amount': 2.0,
#                           'consistency': 'liquid',
#                           'id': 9152,
#                           'image': 'lemon-juice.jpg',
#                           'measures': {'metric': {'amount': 2.0,
#                                                   'unitLong': 'Tbsps',
#                                                   'unitShort': 'Tbsps'},
#                                        'us': {'amount': 2.0,
#                                               'unitLong': 'Tbsps',
#                                               'unitShort': 'Tbsps'}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'lemon juice',
#                           'original': '2 Tbsp. lemon juice',
#                           'originalName': 'lemon juice',
#                           'originalString': '2 Tbsp. lemon juice',
#                           'unit': 'Tbsp'},
#                          {'aisle': 'Produce',
#                           'amount': 1.0,
#                           'consistency': 'solid',
#                           'id': 9156,
#                           'image': 'zest-lemon.jpg',
#                           'measures': {'metric': {'amount': 1.0,
#                                                   'unitLong': '',
#                                                   'unitShort': ''},
#                                        'us': {'amount': 1.0,
#                                               'unitLong': '',
#                                               'unitShort': ''}},
#                           'meta': ['organic', 'finely grated'],
#                           'metaInformation': ['organic', 'finely grated'],
#                           'name': 'lemon zest',
#                           'original': 'Finely grated zest of 1 organic lemon',
#                           'originalName': 'Finely grated zest of organic lemon',
#                           'originalString': 'Finely grated zest of 1 organic '
#                                             'lemon',
#                           'unit': ''},
#                          {'aisle': 'Cereal',
#                           'amount': 2.0,
#                           'consistency': 'liquid',
#                           'id': 19911,
#                           'image': 'maple-syrup.png',
#                           'measures': {'metric': {'amount': 2.0,
#                                                   'unitLong': 'Tbsps',
#                                                   'unitShort': 'Tbsps'},
#                                        'us': {'amount': 2.0,
#                                               'unitLong': 'Tbsps',
#                                               'unitShort': 'Tbsps'}},
#                           'meta': ['pure'],
#                           'metaInformation': ['pure'],
#                           'name': 'maple syrup',
#                           'original': '2 Tbsp. pure maple syrup',
#                           'originalName': 'pure maple syrup',
#                           'originalString': '2 Tbsp. pure maple syrup',
#                           'unit': 'Tbsp'},
#                          {'aisle': 'Produce',
#                           'amount': 1.5,
#                           'consistency': 'solid',
#                           'id': 9302,
#                           'image': 'raspberries.jpg',
#                           'measures': {'metric': {'amount': 354.882,
#                                                   'unitLong': 'milliliters',
#                                                   'unitShort': 'ml'},
#                                        'us': {'amount': 1.5,
#                                               'unitLong': 'cups',
#                                               'unitShort': 'cups'}},
#                           'meta': ['frozen', '(increased fruit by)'],
#                           'metaInformation': ['frozen', '(increased fruit by)'],
#                           'name': 'raspberries',
#                           'original': '1 ½ cups raspberries frozen; keep '
#                                       'frozen until ready to use (increased '
#                                       'fruit by ½ cup)',
#                           'originalName': 'raspberries frozen; keep frozen '
#                                           'until ready to use (increased fruit '
#                                           'by ½ cup)',
#                           'originalString': '1 ½ cups raspberries frozen; keep '
#                                             'frozen until ready to use '
#                                             '(increased fruit by ½ cup)',
#                           'unit': 'cups'},
#                          {'aisle': 'Spices and Seasonings',
#                           'amount': 0.5,
#                           'consistency': 'solid',
#                           'id': 2047,
#                           'image': 'salt.jpg',
#                           'measures': {'metric': {'amount': 0.5,
#                                                   'unitLong': 'teaspoons',
#                                                   'unitShort': 'tsps'},
#                                        'us': {'amount': 0.5,
#                                               'unitLong': 'teaspoons',
#                                               'unitShort': 'tsps'}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'salt',
#                           'original': '½ tsp. salt',
#                           'originalName': 'salt',
#                           'originalString': '½ tsp. salt',
#                           'unit': 'tsp'},
#                          {'aisle': 'Milk, Eggs, Other Dairy',
#                           'amount': 3.0,
#                           'consistency': 'solid',
#                           'id': 1145,
#                           'image': 'butter-sliced.jpg',
#                           'measures': {'metric': {'amount': 3.0,
#                                                   'unitLong': 'Tbsps',
#                                                   'unitShort': 'Tbsps'},
#                                        'us': {'amount': 3.0,
#                                               'unitLong': 'Tbsps',
#                                               'unitShort': 'Tbsps'}},
#                           'meta': ['unsalted',
#                                    'organic',
#                                    'at room temperature'],
#                           'metaInformation': ['unsalted',
#                                               'organic',
#                                               'at room temperature'],
#                           'name': 'unsalted butter',
#                           'original': '3 Tbsp. unsalted organic butter at room '
#                                       'temperature',
#                           'originalName': 'unsalted organic butter at room '
#                                           'temperature',
#                           'originalString': '3 Tbsp. unsalted organic butter '
#                                             'at room temperature',
#                           'unit': 'Tbsp'},
#                          {'aisle': 'Baking',
#                           'amount': 2.0,
#                           'consistency': 'liquid',
#                           'id': 2050,
#                           'image': 'vanilla-extract.jpg',
#                           'measures': {'metric': {'amount': 2.0,
#                                                   'unitLong': 'teaspoons',
#                                                   'unitShort': 'tsps'},
#                                        'us': {'amount': 2.0,
#                                               'unitLong': 'teaspoons',
#                                               'unitShort': 'tsps'}},
#                           'meta': ['pure',
#                                    '(increased 1 tsp. vanilla to enhance '
#                                    'sweetness)'],
#                           'metaInformation': ['pure',
#                                               '(increased 1 tsp. vanilla to '
#                                               'enhance sweetness)'],
#                           'name': 'vanilla extract',
#                           'original': '2 tsp. pure vanilla extract (increased '
#                                       '1 tsp. vanilla to enhance sweetness)',
#                           'originalName': 'pure vanilla extract (increased 1 '
#                                           'tsp. vanilla to enhance sweetness)',
#                           'originalString': '2 tsp. pure vanilla extract '
#                                             '(increased 1 tsp. vanilla to '
#                                             'enhance sweetness)',
#                           'unit': 'tsp'},
#                          {'aisle': 'Milk, Eggs, Other Dairy',
#                           'amount': 1.0,
#                           'consistency': 'liquid',
#                           'id': 1119,
#                           'image': 'vanilla-yogurt.png',
#                           'measures': {'metric': {'amount': 236.588,
#                                                   'unitLong': 'milliliters',
#                                                   'unitShort': 'ml'},
#                                        'us': {'amount': 1.0,
#                                               'unitLong': 'cup',
#                                               'unitShort': 'cup'}},
#                           'meta': ['organic'],
#                           'metaInformation': ['organic'],
#                           'name': 'vanilla yogurt',
#                           'original': '1 cup organic vanilla yogurt',
#                           'originalName': 'organic vanilla yogurt',
#                           'originalString': '1 cup organic vanilla yogurt',
#                           'unit': 'cup'},
#                          {'aisle': 'Gluten Free;Health Foods',
#                           'amount': 2.25,
#                           'consistency': 'solid',
#                           'id': 20132,
#                           'image': 'brown-flour.jpg',
#                           'measures': {'metric': {'amount': 532.323,
#                                                   'unitLong': 'milliliters',
#                                                   'unitShort': 'ml'},
#                                        'us': {'amount': 2.25,
#                                               'unitLong': 'cups',
#                                               'unitShort': 'cups'}},
#                           'meta': ['whole-wheat', 'whole', 'white'],
#                           'metaInformation': ['whole-wheat', 'whole', 'white'],
#                           'name': 'whole grain oat flour',
#                           'original': '2 ¼ cups spelt, kamut, or whole grain '
#                                       'whole-wheat flour (replaced 2 ¼ cups '
#                                       'white cake flour)',
#                           'originalName': 'spelt, kamut, or whole grain '
#                                           'whole-wheat flour (replaced 2 ¼ '
#                                           'cups white cake flour)',
#                           'originalString': '2 ¼ cups spelt, kamut, or whole '
#                                             'grain whole-wheat flour (replaced '
#                                             '2 ¼ cups white cake flour)',
#                           'unit': 'cups'}],
#  'gaps': 'no',
#  'glutenFree': True,
#  'healthScore': 14.0,
#  'id': 66135,
#  'image': 'https://spoonacular.com/recipeImages/66135-556x370.jpg',
#  'imageType': 'jpg',
#  'instructions': None,
#  'lowFodmap': False,
#  'nutrition': {'caloricBreakdown': {'percentCarbs': 63.33,
#                                     'percentFat': 25.99,
#                                     'percentProtein': 10.68},
#                'ingredients': [{'amount': 0.25,
#                                 'name': 'aluminum free baking powder',
#                                 'nutrients': [{'amount': 1.13,
#                                                'name': 'Sodium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Caffeine',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin D',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin E',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Alcohol',
#                                                'unit': 'g'},
#                                               {'amount': 0.36,
#                                                'name': 'Magnesium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Folate',
#                                                'unit': 'µg'},
#                                               {'amount': 0.03,
#                                                'name': 'Fiber',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Folic Acid',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin C',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Copper',
#                                                'unit': 'mg'},
#                                               {'amount': 0.59,
#                                                'name': 'Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin K',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B6',
#                                                'unit': 'mg'},
#                                               {'amount': 0.56,
#                                                'name': 'Net Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B1',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B2',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B3',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B5',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Choline',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Protein',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B12',
#                                                'unit': 'µg'},
#                                               {'amount': 1.21,
#                                                'name': 'Calories',
#                                                'unit': 'cal'},
#                                               {'amount': 54.15,
#                                                'name': 'Calcium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.1,
#                                                'name': 'Iron',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Selenium',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Cholesterol',
#                                                'unit': 'mg'},
#                                               {'amount': 0.01,
#                                                'name': 'Zinc',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Saturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 126.25,
#                                                'name': 'Potassium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Mono Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Poly Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.01,
#                                                'name': 'Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.01,
#                                                'name': 'Manganese',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin A',
#                                                'unit': 'IU'},
#                                               {'amount': 0.0,
#                                                'name': 'Sugar',
#                                                'unit': 'g'},
#                                               {'amount': 85.86,
#                                                'name': 'Phosphorus',
#                                                'unit': 'mg'}],
#                                 'unit': 'tsp'},
#                                {'amount': 0.5,
#                                 'name': 'applesauce',
#                                 'nutrients': [{'amount': 0.15,
#                                                'name': 'Sodium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Caffeine',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin D',
#                                                'unit': 'µg'},
#                                               {'amount': 0.01,
#                                                'name': 'Vitamin E',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Alcohol',
#                                                'unit': 'g'},
#                                               {'amount': 0.23,
#                                                'name': 'Magnesium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.23,
#                                                'name': 'Folate',
#                                                'unit': 'µg'},
#                                               {'amount': 0.08,
#                                                'name': 'Fiber',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Folic Acid',
#                                                'unit': 'µg'},
#                                               {'amount': 0.08,
#                                                'name': 'Vitamin C',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Copper',
#                                                'unit': 'mg'},
#                                               {'amount': 0.85,
#                                                'name': 'Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.04,
#                                                'name': 'Vitamin K',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B6',
#                                                'unit': 'mg'},
#                                               {'amount': 0.76,
#                                                'name': 'Net Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B1',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B2',
#                                                'unit': 'mg'},
#                                               {'amount': 0.01,
#                                                'name': 'Vitamin B3',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B5',
#                                                'unit': 'mg'},
#                                               {'amount': 0.17,
#                                                'name': 'Choline',
#                                                'unit': 'mg'},
#                                               {'amount': 0.01,
#                                                'name': 'Protein',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B12',
#                                                'unit': 'µg'},
#                                               {'amount': 3.15,
#                                                'name': 'Calories',
#                                                'unit': 'cal'},
#                                               {'amount': 0.3,
#                                                'name': 'Calcium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.02,
#                                                'name': 'Iron',
#                                                'unit': 'mg'},
#                                               {'amount': 0.02,
#                                                'name': 'Selenium',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Cholesterol',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Zinc',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Saturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 5.55,
#                                                'name': 'Potassium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Mono Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Poly Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.01,
#                                                'name': 'Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Manganese',
#                                                'unit': 'mg'},
#                                               {'amount': 2.17,
#                                                'name': 'Vitamin A',
#                                                'unit': 'IU'},
#                                               {'amount': 0.7,
#                                                'name': 'Sugar',
#                                                'unit': 'g'},
#                                               {'amount': 0.38,
#                                                'name': 'Phosphorus',
#                                                'unit': 'mg'}],
#                                 'unit': 'Tbsp'},
#                                {'amount': 0.13,
#                                 'name': 'baking soda',
#                                 'nutrients': [{'amount': 157.32,
#                                                'name': 'Sodium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Caffeine',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin D',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin E',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Alcohol',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Magnesium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Folate',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Fiber',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Folic Acid',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin C',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Copper',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin K',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B6',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Net Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B1',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B2',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B3',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B5',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Choline',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Protein',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B12',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Calories',
#                                                'unit': 'cal'},
#                                               {'amount': 0.0,
#                                                'name': 'Calcium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Iron',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Selenium',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Cholesterol',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Zinc',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Saturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Potassium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Mono Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Poly Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Manganese',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin A',
#                                                'unit': 'IU'},
#                                               {'amount': 0.0,
#                                                'name': 'Sugar',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Phosphorus',
#                                                'unit': 'mg'}],
#                                 'unit': 'tsp'},
#                                {'amount': 0.13,
#                                 'name': 'cane sugar',
#                                 'nutrients': [{'amount': 0.25,
#                                                'name': 'Sodium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Caffeine',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin D',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin E',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Alcohol',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Magnesium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Folate',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Fiber',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Folic Acid',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin C',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Copper',
#                                                'unit': 'mg'},
#                                               {'amount': 25.0,
#                                                'name': 'Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin K',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B6',
#                                                'unit': 'mg'},
#                                               {'amount': 25.0,
#                                                'name': 'Net Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B1',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B2',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B3',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B5',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Choline',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Protein',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Fluoride',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B12',
#                                                'unit': 'µg'},
#                                               {'amount': 96.75,
#                                                'name': 'Calories',
#                                                'unit': 'cal'},
#                                               {'amount': 0.25,
#                                                'name': 'Calcium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.01,
#                                                'name': 'Iron',
#                                                'unit': 'mg'},
#                                               {'amount': 0.15,
#                                                'name': 'Selenium',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Cholesterol',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Zinc',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Saturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.5,
#                                                'name': 'Potassium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Mono Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Poly Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
# ...
#                                               {'amount': 44.35,
#                                                'name': 'Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 2.16,
#                                                'name': 'Vitamin K',
#                                                'unit': 'µg'},
#                                               {'amount': 0.08,
#                                                'name': 'Vitamin B6',
#                                                'unit': 'mg'},
#                                               {'amount': 39.96,
#                                                'name': 'Net Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.47,
#                                                'name': 'Vitamin B1',
#                                                'unit': 'mg'},
#                                               {'amount': 0.08,
#                                                'name': 'Vitamin B2',
#                                                'unit': 'mg'},
#                                               {'amount': 0.99,
#                                                'name': 'Vitamin B3',
#                                                'unit': 'mg'},
#                                               {'amount': 0.14,
#                                                'name': 'Vitamin B5',
#                                                'unit': 'mg'},
#                                               {'amount': 20.18,
#                                                'name': 'Choline',
#                                                'unit': 'mg'},
#                                               {'amount': 9.9,
#                                                'name': 'Protein',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B12',
#                                                'unit': 'µg'},
#                                               {'amount': 272.7,
#                                                'name': 'Calories',
#                                                'unit': 'cal'},
#                                               {'amount': 37.13,
#                                                'name': 'Calcium',
#                                                'unit': 'mg'},
#                                               {'amount': 2.7,
#                                                'name': 'Iron',
#                                                'unit': 'mg'},
#                                               {'amount': 22.95,
#                                                'name': 'Selenium',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Cholesterol',
#                                                'unit': 'mg'},
#                                               {'amount': 2.16,
#                                                'name': 'Zinc',
#                                                'unit': 'mg'},
#                                               {'amount': 1.08,
#                                                'name': 'Saturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 250.43,
#                                                'name': 'Potassium',
#                                                'unit': 'mg'},
#                                               {'amount': 1.93,
#                                                'name': 'Mono Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 2.25,
#                                                'name': 'Poly Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 6.16,
#                                                'name': 'Fat',
#                                                'unit': 'g'},
#                                               {'amount': 2.71,
#                                                'name': 'Manganese',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin A',
#                                                'unit': 'IU'},
#                                               {'amount': 0.54,
#                                                'name': 'Sugar',
#                                                'unit': 'g'},
#                                               {'amount': 305.1,
#                                                'name': 'Phosphorus',
#                                                'unit': 'mg'}],
#                                 'unit': 'cups'}],
#                'nutrients': [{'amount': 582.59,
#                               'percentOfDailyNeeds': 29.13,
#                               'title': 'Calories',
#                               'unit': 'cal'},
#                              {'amount': 17.0,
#                               'percentOfDailyNeeds': 26.15,
#                               'title': 'Fat',
#                               'unit': 'g'},
#                              {'amount': 7.16,
#                               'percentOfDailyNeeds': 44.73,
#                               'title': 'Saturated Fat',
#                               'unit': 'g'},
#                              {'amount': 93.22,
#                               'percentOfDailyNeeds': 31.07,
#                               'title': 'Carbohydrates',
#                               'unit': 'g'},
#                              {'amount': 84.91,
#                               'percentOfDailyNeeds': 30.88,
#                               'title': 'Net Carbohydrates',
#                               'unit': 'g'},
#                              {'amount': 43.3,
#                               'percentOfDailyNeeds': 48.11,
#                               'title': 'Sugar',
#                               'unit': 'g'},
#                              {'amount': 25.96,
#                               'percentOfDailyNeeds': 8.65,
#                               'title': 'Cholesterol',
#                               'unit': 'mg'},
#                              {'amount': 531.33,
#                               'percentOfDailyNeeds': 23.1,
#                               'title': 'Sodium',
#                               'unit': 'mg'},
#                              {'amount': 0.72,
#                               'percentOfDailyNeeds': 4.01,
#                               'title': 'Alcohol',
#                               'unit': 'g'},
#                              {'amount': 15.72,
#                               'percentOfDailyNeeds': 31.43,
#                               'title': 'Protein',
#                               'unit': 'g'},
#                              {'amount': 3.33,
#                               'percentOfDailyNeeds': 166.37,
#                               'title': 'Manganese',
#                               'unit': 'mg'},
#                              {'amount': 509.32,
#                               'percentOfDailyNeeds': 50.93,
#                               'title': 'Phosphorus',
#                               'unit': 'mg'},
#                              {'amount': 30.0,
#                               'percentOfDailyNeeds': 42.85,
#                               'title': 'Selenium',
#                               'unit': 'µg'},
#                              {'amount': 0.56,
#                               'percentOfDailyNeeds': 37.48,
#                               'title': 'Vitamin B1',
#                               'unit': 'mg'},
#                              {'amount': 8.31,
#                               'percentOfDailyNeeds': 33.23,
#                               'title': 'Fiber',
#                               'unit': 'g'},
#                              {'amount': 132.48,
#                               'percentOfDailyNeeds': 33.12,
#                               'title': 'Magnesium',
#                               'unit': 'mg'},
#                              {'amount': 0.44,
#                               'percentOfDailyNeeds': 25.68,
#                               'title': 'Vitamin B2',
#                               'unit': 'mg'},
#                              {'amount': 231.76,
#                               'percentOfDailyNeeds': 23.18,
#                               'title': 'Calcium',
#                               'unit': 'mg'},
#                              {'amount': 17.21,
#                               'percentOfDailyNeeds': 20.86,
#                               'title': 'Vitamin C',
#                               'unit': 'mg'},
#                              {'amount': 3.08,
#                               'percentOfDailyNeeds': 20.52,
#                               'title': 'Zinc',
#                               'unit': 'mg'},
#                              {'amount': 0.39,
#                               'percentOfDailyNeeds': 19.42,
#                               'title': 'Copper',
#                               'unit': 'mg'},
#                              {'amount': 668.55,
#                               'percentOfDailyNeeds': 19.1,
#                               'title': 'Potassium',
#                               'unit': 'mg'},
#                              {'amount': 3.38,
#                               'percentOfDailyNeeds': 18.78,
#                               'title': 'Iron',
#                               'unit': 'mg'},
#                              {'amount': 42.87,
#                               'percentOfDailyNeeds': 10.72,
#                               'title': 'Folate',
#                               'unit': 'µg'},
#                              {'amount': 0.16,
#                               'percentOfDailyNeeds': 7.93,
#                               'title': 'Vitamin B6',
#                               'unit': 'mg'},
#                              {'amount': 1.16,
#                               'percentOfDailyNeeds': 7.72,
#                               'title': 'Vitamin E',
#                               'unit': 'mg'},
#                              {'amount': 1.47,
#                               'percentOfDailyNeeds': 7.33,
#                               'title': 'Vitamin B3',
#                               'unit': 'mg'},
#                              {'amount': 0.71,
#                               'percentOfDailyNeeds': 7.06,
#                               'title': 'Vitamin B5',
#                               'unit': 'mg'},
#                              {'amount': 6.63,
#                               'percentOfDailyNeeds': 6.31,
#                               'title': 'Vitamin K',
#                               'unit': 'µg'},
#                              {'amount': 310.71,
#                               'percentOfDailyNeeds': 6.21,
#                               'title': 'Vitamin A',
#                               'unit': 'IU'},
#                              {'amount': 0.36,
#                               'percentOfDailyNeeds': 5.94,
#                               'title': 'Vitamin B12',
#                               'unit': 'µg'},
#                              {'amount': 0.16,
#                               'percentOfDailyNeeds': 1.07,
#                               'title': 'Vitamin D',
#                               'unit': 'µg'}],
#                'properties': [{'amount': 41.15,
#                                'title': 'Glycemic Index',
#                                'unit': ''},
#                               {'amount': 20.63,
#                                'title': 'Glycemic Load',
#                                'unit': ''}],
#                'weightPerServing': {'amount': 258, 'unit': 'g'}},
#  'occasions': [],
#  'originalId': None,
#  'pricePerServing': 204.21,
#  'readyInMinutes': 45,
#  'servings': 4,
#  'sourceName': None,
#  'sourceUrl': 'http://www.mynewroots.blogspot.com/2008/05/pound-for-pound.html',
#  'spoonacularScore': 50.0,
#  'summary': 'Lemon Raspberry Pound Cake might be just the dessert you are '
#             'searching for. This gluten free and vegetarian recipe serves 4 '
#             'and costs <b>$2.04 per serving</b>. One serving contains <b>583 '
#             'calories</b>, <b>16g of protein</b>, and <b>17g of fat</b>. 1 '
#             'person has made this recipe and would make it again. If you have '
#             'ground flax seed, lemon zest, cane sugar, and a few other '
#             'ingredients on hand, you can make it. From preparation to the '
#             'plate, this recipe takes roughly <b>45 minutes</b>. All things '
#             'considered, we decided this recipe <b>deserves a spoonacular '
#             'score of 54%</b>. This score is solid. Similar recipes are <a '
#             'href="https://spoonacular.com/recipes/lemon-raspberry-pound-cake-631390">Lemon '
#             'Raspberry Pound Cake</a>, <a '
#             'href="https://spoonacular.com/recipes/raspberry-pound-cake-truffles-236834">Raspberry '
#             'Pound Cake Truffles</a>, and <a '
#             'href="https://spoonacular.com/recipes/chocolate-raspberry-pound-cake-50290">Chocolate '
#             'Raspberry Pound Cake</a>.',
#  'sustainable': False,
#  'title': 'Lemon Raspberry Pound Cake',
#  'vegan': False,
#  'vegetarian': True,
#  'veryHealthy': False,
#  'veryPopular': False,
#  'weightWatcherSmartPoints': 22,
#  'winePairing': {'pairedWines': ['cream sherry', 'moscato dasti', 'port'],
#                  'pairingText': "Cream Sherry, Moscato d'Asti, and Port are my "
#                                 'top picks for Dessert. A common wine pairing '
#                                 'rule is to make sure your wine is sweeter '
#                                 'than your food. Delicate desserts go well '
#                                 "with Moscato d'Asti, nutty desserts with "
#                                 'cream sherry, and caramel or chocolate '
#                                 'desserts pair well with port. The NV Solera '
#                                 'Cream Sherry with a 4.5 out of 5 star rating '
#                                 'seems like a good match. It costs about 17 '
#                                 'dollars per bottle.',
#                  'productMatches': [{'averageRating': 0.9,
#                                      'description': 'The Solera Cream Sherry '
#                                                     'has a brilliant amber and '
#                                                     'deep copper hue. With '
#                                                     'butterscotch and pecan '
#                                                     'aromas, the sweet salted '
#                                                     'nut and brown spice '
#                                                     'aromas carry a complex '
#                                                     'caramel accent. A sweet '
#                                                     'entry leads to a rounded, '
#                                                     'lush, moderately '
#                                                     'full-bodied palate with a '
#                                                     'lengthy, flavorful '
#                                                     'finish.',
#                                      'id': 428475,
#                                      'imageUrl': 'https://spoonacular.com/productImages/428475-312x231.jpg',
#                                      'link': 'https://www.amazon.com/NV-Solera-Cream-Sherry-750/dp/B00HSME8OW?tag=spoonacular-20',
#                                      'price': '$16.99',
#                                      'ratingCount': 4.0,
#                                      'score': 0.823076923076923,
#                                      'title': 'NV Solera Cream Sherry'}]}}

# %%
random_num = [random.randrange(1,200000,1) for i in range(5)]
random_num
# Out:
# [53885, 99045, 44710, 180457, 18978]

# %%
# ingredients = list(range(len(response['nutrition']['ingredients'])))
# ingredients

# for i in ingredients:
#     names = response['nutrition']['ingredients'][i]['name']
#     print(names)

# Extract desired data from the stored json response 
summary = response['summary']
title = response['title']
prepTime = response['readyInMinutes']
image = response['image']
pairedWine = response['winePairing']['pairedWines']
pairingDesc = response['winePairing']['pairingText']
id_number = response['id']
serving = response['servings']
likes = response['aggregateLikes']
sourceurl = response['sourceUrl']
nutrition = response['nutrition']['caloricBreakdown']

# food_names = response['nutrition']['ingredients'][i for i in ingredients]['name']
# Out:
# {'percentProtein': 10.68, 'percentFat': 25.99, 'percentCarbs': 63.33}

# %%
url_base = f"https://api.spoonacular.com/recipes/"
url_tail = "/information?includeNutrition=true"
key = f"&apiKey={api_key}"

for num in random_num:
    params = f'{num}'

    response = s.get(url_base + params + url_tail + key).json()

# %%
# create empty dataframe to collect dish pairings from list of wines 
columns = ['Recipe_ID']
recipe_df = pd.DataFrame(columns=columns)
recipe_df
# dish_pairing_df['wine'] = wine_selections
# dish_pairing_df
# Out:
# Empty DataFrame
# Columns: [Recipe_ID]
# Index: []

# %%
recipe_num= [random.randrange(1,200000,1) for i in range(5)]
recipe_num
# Out:
# [92605, 59934, 92789, 81887, 34486]

# %%
recipe_df['Recipe_ID'] = recipe_num
recipe_df
# Out:
#    Recipe_ID
# 0      92605
# 1      59934
# 2      92789
# 3      81887
# 4      34486

# %%
recipe_df['Spoon_ID'] = ''
recipe_df['Title'] = ''
recipe_df['PrepTime'] = ''
recipe_df['Summary'] = ''
recipe_df['CaloricBreakdown'] = ''
recipe_df['Servings'] = ''
recipe_df['Likes'] = ''
recipe_df['SourceURL'] = ''
recipe_df['ImageURL'] = ''
recipe_df['WinePairing'] = ''
recipe_df['WineDescription'] = ''
recipe_df
# Out:
#    Recipe_ID Spoon_ID Title PrepTime Summary CaloricBreakdown Servings Likes  \
# 0      92605
# 1      59934
# 2      92789
# 3      81887
# 4      34486
#
#   SourceURL ImageURL WinePairing WineDescription
# 0
# 1
# 2
# 3
# 4

# %%
url_base = f"https://api.spoonacular.com/recipes/"
url_tail = "/information?includeNutrition=true"
key = f"&apiKey={api_key}"

# recipe_query = f"{url_base}{meal_id}{recipe_url_tail}&apiKey={key}"

s = requests.Session()
# response = s.get(recipe_query).json()
# response

# %%
for index, row in recipe_df.iterrows():
    meal_id = row['Recipe_ID']
    params = f'{meal_id}'

    response = s.get(url_base + params + url_tail + key).json()  
    
    try:
        recipe_df.loc[index,"Spoon_ID"] = response['id']
        recipe_df.loc[index,"Title"] = response['title']
        recipe_df.loc[index,"PrepTime"] = response['readyInMinutes']
        recipe_df.loc[index,"Summary"] = response['summary']
#         recipe_df.loc[index,"CaloricBreakdown"] = response['nutrition']['caloricBreakdown']
#         recipe_df.loc[index,"Servings"] = response['servings']
#         recipe_df.loc[index,"Likes"] = response['aggregateLikes']
#         recipe_df.loc[index,"SourceURL"] = response['sourceURL']
#         recipe_df.loc[index,"ImageURL"] = response['image']
#         recipe_df.loc[index,"WinePairing"] = response['winePairing']['pairedWines']
#         recipe_df.loc[index,"WineDescription"] = response['winePairing']['pairingText']
    except (KeyError, IndexError, ValueError):
        recipe_df.loc[index,"Spoon_ID"] = "ID does not exist"
        recipe_df.loc[index,"Title"] = "no title available"
        recipe_df.loc[index,"PrepTime"] = "no prep time available"
        recipe_df.loc[index,"Summary"] = "no summary avaialble"
#         recipe_df.loc[index,"CaloricBreakdown"] = "no calorie information available"
#         recipe_df.loc[index,"Servings"] = "no servings available"
#         recipe_df.loc[index,"Likes"] = "noone likes this dish"
#         recipe_df.loc[index,"SourceURL"] = "no source URL available"
#         recipe_df.loc[index,"ImageURL"] = "no image URL available"
#         recipe_df.loc[index,"WinePairing"] = "no wine pairing available"
#         recipe_df.loc[index,"WineDescription"] = "no wine description available"

# %%
recipe_df
# Out:
#    Recipe_ID           Spoon_ID                           Title  \
# 0      92605              92605   Cheesy Fried Brussels Sprouts
# 1      59934              59934  Seriously Asian: Caramel Sauce
# 2      92789  ID does not exist              no title available
# 3      81887              81887     Pancetta-wrapped Pork Roast
# 4      34486              34486     Stir-Fried Noodles and Pork
#
#                  PrepTime                                            Summary  \
# 0                      45  You can never have too many main course recipe...
# 1                    1788  You can never have too many sauce recipes, so ...
# 2  no prep time available                               no summary avaialble
# 3                      70  You can never have too many main course recipe...
# 4                      35  Need a <b>dairy free main course</b>? Stir-Fri...
#
#   CaloricBreakdown Servings Likes SourceURL ImageURL WinePairing  \
# 0
# 1
# 2
# 3
# 4
#
#   WineDescription
# 0
# 1
# 2
# 3
# 4
