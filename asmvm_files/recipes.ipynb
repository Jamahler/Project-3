# %%
import json, requests
from pprint import pprint
import pandas as pd
from config import api_key
import numpy as np
import random

# %%
recipe_base = f"https://api.spoonacular.com/recipes/"
recipe_url_tail = "/information?includeNutrition=true"
# recipe_url_base =f"https://api.spoonacular.com/recipes/information?includeNutrition=true/"
recipe_id = "66135"
recipe_query = f"{recipe_base}{recipe_id}{recipe_url_tail}&apiKey={api_key}"
print(recipe_query)
# Out:
# https://api.spoonacular.com/recipes/66135/information?includeNutrition=true&apiKey=655b2ca78d0b4f769402f9bd14d4064a

# %%
s = requests.Session()
response = s.get(recipe_query).json()
## pretty print the response 
pprint(response)
# response
# Out:
# {'aggregateLikes': 0,
#  'analyzedInstructions': [],
#  'cheap': False,
#  'creditsText': None,
#  'cuisines': [],
#  'dairyFree': False,
#  'diets': ['gluten free', 'lacto ovo vegetarian'],
#  'dishTypes': ['lunch', 'main course', 'main dish', 'dinner'],
#  'extendedIngredients': [{'aisle': 'Baking',
#                           'amount': 1.0,
#                           'consistency': 'solid',
#                           'id': 18371,
#                           'image': 'white-powder.jpg',
#                           'measures': {'metric': {'amount': 1.0,
#                                                   'unitLong': 'teaspoon',
#                                                   'unitShort': 'tsp'},
#                                        'us': {'amount': 1.0,
#                                               'unitLong': 'teaspoon',
#                                               'unitShort': 'tsp'}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'aluminum free baking powder',
#                           'original': '1 tsp. aluminum-free baking powder',
#                           'originalName': 'aluminum-free baking powder',
#                           'originalString': '1 tsp. aluminum-free baking '
#                                             'powder',
#                           'unit': 'tsp'},
#                          {'aisle': 'Canned and Jarred',
#                           'amount': 2.0,
#                           'consistency': 'solid',
#                           'id': 9019,
#                           'image': 'applesauce.png',
#                           'measures': {'metric': {'amount': 2.0,
#                                                   'unitLong': 'Tbsps',
#                                                   'unitShort': 'Tbsps'},
#                                        'us': {'amount': 2.0,
#                                               'unitLong': 'Tbsps',
#                                               'unitShort': 'Tbsps'}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'applesauce',
#                           'original': '2 Tbsp. applesauce (replaced 2 Tbsp. '
#                                       'butter)',
#                           'originalName': 'applesauce (replaced 2 Tbsp. '
#                                           'butter)',
#                           'originalString': '2 Tbsp. applesauce (replaced 2 '
#                                             'Tbsp. butter)',
#                           'unit': 'Tbsp'},
#                          {'aisle': 'Baking',
#                           'amount': 0.5,
#                           'consistency': 'solid',
#                           'id': 18372,
#                           'image': 'white-powder.jpg',
#                           'measures': {'metric': {'amount': 0.5,
#                                                   'unitLong': 'teaspoons',
#                                                   'unitShort': 'tsps'},
#                                        'us': {'amount': 0.5,
#                                               'unitLong': 'teaspoons',
#                                               'unitShort': 'tsps'}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'baking soda',
#                           'original': '½ tsp. baking soda',
#                           'originalName': 'baking soda',
#                           'originalString': '½ tsp. baking soda',
#                           'unit': 'tsp'},
#                          {'aisle': 'Baking',
#                           'amount': 0.5,
#                           'consistency': 'solid',
#                           'id': 19335,
#                           'image': 'sugar-in-bowl.png',
#                           'measures': {'metric': {'amount': 118.294,
#                                                   'unitLong': 'milliliters',
#                                                   'unitShort': 'ml'},
#                                        'us': {'amount': 0.5,
#                                               'unitLong': 'cups',
#                                               'unitShort': 'cups'}},
#                           'meta': ['raw',
#                                    'white',
#                                    'organic',
#                                    '(replaced 1 cup sugar)'],
#                           'metaInformation': ['raw',
#                                               'white',
#                                               'organic',
#                                               '(replaced 1 cup sugar)'],
#                           'name': 'cane sugar',
#                           'original': '½ cup organic raw cane sugar or Sucanat '
#                                       '(replaced 1 cup white sugar)',
#                           'originalName': 'organic raw cane sugar or Sucanat '
#                                           '(replaced 1 cup white sugar)',
#                           'originalString': '½ cup organic raw cane sugar or '
#                                             'Sucanat (replaced 1 cup white '
#                                             'sugar)',
#                           'unit': 'cup'},
#                          {'aisle': 'Milk, Eggs, Other Dairy',
#                           'amount': 2.0,
#                           'consistency': 'solid',
#                           'id': 1124,
#                           'image': 'egg-white.jpg',
#                           'measures': {'metric': {'amount': 2.0,
#                                                   'unitLong': '',
#                                                   'unitShort': ''},
#                                        'us': {'amount': 2.0,
#                                               'unitLong': '',
#                                               'unitShort': ''}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'egg whites',
#                           'original': '2 egg whites',
#                           'originalName': 'egg whites',
#                           'originalString': '2 egg whites',
#                           'unit': ''},
#                          {'aisle': 'Health Foods;Baking',
#                           'amount': 1.0,
#                           'consistency': 'solid',
#                           'id': 12220,
#                           'image': 'flax-seeds.png',
#                           'measures': {'metric': {'amount': 1.0,
#                                                   'unitLong': 'Tbsp',
#                                                   'unitShort': 'Tbsp'},
#                                        'us': {'amount': 1.0,
#                                               'unitLong': 'Tbsp',
#                                               'unitShort': 'Tbsp'}},
#                           'meta': ['mixed',
#                                    'with 3 tbsp. water (replaced 1 large egg)'],
#                           'metaInformation': ['mixed',
#                                               'with 3 tbsp. water (replaced 1 '
#                                               'large egg)'],
#                           'name': 'ground flax seed',
#                           'original': '1 Tbsp. ground flax seed mixed with 3 '
#                                       'Tbsp. water (replaced 1 large egg)',
#                           'originalName': 'ground flax seed mixed with 3 Tbsp. '
#                                           'water (replaced 1 large egg)',
#                           'originalString': '1 Tbsp. ground flax seed mixed '
#                                             'with 3 Tbsp. water (replaced 1 '
#                                             'large egg)',
#                           'unit': 'Tbsp'},
#                          {'aisle': 'Produce',
#                           'amount': 2.0,
#                           'consistency': 'liquid',
#                           'id': 9152,
#                           'image': 'lemon-juice.jpg',
#                           'measures': {'metric': {'amount': 2.0,
#                                                   'unitLong': 'Tbsps',
#                                                   'unitShort': 'Tbsps'},
#                                        'us': {'amount': 2.0,
#                                               'unitLong': 'Tbsps',
#                                               'unitShort': 'Tbsps'}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'lemon juice',
#                           'original': '2 Tbsp. lemon juice',
#                           'originalName': 'lemon juice',
#                           'originalString': '2 Tbsp. lemon juice',
#                           'unit': 'Tbsp'},
#                          {'aisle': 'Produce',
#                           'amount': 1.0,
#                           'consistency': 'solid',
#                           'id': 9156,
#                           'image': 'zest-lemon.jpg',
#                           'measures': {'metric': {'amount': 1.0,
#                                                   'unitLong': '',
#                                                   'unitShort': ''},
#                                        'us': {'amount': 1.0,
#                                               'unitLong': '',
#                                               'unitShort': ''}},
#                           'meta': ['organic', 'finely grated'],
#                           'metaInformation': ['organic', 'finely grated'],
#                           'name': 'lemon zest',
#                           'original': 'Finely grated zest of 1 organic lemon',
#                           'originalName': 'Finely grated zest of organic lemon',
#                           'originalString': 'Finely grated zest of 1 organic '
#                                             'lemon',
#                           'unit': ''},
#                          {'aisle': 'Cereal',
#                           'amount': 2.0,
#                           'consistency': 'liquid',
#                           'id': 19911,
#                           'image': 'maple-syrup.png',
#                           'measures': {'metric': {'amount': 2.0,
#                                                   'unitLong': 'Tbsps',
#                                                   'unitShort': 'Tbsps'},
#                                        'us': {'amount': 2.0,
#                                               'unitLong': 'Tbsps',
#                                               'unitShort': 'Tbsps'}},
#                           'meta': ['pure'],
#                           'metaInformation': ['pure'],
#                           'name': 'maple syrup',
#                           'original': '2 Tbsp. pure maple syrup',
#                           'originalName': 'pure maple syrup',
#                           'originalString': '2 Tbsp. pure maple syrup',
#                           'unit': 'Tbsp'},
#                          {'aisle': 'Produce',
#                           'amount': 1.5,
#                           'consistency': 'solid',
#                           'id': 9302,
#                           'image': 'raspberries.jpg',
#                           'measures': {'metric': {'amount': 354.882,
#                                                   'unitLong': 'milliliters',
#                                                   'unitShort': 'ml'},
#                                        'us': {'amount': 1.5,
#                                               'unitLong': 'cups',
#                                               'unitShort': 'cups'}},
#                           'meta': ['frozen', '(increased fruit by)'],
#                           'metaInformation': ['frozen', '(increased fruit by)'],
#                           'name': 'raspberries',
#                           'original': '1 ½ cups raspberries frozen; keep '
#                                       'frozen until ready to use (increased '
#                                       'fruit by ½ cup)',
#                           'originalName': 'raspberries frozen; keep frozen '
#                                           'until ready to use (increased fruit '
#                                           'by ½ cup)',
#                           'originalString': '1 ½ cups raspberries frozen; keep '
#                                             'frozen until ready to use '
#                                             '(increased fruit by ½ cup)',
#                           'unit': 'cups'},
#                          {'aisle': 'Spices and Seasonings',
#                           'amount': 0.5,
#                           'consistency': 'solid',
#                           'id': 2047,
#                           'image': 'salt.jpg',
#                           'measures': {'metric': {'amount': 0.5,
#                                                   'unitLong': 'teaspoons',
#                                                   'unitShort': 'tsps'},
#                                        'us': {'amount': 0.5,
#                                               'unitLong': 'teaspoons',
#                                               'unitShort': 'tsps'}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'salt',
#                           'original': '½ tsp. salt',
#                           'originalName': 'salt',
#                           'originalString': '½ tsp. salt',
#                           'unit': 'tsp'},
#                          {'aisle': 'Milk, Eggs, Other Dairy',
#                           'amount': 3.0,
#                           'consistency': 'solid',
#                           'id': 1145,
#                           'image': 'butter-sliced.jpg',
#                           'measures': {'metric': {'amount': 3.0,
#                                                   'unitLong': 'Tbsps',
#                                                   'unitShort': 'Tbsps'},
#                                        'us': {'amount': 3.0,
#                                               'unitLong': 'Tbsps',
#                                               'unitShort': 'Tbsps'}},
#                           'meta': ['unsalted',
#                                    'organic',
#                                    'at room temperature'],
#                           'metaInformation': ['unsalted',
#                                               'organic',
#                                               'at room temperature'],
#                           'name': 'unsalted butter',
#                           'original': '3 Tbsp. unsalted organic butter at room '
#                                       'temperature',
#                           'originalName': 'unsalted organic butter at room '
#                                           'temperature',
#                           'originalString': '3 Tbsp. unsalted organic butter '
#                                             'at room temperature',
#                           'unit': 'Tbsp'},
#                          {'aisle': 'Baking',
#                           'amount': 2.0,
#                           'consistency': 'liquid',
#                           'id': 2050,
#                           'image': 'vanilla-extract.jpg',
#                           'measures': {'metric': {'amount': 2.0,
#                                                   'unitLong': 'teaspoons',
#                                                   'unitShort': 'tsps'},
#                                        'us': {'amount': 2.0,
#                                               'unitLong': 'teaspoons',
#                                               'unitShort': 'tsps'}},
#                           'meta': ['pure',
#                                    '(increased 1 tsp. vanilla to enhance '
#                                    'sweetness)'],
#                           'metaInformation': ['pure',
#                                               '(increased 1 tsp. vanilla to '
#                                               'enhance sweetness)'],
#                           'name': 'vanilla extract',
#                           'original': '2 tsp. pure vanilla extract (increased '
#                                       '1 tsp. vanilla to enhance sweetness)',
#                           'originalName': 'pure vanilla extract (increased 1 '
#                                           'tsp. vanilla to enhance sweetness)',
#                           'originalString': '2 tsp. pure vanilla extract '
#                                             '(increased 1 tsp. vanilla to '
#                                             'enhance sweetness)',
#                           'unit': 'tsp'},
#                          {'aisle': 'Milk, Eggs, Other Dairy',
#                           'amount': 1.0,
#                           'consistency': 'liquid',
#                           'id': 1119,
#                           'image': 'vanilla-yogurt.png',
#                           'measures': {'metric': {'amount': 236.588,
#                                                   'unitLong': 'milliliters',
#                                                   'unitShort': 'ml'},
#                                        'us': {'amount': 1.0,
#                                               'unitLong': 'cup',
#                                               'unitShort': 'cup'}},
#                           'meta': ['organic'],
#                           'metaInformation': ['organic'],
#                           'name': 'vanilla yogurt',
#                           'original': '1 cup organic vanilla yogurt',
#                           'originalName': 'organic vanilla yogurt',
#                           'originalString': '1 cup organic vanilla yogurt',
#                           'unit': 'cup'},
#                          {'aisle': 'Gluten Free;Health Foods',
#                           'amount': 2.25,
#                           'consistency': 'solid',
#                           'id': 20132,
#                           'image': 'brown-flour.jpg',
#                           'measures': {'metric': {'amount': 532.323,
#                                                   'unitLong': 'milliliters',
#                                                   'unitShort': 'ml'},
#                                        'us': {'amount': 2.25,
#                                               'unitLong': 'cups',
#                                               'unitShort': 'cups'}},
#                           'meta': ['whole-wheat', 'whole', 'white'],
#                           'metaInformation': ['whole-wheat', 'whole', 'white'],
#                           'name': 'whole grain oat flour',
#                           'original': '2 ¼ cups spelt, kamut, or whole grain '
#                                       'whole-wheat flour (replaced 2 ¼ cups '
#                                       'white cake flour)',
#                           'originalName': 'spelt, kamut, or whole grain '
#                                           'whole-wheat flour (replaced 2 ¼ '
#                                           'cups white cake flour)',
#                           'originalString': '2 ¼ cups spelt, kamut, or whole '
#                                             'grain whole-wheat flour (replaced '
#                                             '2 ¼ cups white cake flour)',
#                           'unit': 'cups'}],
#  'gaps': 'no',
#  'glutenFree': True,
#  'healthScore': 14.0,
#  'id': 66135,
#  'image': 'https://spoonacular.com/recipeImages/66135-556x370.jpg',
#  'imageType': 'jpg',
#  'instructions': None,
#  'lowFodmap': False,
#  'nutrition': {'caloricBreakdown': {'percentCarbs': 63.33,
#                                     'percentFat': 25.99,
#                                     'percentProtein': 10.68},
#                'ingredients': [{'amount': 0.25,
#                                 'name': 'aluminum free baking powder',
#                                 'nutrients': [{'amount': 1.13,
#                                                'name': 'Sodium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Caffeine',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin D',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin E',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Alcohol',
#                                                'unit': 'g'},
#                                               {'amount': 0.36,
#                                                'name': 'Magnesium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Folate',
#                                                'unit': 'µg'},
#                                               {'amount': 0.03,
#                                                'name': 'Fiber',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Folic Acid',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin C',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Copper',
#                                                'unit': 'mg'},
#                                               {'amount': 0.59,
#                                                'name': 'Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin K',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B6',
#                                                'unit': 'mg'},
#                                               {'amount': 0.56,
#                                                'name': 'Net Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B1',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B2',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B3',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B5',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Choline',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Protein',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B12',
#                                                'unit': 'µg'},
#                                               {'amount': 1.21,
#                                                'name': 'Calories',
#                                                'unit': 'cal'},
#                                               {'amount': 54.15,
#                                                'name': 'Calcium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.1,
#                                                'name': 'Iron',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Selenium',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Cholesterol',
#                                                'unit': 'mg'},
#                                               {'amount': 0.01,
#                                                'name': 'Zinc',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Saturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 126.25,
#                                                'name': 'Potassium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Mono Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Poly Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.01,
#                                                'name': 'Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.01,
#                                                'name': 'Manganese',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin A',
#                                                'unit': 'IU'},
#                                               {'amount': 0.0,
#                                                'name': 'Sugar',
#                                                'unit': 'g'},
#                                               {'amount': 85.86,
#                                                'name': 'Phosphorus',
#                                                'unit': 'mg'}],
#                                 'unit': 'tsp'},
#                                {'amount': 0.5,
#                                 'name': 'applesauce',
#                                 'nutrients': [{'amount': 0.15,
#                                                'name': 'Sodium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Caffeine',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin D',
#                                                'unit': 'µg'},
#                                               {'amount': 0.01,
#                                                'name': 'Vitamin E',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Alcohol',
#                                                'unit': 'g'},
#                                               {'amount': 0.23,
#                                                'name': 'Magnesium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.23,
#                                                'name': 'Folate',
#                                                'unit': 'µg'},
#                                               {'amount': 0.08,
#                                                'name': 'Fiber',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Folic Acid',
#                                                'unit': 'µg'},
#                                               {'amount': 0.08,
#                                                'name': 'Vitamin C',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Copper',
#                                                'unit': 'mg'},
#                                               {'amount': 0.85,
#                                                'name': 'Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.04,
#                                                'name': 'Vitamin K',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B6',
#                                                'unit': 'mg'},
#                                               {'amount': 0.76,
#                                                'name': 'Net Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B1',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B2',
#                                                'unit': 'mg'},
#                                               {'amount': 0.01,
#                                                'name': 'Vitamin B3',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B5',
#                                                'unit': 'mg'},
#                                               {'amount': 0.17,
#                                                'name': 'Choline',
#                                                'unit': 'mg'},
#                                               {'amount': 0.01,
#                                                'name': 'Protein',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B12',
#                                                'unit': 'µg'},
#                                               {'amount': 3.15,
#                                                'name': 'Calories',
#                                                'unit': 'cal'},
#                                               {'amount': 0.3,
#                                                'name': 'Calcium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.02,
#                                                'name': 'Iron',
#                                                'unit': 'mg'},
#                                               {'amount': 0.02,
#                                                'name': 'Selenium',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Cholesterol',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Zinc',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Saturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 5.55,
#                                                'name': 'Potassium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Mono Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Poly Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.01,
#                                                'name': 'Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Manganese',
#                                                'unit': 'mg'},
#                                               {'amount': 2.17,
#                                                'name': 'Vitamin A',
#                                                'unit': 'IU'},
#                                               {'amount': 0.7,
#                                                'name': 'Sugar',
#                                                'unit': 'g'},
#                                               {'amount': 0.38,
#                                                'name': 'Phosphorus',
#                                                'unit': 'mg'}],
#                                 'unit': 'Tbsp'},
#                                {'amount': 0.13,
#                                 'name': 'baking soda',
#                                 'nutrients': [{'amount': 157.32,
#                                                'name': 'Sodium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Caffeine',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin D',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin E',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Alcohol',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Magnesium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Folate',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Fiber',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Folic Acid',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin C',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Copper',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin K',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B6',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Net Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B1',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B2',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B3',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B5',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Choline',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Protein',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B12',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Calories',
#                                                'unit': 'cal'},
#                                               {'amount': 0.0,
#                                                'name': 'Calcium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Iron',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Selenium',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Cholesterol',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Zinc',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Saturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Potassium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Mono Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Poly Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Manganese',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin A',
#                                                'unit': 'IU'},
#                                               {'amount': 0.0,
#                                                'name': 'Sugar',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Phosphorus',
#                                                'unit': 'mg'}],
#                                 'unit': 'tsp'},
#                                {'amount': 0.13,
#                                 'name': 'cane sugar',
#                                 'nutrients': [{'amount': 0.25,
#                                                'name': 'Sodium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Caffeine',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin D',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin E',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Alcohol',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Magnesium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Folate',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Fiber',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Folic Acid',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin C',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Copper',
#                                                'unit': 'mg'},
#                                               {'amount': 25.0,
#                                                'name': 'Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin K',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B6',
#                                                'unit': 'mg'},
#                                               {'amount': 25.0,
#                                                'name': 'Net Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B1',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B2',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B3',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B5',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Choline',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Protein',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Fluoride',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B12',
#                                                'unit': 'µg'},
#                                               {'amount': 96.75,
#                                                'name': 'Calories',
#                                                'unit': 'cal'},
#                                               {'amount': 0.25,
#                                                'name': 'Calcium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.01,
#                                                'name': 'Iron',
#                                                'unit': 'mg'},
#                                               {'amount': 0.15,
#                                                'name': 'Selenium',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Cholesterol',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Zinc',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Saturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.5,
#                                                'name': 'Potassium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Mono Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Poly Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
# ...
#                                               {'amount': 39.96,
#                                                'name': 'Net Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.47,
#                                                'name': 'Vitamin B1',
#                                                'unit': 'mg'},
#                                               {'amount': 0.08,
#                                                'name': 'Vitamin B2',
#                                                'unit': 'mg'},
#                                               {'amount': 0.99,
#                                                'name': 'Vitamin B3',
#                                                'unit': 'mg'},
#                                               {'amount': 0.14,
#                                                'name': 'Vitamin B5',
#                                                'unit': 'mg'},
#                                               {'amount': 20.18,
#                                                'name': 'Choline',
#                                                'unit': 'mg'},
#                                               {'amount': 9.9,
#                                                'name': 'Protein',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B12',
#                                                'unit': 'µg'},
#                                               {'amount': 272.7,
#                                                'name': 'Calories',
#                                                'unit': 'cal'},
#                                               {'amount': 37.13,
#                                                'name': 'Calcium',
#                                                'unit': 'mg'},
#                                               {'amount': 2.7,
#                                                'name': 'Iron',
#                                                'unit': 'mg'},
#                                               {'amount': 22.95,
#                                                'name': 'Selenium',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Cholesterol',
#                                                'unit': 'mg'},
#                                               {'amount': 2.16,
#                                                'name': 'Zinc',
#                                                'unit': 'mg'},
#                                               {'amount': 1.08,
#                                                'name': 'Saturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 250.43,
#                                                'name': 'Potassium',
#                                                'unit': 'mg'},
#                                               {'amount': 1.93,
#                                                'name': 'Mono Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 2.25,
#                                                'name': 'Poly Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 6.16,
#                                                'name': 'Fat',
#                                                'unit': 'g'},
#                                               {'amount': 2.71,
#                                                'name': 'Manganese',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin A',
#                                                'unit': 'IU'},
#                                               {'amount': 0.54,
#                                                'name': 'Sugar',
#                                                'unit': 'g'},
#                                               {'amount': 305.1,
#                                                'name': 'Phosphorus',
#                                                'unit': 'mg'}],
#                                 'unit': 'cups'}],
#                'nutrients': [{'amount': 582.59,
#                               'percentOfDailyNeeds': 29.13,
#                               'title': 'Calories',
#                               'unit': 'cal'},
#                              {'amount': 17.0,
#                               'percentOfDailyNeeds': 26.15,
#                               'title': 'Fat',
#                               'unit': 'g'},
#                              {'amount': 7.16,
#                               'percentOfDailyNeeds': 44.73,
#                               'title': 'Saturated Fat',
#                               'unit': 'g'},
#                              {'amount': 93.22,
#                               'percentOfDailyNeeds': 31.07,
#                               'title': 'Carbohydrates',
#                               'unit': 'g'},
#                              {'amount': 84.91,
#                               'percentOfDailyNeeds': 30.88,
#                               'title': 'Net Carbohydrates',
#                               'unit': 'g'},
#                              {'amount': 43.3,
#                               'percentOfDailyNeeds': 48.11,
#                               'title': 'Sugar',
#                               'unit': 'g'},
#                              {'amount': 25.96,
#                               'percentOfDailyNeeds': 8.65,
#                               'title': 'Cholesterol',
#                               'unit': 'mg'},
#                              {'amount': 531.33,
#                               'percentOfDailyNeeds': 23.1,
#                               'title': 'Sodium',
#                               'unit': 'mg'},
#                              {'amount': 0.72,
#                               'percentOfDailyNeeds': 4.01,
#                               'title': 'Alcohol',
#                               'unit': 'g'},
#                              {'amount': 15.72,
#                               'percentOfDailyNeeds': 31.43,
#                               'title': 'Protein',
#                               'unit': 'g'},
#                              {'amount': 3.33,
#                               'percentOfDailyNeeds': 166.37,
#                               'title': 'Manganese',
#                               'unit': 'mg'},
#                              {'amount': 509.32,
#                               'percentOfDailyNeeds': 50.93,
#                               'title': 'Phosphorus',
#                               'unit': 'mg'},
#                              {'amount': 30.0,
#                               'percentOfDailyNeeds': 42.85,
#                               'title': 'Selenium',
#                               'unit': 'µg'},
#                              {'amount': 0.56,
#                               'percentOfDailyNeeds': 37.48,
#                               'title': 'Vitamin B1',
#                               'unit': 'mg'},
#                              {'amount': 8.31,
#                               'percentOfDailyNeeds': 33.23,
#                               'title': 'Fiber',
#                               'unit': 'g'},
#                              {'amount': 132.48,
#                               'percentOfDailyNeeds': 33.12,
#                               'title': 'Magnesium',
#                               'unit': 'mg'},
#                              {'amount': 0.44,
#                               'percentOfDailyNeeds': 25.68,
#                               'title': 'Vitamin B2',
#                               'unit': 'mg'},
#                              {'amount': 231.76,
#                               'percentOfDailyNeeds': 23.18,
#                               'title': 'Calcium',
#                               'unit': 'mg'},
#                              {'amount': 17.21,
#                               'percentOfDailyNeeds': 20.86,
#                               'title': 'Vitamin C',
#                               'unit': 'mg'},
#                              {'amount': 3.08,
#                               'percentOfDailyNeeds': 20.52,
#                               'title': 'Zinc',
#                               'unit': 'mg'},
#                              {'amount': 0.39,
#                               'percentOfDailyNeeds': 19.42,
#                               'title': 'Copper',
#                               'unit': 'mg'},
#                              {'amount': 668.55,
#                               'percentOfDailyNeeds': 19.1,
#                               'title': 'Potassium',
#                               'unit': 'mg'},
#                              {'amount': 3.38,
#                               'percentOfDailyNeeds': 18.78,
#                               'title': 'Iron',
#                               'unit': 'mg'},
#                              {'amount': 42.87,
#                               'percentOfDailyNeeds': 10.72,
#                               'title': 'Folate',
#                               'unit': 'µg'},
#                              {'amount': 0.16,
#                               'percentOfDailyNeeds': 7.93,
#                               'title': 'Vitamin B6',
#                               'unit': 'mg'},
#                              {'amount': 1.16,
#                               'percentOfDailyNeeds': 7.72,
#                               'title': 'Vitamin E',
#                               'unit': 'mg'},
#                              {'amount': 1.47,
#                               'percentOfDailyNeeds': 7.33,
#                               'title': 'Vitamin B3',
#                               'unit': 'mg'},
#                              {'amount': 0.71,
#                               'percentOfDailyNeeds': 7.06,
#                               'title': 'Vitamin B5',
#                               'unit': 'mg'},
#                              {'amount': 6.63,
#                               'percentOfDailyNeeds': 6.31,
#                               'title': 'Vitamin K',
#                               'unit': 'µg'},
#                              {'amount': 310.71,
#                               'percentOfDailyNeeds': 6.21,
#                               'title': 'Vitamin A',
#                               'unit': 'IU'},
#                              {'amount': 0.36,
#                               'percentOfDailyNeeds': 5.94,
#                               'title': 'Vitamin B12',
#                               'unit': 'µg'},
#                              {'amount': 0.16,
#                               'percentOfDailyNeeds': 1.07,
#                               'title': 'Vitamin D',
#                               'unit': 'µg'}],
#                'properties': [{'amount': 41.15,
#                                'title': 'Glycemic Index',
#                                'unit': ''},
#                               {'amount': 20.63,
#                                'title': 'Glycemic Load',
#                                'unit': ''}],
#                'weightPerServing': {'amount': 258, 'unit': 'g'}},
#  'occasions': [],
#  'originalId': None,
#  'pricePerServing': 204.21,
#  'readyInMinutes': 45,
#  'servings': 4,
#  'sourceName': None,
#  'sourceUrl': 'http://www.mynewroots.blogspot.com/2008/05/pound-for-pound.html',
#  'spoonacularScore': 50.0,
#  'summary': 'Lemon Raspberry Pound Cake might be just the dessert you are '
#             'searching for. This gluten free and vegetarian recipe serves 4 '
#             'and costs <b>$2.04 per serving</b>. One serving contains <b>583 '
#             'calories</b>, <b>16g of protein</b>, and <b>17g of fat</b>. 1 '
#             'person has made this recipe and would make it again. If you have '
#             'ground flax seed, lemon zest, cane sugar, and a few other '
#             'ingredients on hand, you can make it. From preparation to the '
#             'plate, this recipe takes roughly <b>45 minutes</b>. All things '
#             'considered, we decided this recipe <b>deserves a spoonacular '
#             'score of 54%</b>. This score is solid. Similar recipes are <a '
#             'href="https://spoonacular.com/recipes/lemon-raspberry-pound-cake-631390">Lemon '
#             'Raspberry Pound Cake</a>, <a '
#             'href="https://spoonacular.com/recipes/raspberry-pound-cake-truffles-236834">Raspberry '
#             'Pound Cake Truffles</a>, and <a '
#             'href="https://spoonacular.com/recipes/chocolate-raspberry-pound-cake-50290">Chocolate '
#             'Raspberry Pound Cake</a>.',
#  'sustainable': False,
#  'title': 'Lemon Raspberry Pound Cake',
#  'vegan': False,
#  'vegetarian': True,
#  'veryHealthy': False,
#  'veryPopular': False,
#  'weightWatcherSmartPoints': 22,
#  'winePairing': {'pairedWines': ['cream sherry', 'moscato dasti', 'port'],
#                  'pairingText': 'Dessert works really well with Cream Sherry, '
#                                 "Moscato d'Asti, and Port. A common wine "
#                                 'pairing rule is to make sure your wine is '
#                                 'sweeter than your food. Delicate desserts go '
#                                 "well with Moscato d'Asti, nutty desserts with "
#                                 'cream sherry, and caramel or chocolate '
#                                 'desserts pair well with port. The NV Johnson '
#                                 'Estate Cream Sherry with a 5 out of 5 star '
#                                 'rating seems like a good match. It costs '
#                                 'about 19 dollars per bottle.',
#                  'productMatches': [{'averageRating': 1.0,
#                                      'description': 'Very aromatic with notes '
#                                                     'of hazelnut, vanilla, and '
#                                                     'a touch of oak followed '
#                                                     'by sweet raisins and a '
#                                                     'touch of yeast. Clean '
#                                                     'lasting finish. Good now '
#                                                     'but will reward those '
#                                                     'allow it to age"". A '
#                                                     'favorite pre-prandial '
#                                                     'beverage. Consider it '
#                                                     'with nuts before dinner '
#                                                     'as an aperitif, or after '
#                                                     'dinner with dessert, '
#                                                     'especially chocolates and '
#                                                     'fruit-based desserts. '
#                                                     'Also wonderful on cold '
#                                                     'afternoons, served with '
#                                                     'biscotti to dip in '
#                                                     '""Italian-style"". "',
#                                      'id': 430626,
#                                      'imageUrl': 'https://spoonacular.com/productImages/430626-312x231.jpg',
#                                      'link': 'https://www.amazon.com/Johnson-Estate-Cream-Sherry-750/dp/B00D3GQSRW?tag=spoonacular-20',
#                                      'price': '$19.49',
#                                      'ratingCount': 2.0,
#                                      'score': 0.8571428571428572,
#                                      'title': 'NV Johnson Estate Cream '
#                                               'Sherry'}]}}

# %%
random_num = [random.randrange(1,200000,1) for i in range(5)]
random_num
# Out:
# [7374, 33567, 167943, 188701, 96618]

# %%
# ingredients = list(range(len(response['nutrition']['ingredients'])))
# ingredients

# for i in ingredients:
#     names = response['nutrition']['ingredients'][i]['name']
#     print(names)

# Extract desired data from the stored json response 
summary = response['summary']
title = response['title']
prepTime = response['readyInMinutes']
image = response['image']
pairedWine = response['winePairing']['pairedWines']
pairingDesc = response['winePairing']['pairingText']
id_number = response['id']
serving = response['servings']
likes = response['aggregateLikes']
sourceurl = response['sourceUrl']
nutrition = response['nutrition']['caloricBreakdown']
nutrition

# food_names = response['nutrition']['ingredients'][i for i in ingredients]['name']
# Out:
# {'percentProtein': 9.34, 'percentFat': 22.48, 'percentCarbs': 68.18}

# %%
url_base = f"https://api.spoonacular.com/recipes/"
url_tail = "/information?includeNutrition=true"
key = f"&apiKey={api_key}"

for num in random_num:
    params = f'{num}'

    response = s.get(url_base + params + url_tail + key).json()

# %%
# create empty dataframe to collect dish pairings from list of wines 
columns = ['Recipe_ID']
recipe_df = pd.DataFrame(columns=columns)
recipe_df
# dish_pairing_df['wine'] = wine_selections
# dish_pairing_df
# Out:
# Empty DataFrame
# Columns: [Recipe_ID]
# Index: []

# %%
recipe_num= [random.randrange(1,200000,1) for i in range(5)]
recipe_num
# Out:
# [159879, 119451, 90994, 16486, 63567]

# %%
recipe_df['Recipe_ID'] = recipe_num
recipe_df
# Out:
#    Recipe_ID
# 0     159879
# 1     119451
# 2      90994
# 3      16486
# 4      63567

# %%
recipe_df['Spoon_ID'] = ''
recipe_df['Title'] = ''
recipe_df['PrepTime'] = ''
recipe_df['Summary'] = ''
recipe_df['CaloricBreakdown'] = ''
recipe_df['Servings'] = ''
recipe_df['Likes'] = ''
recipe_df['SourceURL'] = ''
recipe_df['ImageURL'] = ''
recipe_df['WinePairing'] = ''
recipe_df['WineDescription'] = ''
recipe_df
# Out:
#    Recipe_ID Spoon_ID Title PrepTime Summary CaloricBreakdown Servings Likes  \
# 0     159879
# 1     119451
# 2      90994
# 3      16486
# 4      63567
#
#   SourceURL ImageURL WinePairing WineDescription
# 0
# 1
# 2
# 3
# 4

# %%
url_base = f"https://api.spoonacular.com/recipes/"
url_tail = "/information?includeNutrition=true"
key = f"&apiKey={api_key}"

# recipe_query = f"{url_base}{meal_id}{recipe_url_tail}&apiKey={key}"

s = requests.Session()
# response = s.get(recipe_query).json()
# response

# %%
columns = ["Spoon_ID","Title","PrepTime","Summary","CaloricBreakdown","Servings","Likes","SourceURL","ImageURL","WinePairing","WineDescription"]
nutrition = []
recipe_df = pd.DataFrame(columns=columns)

recipe_df["Recipe_ID"]=recipe_num

for index, row in recipe_df.iterrows():
    meal_id = row['Recipe_ID']
    params = f'{meal_id}'

    response = s.get(url_base + params + url_tail + key).json()  
    if response.status_code=200:
        recipe_data=response.json()
    
    try:
        recipe_df.at[index,"Spoon_ID"] = response['id'] 
        recipe_df.at[index,"Title"] = response['title']
        recipe_df.at[index,"PrepTime"] = response['readyInMinutes']
        recipe_df.at[index,"Summary"] = response['summary']
        recipe_df.at[index,"CaloricBreakdown"] = response['nutrition']['caloricBreakdown']
        recipe_df.at[index,"Servings"] = response['servings']
        recipe_df.at[index,"Likes"] = response['aggregateLikes']
        recipe_df.at[index,"SourceURL"] = response['sourceURL']
        recipe_df.at[index,"ImageURL"] = response['image']
        recipe_df.at[index,"WinePairing"] = response['winePairing']['pairedWines']
        recipe_df.at[index,"WineDescription"] = response['winePairing']['pairingText']
        nutrition.append(response['nutrition']['caloricBreakdown'])

    except (KeyError, IndexError, ValueError):
        recipe_df.at[index,"Spoon_ID"] = "ID does not exist"
        recipe_df.at[index,"Title"] = "no title available"
        recipe_df.at[index,"PrepTime"] = "no prep time available"
        recipe_df.at[index,"Summary"] = "no summary avaialble"
        recipe_df.at[index,"CaloricBreakdown"] = "no calorie information available"
        recipe_df.at[index,"Servings"] = "no servings available"
        recipe_df.at[index,"Likes"] = "noone likes this dish"
        recipe_df.at[index,"SourceURL"] = "no source URL available"
        recipe_df.at[index,"ImageURL"] = "no image URL available"
        recipe_df.at[index,"WinePairing"] = "no wine pairing available"
        recipe_df.at[index,"WineDescription"] = "no wine description available"

# %%
recipe_df
# Out:
#             Spoon_ID               Title                PrepTime  \
# 0  ID does not exist  no title available  no prep time available
# 1  ID does not exist  no title available  no prep time available
# 2  ID does not exist  no title available  no prep time available
# 3  ID does not exist  no title available  no prep time available
# 4  ID does not exist  no title available  no prep time available
#
#                 Summary                  CaloricBreakdown  \
# 0  no summary avaialble  no calorie information available
# 1  no summary avaialble  no calorie information available
# 2  no summary avaialble  no calorie information available
# 3  no summary avaialble  no calorie information available
# 4  no summary avaialble  no calorie information available
#
#                 Servings                  Likes                SourceURL  \
# 0  no servings available  noone likes this dish  no source URL available
# 1  no servings available  noone likes this dish  no source URL available
# 2  no servings available  noone likes this dish  no source URL available
# 3  no servings available  noone likes this dish  no source URL available
# 4  no servings available  noone likes this dish  no source URL available
#
#                  ImageURL                WinePairing  \
# 0  no image URL available  no wine pairing available
# 1  no image URL available  no wine pairing available
# 2  no image URL available  no wine pairing available
# 3  no image URL available  no wine pairing available
# 4  no image URL available  no wine pairing available
#
#                  WineDescription  Recipe_ID
# 0  no wine description available     159879
# 1  no wine description available     119451
# 2  no wine description available      90994
# 3  no wine description available      16486
# 4  no wine description available      63567

# %%
recipe_df['CaloricBreakdown'] = nutrition
recipe_df
# Out:
#    Recipe_ID Spoon_ID                              Title PrepTime  \
# 0     159879   159879  Celery Root and Mushroom Stuffing      120
# 1     119451   119451     Chicken Soup with Matzoh Balls       45
# 2      90994    90994        Crispy Butterscotch Cookies       45
# 3      16486    16486                   Easter Lamb Soup       45
# 4      63567    63567         Skinny Red Velvet Cupcakes       45
#
#                                              Summary  \
# 0  Need a <b>gluten free, primal, and vegetarian ...
# 1  Chicken Soup with Matzoh Balls is a <b>dairy f...
# 2  Crispy Butterscotch Cookies might be just the ...
# 3  You can never have too many soup recipes, so g...
# 4  Skinny Red Velvet Cupcakes might be just the d...
#
#                                     CaloricBreakdown Servings Likes SourceURL  \
# 0  {'percentProtein': 7.47, 'percentFat': 66.83, ...
# 1  {'percentProtein': 15.12, 'percentFat': 42.2, ...
# 2  {'percentProtein': 3.31, 'percentFat': 30.5, '...
# 3  {'percentProtein': 6.14, 'percentFat': 72.65, ...
# 4  {'percentProtein': 9.34, 'percentFat': 22.48, ...
#
#   ImageURL WinePairing WineDescription
# 0
# 1
# 2
# 3
# 4

# %%
data = []
import numpy as np
# Recipe Dataframe Components
rec_data_comps = ['id', 'title', 'readyInMinutes', 'nutrition>caloricBreakdown']
def rec_comp_check(comp, recipe_data):
    try:
        comp_path = comp.split(">")
        for c in comp_path:
            recipe_data = recipe_data[c]
        datum = recipe_data
    except:
        datum = np.nan
    return datum
for num in recipe_num: # may need to fix what you iterate over
    params = f'{num}'
    response = s.get(url_base + params + url_tail + key)
    if response.status_code == 200:
        recipe_data = response.json()
        my_big_dict ={"My ID": num}
        for comp in rec_data_comps:
            my_big_dict[comp] = rec_comp_check(comp, recipe_data)
        data.append(my_big_dict)
    else:
        print(f'{meal_id} failed to return a good API response')
        print(response)
pd.DataFrame(data)
# Out:
#     My ID      id                              title  readyInMinutes  \
# 0  159879  159879  Celery Root and Mushroom Stuffing             120
# 1  119451  119451     Chicken Soup with Matzoh Balls              45
# 2   90994   90994        Crispy Butterscotch Cookies              45
# 3   16486   16486                   Easter Lamb Soup              45
# 4   63567   63567         Skinny Red Velvet Cupcakes              45
#
#                           nutrition>caloricBreakdown
# 0  {'percentProtein': 7.47, 'percentFat': 66.83, ...
# 1  {'percentProtein': 15.12, 'percentFat': 42.2, ...
# 2  {'percentProtein': 3.31, 'percentFat': 30.5, '...
# 3  {'percentProtein': 6.14, 'percentFat': 72.65, ...
# 4  {'percentProtein': 9.34, 'percentFat': 22.48, ...

# %%
data
# Out:
# [{'My ID': 159879,
#   'id': 159879,
#   'title': 'Celery Root and Mushroom Stuffing',
#   'readyInMinutes': 120,
#   'nutrition>caloricBreakdown': {'percentProtein': 7.47,
#    'percentFat': 66.83,
#    'percentCarbs': 25.7}},
#  {'My ID': 119451,
#   'id': 119451,
#   'title': 'Chicken Soup with Matzoh Balls',
#   'readyInMinutes': 45,
#   'nutrition>caloricBreakdown': {'percentProtein': 15.12,
#    'percentFat': 42.2,
#    'percentCarbs': 42.68}},
#  {'My ID': 90994,
#   'id': 90994,
#   'title': 'Crispy Butterscotch Cookies',
#   'readyInMinutes': 45,
#   'nutrition>caloricBreakdown': {'percentProtein': 3.31,
#    'percentFat': 30.5,
#    'percentCarbs': 66.19}},
#  {'My ID': 16486,
#   'id': 16486,
#   'title': 'Easter Lamb Soup',
#   'readyInMinutes': 45,
#   'nutrition>caloricBreakdown': {'percentProtein': 6.14,
#    'percentFat': 72.65,
#    'percentCarbs': 21.21}},
#  {'My ID': 63567,
#   'id': 63567,
#   'title': 'Skinny Red Velvet Cupcakes',
#   'readyInMinutes': 45,
#   'nutrition>caloricBreakdown': {'percentProtein': 9.34,
#    'percentFat': 22.48,
#    'percentCarbs': 68.18}}]

# %%
data2 = []

for num in recipe_num: # may need to fix what you iterate over
    params = f'{num}'
    response = s.get(url_base + params + url_tail + key)
    if response.status_code == 200:
        recipe_data = response.json()
        
        data2.append(recipe_data)
pd.DataFrame(data2)
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True  False        True      False        False  False        False
# 1       False  False       False       True        False  False        False
# 2       False  False       False      False        False  False        False
# 3        True  False        True       True        False  False        False
# 4       False  False       False      False        False  False         True
#
#    sustainable  weightWatcherSmartPoints gaps  ...  \
# 0        False                         4   no  ...
# 1        False                         9   no  ...
# 2        False                         3   no  ...
# 3        False                         5   no  ...
# 4        False                         4   no  ...
#
#                                            nutrition  \
# 0  {'nutrients': [{'title': 'Calories', 'amount':...
# 1  {'nutrients': [{'title': 'Calories', 'amount':...
# 2  {'nutrients': [{'title': 'Calories', 'amount':...
# 3  {'nutrients': [{'title': 'Calories', 'amount':...
# 4  {'nutrients': [{'title': 'Calories', 'amount':...
#
#                                              summary    cuisines  \
# 0  Need a <b>gluten free, primal, and vegetarian ...          []
# 1  Chicken Soup with Matzoh Balls is a <b>dairy f...          []
# 2  Crispy Butterscotch Cookies might be just the ...          []
# 3  You can never have too many soup recipes, so g...          []
# 4  Skinny Red Velvet Cupcakes might be just the d...  [American]
#
#                                            dishTypes  \
# 0                                        [side dish]
# 1                                             [soup]
# 2  [antipasti, starter, snack, appetizer, antipas...
# 3                                             [soup]
# 4  [antipasti, starter, snack, appetizer, antipas...
#
#                                                diets               occasions  \
# 0        [gluten free, lacto ovo vegetarian, primal]          [thanksgiving]
# 1                                       [dairy free]          [fall, winter]
# 2                                                 []                      []
# 3  [gluten free, dairy free, paleolithic, lacto o...  [fall, winter, easter]
# 4                                                 []       [valentine's day]
#
#                                          winePairing  \
# 0                                                 {}
# 1                                                 {}
# 2                                                 {}
# 3                                                 {}
# 4  {'pairedWines': [], 'pairingText': '', 'produc...
#
#                                         instructions  \
# 0  Heat the oven to 350°F and arrange a rack in t...
# 1  Preparation                                   ...
# 2  In large bowl, cream butter or margarine and s...
# 3  Preparation                                   ...
# 4  Preheat oven to 350. Line cupcake tins with li...
#
#                                 analyzedInstructions originalId
# 0  [{'name': '', 'steps': [{'number': 1, 'step': ...       None
# 1  [{'name': '', 'steps': [{'number': 1, 'step': ...       None
# 2  [{'name': '', 'steps': [{'number': 1, 'step': ...       None
# 3  [{'name': '', 'steps': [{'number': 1, 'step': ...       None
# 4  [{'name': '', 'steps': [{'number': 1, 'step': ...       None
#
# [5 rows x 35 columns]

# %%
data2
# Out:
# [{'vegetarian': True,
#   'vegan': False,
#   'glutenFree': True,
#   'dairyFree': False,
#   'veryHealthy': False,
#   'cheap': False,
#   'veryPopular': False,
#   'sustainable': False,
#   'weightWatcherSmartPoints': 4,
#   'gaps': 'no',
#   'lowFodmap': False,
#   'aggregateLikes': 0,
#   'spoonacularScore': 32.0,
#   'healthScore': 6.0,
#   'creditsText': 'Chow',
#   'sourceName': 'Chow',
#   'pricePerServing': 110.53,
#   'extendedIngredients': [{'id': 1006615,
#     'aisle': 'Canned and Jarred',
#     'image': 'chicken-broth.png',
#     'consistency': 'liquid',
#     'name': 'broth',
#     'original': '2 cups mushroom broth',
#     'originalString': '2 cups mushroom broth',
#     'originalName': 'mushroom broth',
#     'amount': 2.0,
#     'unit': 'cups',
#     'meta': [],
#     'metaInformation': [],
#     'measures': {'us': {'amount': 2.0,
#       'unitShort': 'cups',
#       'unitLong': 'cups'},
#      'metric': {'amount': 473.176,
#       'unitShort': 'ml',
#       'unitLong': 'milliliters'}}},
#    {'id': 11141,
#     'aisle': 'Produce',
#     'image': 'celeriac.jpg',
#     'consistency': 'solid',
#     'name': 'celery root',
#     'original': '1 medium celery root, also known as celeriac (about 1 pound)',
#     'originalString': '1 medium celery root, also known as celeriac (about 1 pound)',
#     'originalName': 'medium celery root, also known as celeriac (about',
#     'amount': 1.0,
#     'unit': 'pound',
#     'meta': [],
#     'metaInformation': [],
#     'measures': {'us': {'amount': 1.0, 'unitShort': 'lb', 'unitLong': 'pound'},
#      'metric': {'amount': 453.592, 'unitShort': 'g', 'unitLong': 'grams'}}},
#    {'id': 11266,
#     'aisle': 'Produce',
#     'image': 'mushrooms.png',
#     'consistency': 'solid',
#     'name': 'cremini mushrooms',
#     'original': '8 ounces cremini mushrooms, stems trimmed and cut into quarters',
#     'originalString': '8 ounces cremini mushrooms, stems trimmed and cut into quarters',
#     'originalName': 'cremini mushrooms, stems trimmed and cut into quarters',
#     'amount': 8.0,
#     'unit': 'ounces',
#     'meta': ['trimmed', 'cut into quarters'],
#     'metaInformation': ['trimmed', 'cut into quarters'],
#     'measures': {'us': {'amount': 8.0,
#       'unitShort': 'oz',
#       'unitLong': 'ounces'},
#      'metric': {'amount': 226.796, 'unitShort': 'g', 'unitLong': 'grams'}}},
#    {'id': 14106,
#     'aisle': 'Alcoholic Beverages',
#     'image': 'white-wine.jpg',
#     'consistency': 'liquid',
#     'name': 'dry white wine',
#     'original': '1/4 cup dry white wine',
#     'originalString': '1/4 cup dry white wine',
#     'originalName': 'dry white wine',
#     'amount': 0.25,
#     'unit': 'cup',
#     'meta': ['dry white'],
#     'metaInformation': ['dry white'],
#     'measures': {'us': {'amount': 0.25,
#       'unitShort': 'cups',
#       'unitLong': 'cups'},
#      'metric': {'amount': 59.147,
#       'unitShort': 'ml',
#       'unitLong': 'milliliters'}}},
#    {'id': 1123,
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'image': 'egg.png',
#     'consistency': 'solid',
#     'name': 'egg',
#     'original': '1 large egg, lightly beaten',
#     'originalString': '1 large egg, lightly beaten',
#     'originalName': 'egg, lightly beaten',
#     'amount': 1.0,
#     'unit': 'large',
#     'meta': ['lightly beaten'],
#     'metaInformation': ['lightly beaten'],
#     'measures': {'us': {'amount': 1.0,
#       'unitShort': 'large',
#       'unitLong': 'large'},
#      'metric': {'amount': 1.0, 'unitShort': 'large', 'unitLong': 'large'}}},
#    {'id': 99226,
#     'aisle': 'Produce',
#     'image': 'fresh-sage.png',
#     'consistency': 'solid',
#     'name': 'fresh sage leaves',
#     'original': '1 tablespoon finely chopped fresh sage leaves',
#     'originalString': '1 tablespoon finely chopped fresh sage leaves',
#     'originalName': 'finely chopped fresh sage leaves',
#     'amount': 1.0,
#     'unit': 'tablespoon',
#     'meta': ['fresh', 'finely chopped'],
#     'metaInformation': ['fresh', 'finely chopped'],
#     'measures': {'us': {'amount': 1.0,
#       'unitShort': 'Tbsp',
#       'unitLong': 'Tbsp'},
#      'metric': {'amount': 1.0, 'unitShort': 'Tbsp', 'unitLong': 'Tbsp'}}},
#    {'id': 2049,
#     'aisle': 'Produce',
#     'image': 'thyme.jpg',
#     'consistency': 'solid',
#     'name': 'fresh thyme leaves',
#     'original': '2 teaspoons finely chopped fresh thyme leaves',
#     'originalString': '2 teaspoons finely chopped fresh thyme leaves',
#     'originalName': 'finely chopped fresh thyme leaves',
#     'amount': 2.0,
#     'unit': 'teaspoons',
#     'meta': ['fresh', 'finely chopped'],
#     'metaInformation': ['fresh', 'finely chopped'],
#     'measures': {'us': {'amount': 2.0,
#       'unitShort': 'tsps',
#       'unitLong': 'teaspoons'},
#      'metric': {'amount': 2.0, 'unitShort': 'tsps', 'unitLong': 'teaspoons'}}},
#    {'id': 4053,
#     'aisle': 'Oil, Vinegar, Salad Dressing',
#     'image': 'olive-oil.jpg',
#     'consistency': 'liquid',
#     'name': 'olive oil',
#     'original': '3 tablespoons olive oil',
#     'originalString': '3 tablespoons olive oil',
#     'originalName': 'olive oil',
#     'amount': 3.0,
#     'unit': 'tablespoons',
#     'meta': [],
#     'metaInformation': [],
#     'measures': {'us': {'amount': 3.0,
#       'unitShort': 'Tbsps',
#       'unitLong': 'Tbsps'},
#      'metric': {'amount': 3.0, 'unitShort': 'Tbsps', 'unitLong': 'Tbsps'}}},
#    {'id': 1145,
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'image': 'butter-sliced.jpg',
#     'consistency': 'solid',
#     'name': 'unsalted butter',
#     'original': '3 tablespoons unsalted butter, plus more for coating the dish',
#     'originalString': '3 tablespoons unsalted butter, plus more for coating the dish',
#     'originalName': 'unsalted butter, plus more for coating the dish',
#     'amount': 3.0,
#     'unit': 'tablespoons',
#     'meta': ['unsalted', 'plus more for coating the dish'],
#     'metaInformation': ['unsalted', 'plus more for coating the dish'],
#     'measures': {'us': {'amount': 3.0,
#       'unitShort': 'Tbsps',
#       'unitLong': 'Tbsps'},
#      'metric': {'amount': 3.0, 'unitShort': 'Tbsps', 'unitLong': 'Tbsps'}}},
#    {'id': 10511282,
#     'aisle': 'Produce',
#     'image': 'brown-onion.png',
#     'consistency': 'solid',
#     'name': 'yellow onion',
#     'original': '1 medium yellow onion, cut into 1/2-inch cubes',
#     'originalString': '1 medium yellow onion, cut into 1/2-inch cubes',
#     'originalName': 'yellow onion, cut into 1/2-inch cubes',
#     'amount': 1.0,
#     'unit': 'medium',
#     'meta': ['yellow', 'cut into 1/2-inch cubes'],
#     'metaInformation': ['yellow', 'cut into 1/2-inch cubes'],
#     'measures': {'us': {'amount': 1.0,
#       'unitShort': 'medium',
#       'unitLong': 'medium'},
#      'metric': {'amount': 1.0, 'unitShort': 'medium', 'unitLong': 'medium'}}},
#    {'id': None,
#     'aisle': '?',
#     'image': None,
#     'consistency': None,
#     'name': 'batard',
#     'original': '1 loaf sweet batard (about 1 pound), cut into 1-inch cubes',
#     'originalString': '1 loaf sweet batard (about 1 pound), cut into 1-inch cubes',
#     'originalName': 'loaf sweet batard (about , cut into 1-inch cubes',
#     'amount': 1.0,
#     'unit': 'pound',
#     'meta': ['sweet', 'cut into 1-inch cubes'],
#     'metaInformation': ['sweet', 'cut into 1-inch cubes'],
#     'measures': {'us': {'amount': 1.0, 'unitShort': 'lb', 'unitLong': 'pound'},
#      'metric': {'amount': 453.592, 'unitShort': 'g', 'unitLong': 'grams'}}}],
#   'id': 159879,
#   'title': 'Celery Root and Mushroom Stuffing',
#   'readyInMinutes': 120,
#   'servings': 8,
#   'sourceUrl': 'http://www.chow.com/recipes/28904-celery-root-and-mushroom-stuffing',
#   'image': 'https://spoonacular.com/recipeImages/159879-556x370.jpg',
#   'imageType': 'jpg',
#   'nutrition': {'nutrients': [{'title': 'Calories',
#      'amount': 139.22,
#      'unit': 'cal',
#      'percentOfDailyNeeds': 6.96},
#     {'title': 'Fat',
#      'amount': 10.36,
#      'unit': 'g',
#      'percentOfDailyNeeds': 15.94},
#     {'title': 'Saturated Fat',
#      'amount': 3.7,
#      'unit': 'g',
#      'percentOfDailyNeeds': 23.09},
#     {'title': 'Carbohydrates',
#      'amount': 8.96,
#      'unit': 'g',
#      'percentOfDailyNeeds': 2.99},
#     {'title': 'Net Carbohydrates',
#      'amount': 7.42,
#      'unit': 'g',
#      'percentOfDailyNeeds': 2.7},
#     {'title': 'Sugar',
#      'amount': 2.58,
#      'unit': 'g',
#      'percentOfDailyNeeds': 2.86},
#     {'title': 'Cholesterol',
#      'amount': 34.54,
#      'unit': 'mg',
#      'percentOfDailyNeeds': 11.51},
#     {'title': 'Sodium',
#      'amount': 303.96,
#      'unit': 'mg',
#      'percentOfDailyNeeds': 13.22},
#     {'title': 'Alcohol',
#      'amount': 0.77,
#      'unit': 'g',
#      'percentOfDailyNeeds': 4.29},
#     {'title': 'Protein',
#      'amount': 2.6,
#      'unit': 'g',
#      'percentOfDailyNeeds': 5.21},
#     {'title': 'Copper',
#      'amount': 2.47,
#      'unit': 'mg',
#      'percentOfDailyNeeds': 123.44},
#     {'title': 'Vitamin K',
#      'amount': 26.88,
#      'unit': 'µg',
#      'percentOfDailyNeeds': 25.6},
#     {'title': 'Selenium',
#      'amount': 9.82,
#      'unit': 'µg',
#      'percentOfDailyNeeds': 14.02},
#     {'title': 'Vitamin B2',
#      'amount': 0.21,
#      'unit': 'mg',
#      'percentOfDailyNeeds': 12.44},
#     {'title': 'Manganese',
#      'amount': 0.24,
#      'unit': 'mg',
#      'percentOfDailyNeeds': 12.08},
#     {'title': 'Phosphorus',
#      'amount': 119.0,
#      'unit': 'mg',
#      'percentOfDailyNeeds': 11.9},
#     {'title': 'Potassium',
#      'amount': 338.68,
#      'unit': 'mg',
#      'percentOfDailyNeeds': 9.68},
#     {'title': 'Vitamin B6',
#      'amount': 0.16,
#      'unit': 'mg',
#      'percentOfDailyNeeds': 7.88},
#     {'title': 'Vitamin C',
#      'amount': 6.35,
#      'unit': 'mg',
#      'percentOfDailyNeeds': 7.7},
#     {'title': 'Vitamin E',
#      'amount': 1.15,
#      'unit': 'mg',
#      'percentOfDailyNeeds': 7.67},
#     {'title': 'Vitamin B3',
#      'amount': 1.51,
#      'unit': 'mg',
#      'percentOfDailyNeeds': 7.57},
#     {'title': 'Vitamin B5',
#      'amount': 0.75,
#      'unit': 'mg',
#      'percentOfDailyNeeds': 7.49},
#     {'title': 'Vitamin A',
#      'amount': 314.12,
#      'unit': 'IU',
#      'percentOfDailyNeeds': 6.28},
#     {'title': 'Fiber',
#      'amount': 1.55,
#      'unit': 'g',
#      'percentOfDailyNeeds': 6.19},
#     {'title': 'Iron',
#      'amount': 0.87,
#      'unit': 'mg',
#      'percentOfDailyNeeds': 4.84},
#     {'title': 'Magnesium',
#      'amount': 18.95,
#      'unit': 'mg',
#      'percentOfDailyNeeds': 4.74},
#     {'title': 'Calcium',
#      'amount': 45.08,
#      'unit': 'mg',
#      'percentOfDailyNeeds': 4.51},
#     {'title': 'Vitamin B1',
#      'amount': 0.07,
#      'unit': 'mg',
#      'percentOfDailyNeeds': 4.48},
#     {'title': 'Folate',
#      'amount': 17.63,
#      'unit': 'µg',
#      'percentOfDailyNeeds': 4.41},
#     {'title': 'Zinc',
#      'amount': 0.64,
#      'unit': 'mg',
#      'percentOfDailyNeeds': 4.27},
#     {'title': 'Vitamin D',
#      'amount': 0.23,
#      'unit': 'µg',
#      'percentOfDailyNeeds': 1.55},
#     {'title': 'Vitamin B12',
#      'amount': 0.09,
#      'unit': 'µg',
#      'percentOfDailyNeeds': 1.55}],
#    'properties': [{'title': 'Glycemic Index', 'amount': 20.88, 'unit': ''},
#     {'title': 'Glycemic Load', 'amount': 2.14, 'unit': ''}],
#    'ingredients': [{'name': 'broth',
#      'amount': 0.25,
#      'unit': 'cups',
#      'nutrients': [{'name': 'Sodium', 'amount': 235.0, 'unit': 'mg'},
#       {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Calories', 'amount': 2.94, 'unit': 'cal'},
#       {'name': 'Calcium', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Iron', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Carbohydrates', 'amount': 0.75, 'unit': 'g'},
#       {'name': 'Vitamin A', 'amount': 125.14, 'unit': 'IU'},
#       {'name': 'Trans Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Net Carbohydrates', 'amount': 0.75, 'unit': 'g'},
#       {'name': 'Sugar', 'amount': 0.5, 'unit': 'g'}]},
#     {'name': 'celery root',
#      'amount': 0.13,
#      'unit': 'pound',
#      'nutrients': [{'name': 'Sodium', 'amount': 56.7, 'unit': 'mg'},
#       {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin E', 'amount': 0.2, 'unit': 'mg'},
#       {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Magnesium', 'amount': 11.34, 'unit': 'mg'},
#       {'name': 'Folate', 'amount': 4.54, 'unit': 'µg'},
#       {'name': 'Fiber', 'amount': 1.02, 'unit': 'g'},
#       {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin C', 'amount': 4.54, 'unit': 'mg'},
#       {'name': 'Copper', 'amount': 0.04, 'unit': 'mg'},
#       {'name': 'Carbohydrates', 'amount': 5.22, 'unit': 'g'},
#       {'name': 'Vitamin K', 'amount': 23.25, 'unit': 'µg'},
#       {'name': 'Vitamin B6', 'amount': 0.09, 'unit': 'mg'},
#       {'name': 'Net Carbohydrates', 'amount': 4.2, 'unit': 'g'},
#       {'name': 'Vitamin B1', 'amount': 0.03, 'unit': 'mg'},
#       {'name': 'Vitamin B2', 'amount': 0.03, 'unit': 'mg'},
#       {'name': 'Vitamin B3', 'amount': 0.4, 'unit': 'mg'},
#       {'name': 'Vitamin B5', 'amount': 0.2, 'unit': 'mg'},
#       {'name': 'Choline', 'amount': 5.1, 'unit': 'mg'},
#       {'name': 'Protein', 'amount': 0.85, 'unit': 'g'},
#       {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Calories', 'amount': 23.81, 'unit': 'cal'},
#       {'name': 'Calcium', 'amount': 24.38, 'unit': 'mg'},
#       {'name': 'Iron', 'amount': 0.4, 'unit': 'mg'},
#       {'name': 'Selenium', 'amount': 0.4, 'unit': 'µg'},
#       {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Zinc', 'amount': 0.19, 'unit': 'mg'},
#       {'name': 'Saturated Fat', 'amount': 0.04, 'unit': 'g'},
#       {'name': 'Potassium', 'amount': 170.1, 'unit': 'mg'},
#       {'name': 'Mono Unsaturated Fat', 'amount': 0.03, 'unit': 'g'},
#       {'name': 'Poly Unsaturated Fat', 'amount': 0.08, 'unit': 'g'},
#       {'name': 'Fat', 'amount': 0.17, 'unit': 'g'},
#       {'name': 'Manganese', 'amount': 0.09, 'unit': 'mg'},
#       {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#       {'name': 'Sugar', 'amount': 0.91, 'unit': 'g'},
#       {'name': 'Phosphorus', 'amount': 65.2, 'unit': 'mg'}]},
#     {'name': 'cremini mushrooms',
#      'amount': 1.0,
#      'unit': 'ounces',
#      'nutrients': [{'name': 'Sodium', 'amount': 1.7, 'unit': 'mg'},
#       {'name': 'Vitamin D', 'amount': 0.03, 'unit': 'µg'},
#       {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Magnesium', 'amount': 2.55, 'unit': 'mg'},
#       {'name': 'Folate', 'amount': 7.09, 'unit': 'µg'},
#       {'name': 'Fiber', 'amount': 0.17, 'unit': 'g'},
#       {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Copper', 'amount': 0.14, 'unit': 'mg'},
#       {'name': 'Carbohydrates', 'amount': 1.22, 'unit': 'g'},
#       {'name': 'Vitamin K', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin B6', 'amount': 0.03, 'unit': 'mg'},
#       {'name': 'Net Carbohydrates', 'amount': 1.05, 'unit': 'g'},
#       {'name': 'Vitamin B1', 'amount': 0.03, 'unit': 'mg'},
#       {'name': 'Vitamin B2', 'amount': 0.14, 'unit': 'mg'},
#       {'name': 'Vitamin B3', 'amount': 1.08, 'unit': 'mg'},
#       {'name': 'Vitamin B5', 'amount': 0.43, 'unit': 'mg'},
#       {'name': 'Choline', 'amount': 6.27, 'unit': 'mg'},
#       {'name': 'Protein', 'amount': 0.71, 'unit': 'g'},
#       {'name': 'Vitamin B12', 'amount': 0.03, 'unit': 'µg'},
#       {'name': 'Calories', 'amount': 6.24, 'unit': 'cal'},
#       {'name': 'Calcium', 'amount': 5.1, 'unit': 'mg'},
#       {'name': 'Iron', 'amount': 0.11, 'unit': 'mg'},
#       {'name': 'Selenium', 'amount': 7.37, 'unit': 'µg'},
#       {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Zinc', 'amount': 0.31, 'unit': 'mg'},
#       {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Potassium', 'amount': 127.01, 'unit': 'mg'},
#       {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Poly Unsaturated Fat', 'amount': 0.01, 'unit': 'g'},
#       {'name': 'Fat', 'amount': 0.03, 'unit': 'g'},
#       {'name': 'Manganese', 'amount': 0.04, 'unit': 'mg'},
#       {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#       {'name': 'Sugar', 'amount': 0.49, 'unit': 'g'},
#       {'name': 'Phosphorus', 'amount': 34.02, 'unit': 'mg'}]},
#     {'name': 'dry white wine',
#      'amount': 0.03,
#      'unit': 'cup',
#      'nutrients': [{'name': 'Sodium', 'amount': 0.38, 'unit': 'mg'},
#       {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Alcohol', 'amount': 0.77, 'unit': 'g'},
#       {'name': 'Magnesium', 'amount': 0.75, 'unit': 'mg'},
#       {'name': 'Folate', 'amount': 0.08, 'unit': 'µg'},
#       {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Carbohydrates', 'amount': 0.2, 'unit': 'g'},
#       {'name': 'Vitamin K', 'amount': 0.03, 'unit': 'µg'},
#       {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Net Carbohydrates', 'amount': 0.2, 'unit': 'g'},
#       {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B3', 'amount': 0.01, 'unit': 'mg'},
#       {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Choline', 'amount': 0.32, 'unit': 'mg'},
#       {'name': 'Protein', 'amount': 0.01, 'unit': 'g'},
#       {'name': 'Fluoride', 'amount': 15.15, 'unit': 'mg'},
#       {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Calories', 'amount': 6.15, 'unit': 'cal'},
#       {'name': 'Calcium', 'amount': 0.68, 'unit': 'mg'},
#       {'name': 'Iron', 'amount': 0.02, 'unit': 'mg'},
#       {'name': 'Selenium', 'amount': 0.01, 'unit': 'µg'},
#       {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Zinc', 'amount': 0.01, 'unit': 'mg'},
#       {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Potassium', 'amount': 5.33, 'unit': 'mg'},
#       {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Manganese', 'amount': 0.01, 'unit': 'mg'},
#       {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#       {'name': 'Sugar', 'amount': 0.07, 'unit': 'g'},
#       {'name': 'Phosphorus', 'amount': 1.35, 'unit': 'mg'}]},
#     {'name': 'egg',
#      'amount': 0.13,
#      'unit': 'large',
#      'nutrients': [{'name': 'Sodium', 'amount': 8.88, 'unit': 'mg'},
#       {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin D', 'amount': 0.13, 'unit': 'µg'},
#       {'name': 'Vitamin E', 'amount': 0.07, 'unit': 'mg'},
#       {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Magnesium', 'amount': 0.75, 'unit': 'mg'},
#       {'name': 'Folate', 'amount': 2.94, 'unit': 'µg'},
#       {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Carbohydrates', 'amount': 0.05, 'unit': 'g'},
#       {'name': 'Vitamin K', 'amount': 0.02, 'unit': 'µg'},
#       {'name': 'Vitamin B6', 'amount': 0.01, 'unit': 'mg'},
#       {'name': 'Net Carbohydrates', 'amount': 0.05, 'unit': 'g'},
#       {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B2', 'amount': 0.03, 'unit': 'mg'},
#       {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B5', 'amount': 0.1, 'unit': 'mg'},
#       {'name': 'Choline', 'amount': 18.36, 'unit': 'mg'},
#       {'name': 'Protein', 'amount': 0.79, 'unit': 'g'},
#       {'name': 'Fluoride', 'amount': 0.07, 'unit': 'mg'},
#       {'name': 'Vitamin B12', 'amount': 0.06, 'unit': 'µg'},
#       {'name': 'Calories', 'amount': 8.94, 'unit': 'cal'},
#       {'name': 'Calcium', 'amount': 3.5, 'unit': 'mg'},
#       {'name': 'Iron', 'amount': 0.11, 'unit': 'mg'},
#       {'name': 'Selenium', 'amount': 1.92, 'unit': 'µg'},
#       {'name': 'Cholesterol', 'amount': 23.25, 'unit': 'mg'},
#       {'name': 'Zinc', 'amount': 0.08, 'unit': 'mg'},
#       {'name': 'Saturated Fat', 'amount': 0.2, 'unit': 'g'},
#       {'name': 'Potassium', 'amount': 8.63, 'unit': 'mg'},
#       {'name': 'Mono Unsaturated Fat', 'amount': 0.23, 'unit': 'g'},
#       {'name': 'Poly Unsaturated Fat', 'amount': 0.12, 'unit': 'g'},
#       {'name': 'Fat', 'amount': 0.59, 'unit': 'g'},
#       {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin A', 'amount': 33.75, 'unit': 'IU'},
#       {'name': 'Trans Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Sugar', 'amount': 0.02, 'unit': 'g'},
#       {'name': 'Phosphorus', 'amount': 12.38, 'unit': 'mg'}]},
#     {'name': 'fresh sage leaves',
#      'amount': 0.13,
#      'unit': 'tablespoon',
#      'nutrients': [{'name': 'Sodium', 'amount': 0.04, 'unit': 'mg'},
#       {'name': 'Protein', 'amount': 0.03, 'unit': 'g'},
#       {'name': 'Magnesium', 'amount': 1.28, 'unit': 'mg'},
#       {'name': 'Fluoride', 'amount': 1.2, 'unit': 'mg'},
#       {'name': 'Fiber', 'amount': 0.05, 'unit': 'g'},
#       {'name': 'Calories', 'amount': 1.09, 'unit': 'cal'},
#       {'name': 'Calcium', 'amount': 4.92, 'unit': 'mg'},
#       {'name': 'Iron', 'amount': 0.08, 'unit': 'mg'},
#       {'name': 'Copper', 'amount': 2.27, 'unit': 'mg'},
#       {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Zinc', 'amount': 0.01, 'unit': 'mg'},
#       {'name': 'Saturated Fat', 'amount': 0.02, 'unit': 'g'},
#       {'name': 'Potassium', 'amount': 3.2, 'unit': 'mg'},
#       {'name': 'Mono Unsaturated Fat', 'amount': 0.01, 'unit': 'g'},
#       {'name': 'Poly Unsaturated Fat', 'amount': 0.01, 'unit': 'g'},
#       {'name': 'Fat', 'amount': 0.04, 'unit': 'g'},
#       {'name': 'Carbohydrates', 'amount': 0.13, 'unit': 'g'},
#       {'name': 'Manganese', 'amount': 0.07, 'unit': 'mg'},
#       {'name': 'Net Carbohydrates', 'amount': 0.07, 'unit': 'g'},
#       {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Phosphorus', 'amount': 0.28, 'unit': 'mg'},
#       {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'}]},
#     {'name': 'fresh thyme leaves',
#      'amount': 0.25,
#      'unit': 'teaspoons',
#      'nutrients': [{'name': 'Sodium', 'amount': 0.05, 'unit': 'mg'},
#       {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Magnesium', 'amount': 0.8, 'unit': 'mg'},
#       {'name': 'Folate', 'amount': 0.23, 'unit': 'µg'},
#       {'name': 'Fiber', 'amount': 0.07, 'unit': 'g'},
#       {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin C', 'amount': 0.8, 'unit': 'mg'},
#       {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Carbohydrates', 'amount': 0.12, 'unit': 'g'},
#       {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Net Carbohydrates', 'amount': 0.05, 'unit': 'g'},
#       {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B3', 'amount': 0.01, 'unit': 'mg'},
#       {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Protein', 'amount': 0.03, 'unit': 'g'},
#       {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Calories', 'amount': 0.51, 'unit': 'cal'},
#       {'name': 'Calcium', 'amount': 2.03, 'unit': 'mg'},
#       {'name': 'Iron', 'amount': 0.09, 'unit': 'mg'},
#       {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Zinc', 'amount': 0.01, 'unit': 'mg'},
#       {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Potassium', 'amount': 3.05, 'unit': 'mg'},
#       {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Fat', 'amount': 0.01, 'unit': 'g'},
#       {'name': 'Manganese', 'amount': 0.01, 'unit': 'mg'},
#       {'name': 'Vitamin A', 'amount': 23.76, 'unit': 'IU'},
#       {'name': 'Phosphorus', 'amount': 0.53, 'unit': 'mg'}]},
#     {'name': 'olive oil',
#      'amount': 0.38,
#      'unit': 'tablespoons',
#      'nutrients': [{'name': 'Sodium', 'amount': 0.11, 'unit': 'mg'},
#       {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin E', 'amount': 0.75, 'unit': 'mg'},
#       {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Magnesium', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Folate', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Vitamin K', 'amount': 3.16, 'unit': 'µg'},
#       {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Net Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Choline', 'amount': 0.02, 'unit': 'mg'},
#       {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Calories', 'amount': 46.41, 'unit': 'cal'},
#       {'name': 'Calcium', 'amount': 0.05, 'unit': 'mg'},
#       {'name': 'Iron', 'amount': 0.03, 'unit': 'mg'},
#       {'name': 'Selenium', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Saturated Fat', 'amount': 0.72, 'unit': 'g'},
#       {'name': 'Potassium', 'amount': 0.05, 'unit': 'mg'},
#       {'name': 'Mono Unsaturated Fat', 'amount': 3.83, 'unit': 'g'},
#       {'name': 'Poly Unsaturated Fat', 'amount': 0.55, 'unit': 'g'},
#       {'name': 'Fat', 'amount': 5.25, 'unit': 'g'},
#       {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#       {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Phosphorus', 'amount': 0.0, 'unit': 'mg'}]},
#     {'name': 'unsalted butter',
#      'amount': 0.38,
#      'unit': 'tablespoons',
#      'nutrients': [{'name': 'Sodium', 'amount': 0.58, 'unit': 'mg'},
#       {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin D', 'amount': 0.08, 'unit': 'µg'},
#       {'name': 'Vitamin E', 'amount': 0.12, 'unit': 'mg'},
#       {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Magnesium', 'amount': 0.11, 'unit': 'mg'},
#       {'name': 'Folate', 'amount': 0.16, 'unit': 'µg'},
#       {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Vitamin K', 'amount': 0.37, 'unit': 'µg'},
#       {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Net Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B5', 'amount': 0.01, 'unit': 'mg'},
#       {'name': 'Choline', 'amount': 0.99, 'unit': 'mg'},
#       {'name': 'Protein', 'amount': 0.04, 'unit': 'g'},
#       {'name': 'Fluoride', 'amount': 0.15, 'unit': 'mg'},
#       {'name': 'Vitamin B12', 'amount': 0.01, 'unit': 'µg'},
#       {'name': 'Calories', 'amount': 37.64, 'unit': 'cal'},
#       {'name': 'Calcium', 'amount': 1.26, 'unit': 'mg'},
#       {'name': 'Iron', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Selenium', 'amount': 0.05, 'unit': 'µg'},
#       {'name': 'Cholesterol', 'amount': 11.29, 'unit': 'mg'},
#       {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Saturated Fat', 'amount': 2.7, 'unit': 'g'},
#       {'name': 'Potassium', 'amount': 1.26, 'unit': 'mg'},
#       {'name': 'Mono Unsaturated Fat', 'amount': 1.1, 'unit': 'g'},
#       {'name': 'Poly Unsaturated Fat', 'amount': 0.16, 'unit': 'g'},
#       {'name': 'Fat', 'amount': 4.26, 'unit': 'g'},
#       {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin A', 'amount': 131.2, 'unit': 'IU'},
#       {'name': 'Trans Fat', 'amount': 0.17, 'unit': 'g'},
#       {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Phosphorus', 'amount': 1.26, 'unit': 'mg'}]},
#     {'name': 'yellow onion',
#      'amount': 0.13,
#      'unit': 'medium',
#      'nutrients': [{'name': 'Sodium', 'amount': 0.55, 'unit': 'mg'},
#       {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Magnesium', 'amount': 1.38, 'unit': 'mg'},
#       {'name': 'Folate', 'amount': 2.61, 'unit': 'µg'},
#       {'name': 'Fiber', 'amount': 0.23, 'unit': 'g'},
#       {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin C', 'amount': 1.02, 'unit': 'mg'},
#       {'name': 'Copper', 'amount': 0.01, 'unit': 'mg'},
#       {'name': 'Carbohydrates', 'amount': 1.28, 'unit': 'g'},
#       {'name': 'Vitamin K', 'amount': 0.06, 'unit': 'µg'},
#       {'name': 'Vitamin B6', 'amount': 0.02, 'unit': 'mg'},
#       {'name': 'Net Carbohydrates', 'amount': 1.05, 'unit': 'g'},
#       {'name': 'Vitamin B1', 'amount': 0.01, 'unit': 'mg'},
#       {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B3', 'amount': 0.02, 'unit': 'mg'},
#       {'name': 'Vitamin B5', 'amount': 0.02, 'unit': 'mg'},
#       {'name': 'Choline', 'amount': 0.84, 'unit': 'mg'},
#       {'name': 'Protein', 'amount': 0.15, 'unit': 'g'},
#       {'name': 'Fluoride', 'amount': 0.15, 'unit': 'mg'},
#       {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Calories', 'amount': 5.5, 'unit': 'cal'},
#       {'name': 'Calcium', 'amount': 3.16, 'unit': 'mg'},
#       {'name': 'Iron', 'amount': 0.03, 'unit': 'mg'},
#       {'name': 'Selenium', 'amount': 0.07, 'unit': 'µg'},
#       {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Zinc', 'amount': 0.02, 'unit': 'mg'},
#       {'name': 'Saturated Fat', 'amount': 0.01, 'unit': 'g'},
#       {'name': 'Potassium', 'amount': 20.08, 'unit': 'mg'},
#       {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Fat', 'amount': 0.01, 'unit': 'g'},
#       {'name': 'Manganese', 'amount': 0.02, 'unit': 'mg'},
#       {'name': 'Vitamin A', 'amount': 0.28, 'unit': 'IU'},
#       {'name': 'Sugar', 'amount': 0.58, 'unit': 'g'},
#       {'name': 'Phosphorus', 'amount': 3.99, 'unit': 'mg'}]}],
#    'caloricBreakdown': {'percentProtein': 7.47,
#     'percentFat': 66.83,
#     'percentCarbs': 25.7},
#    'weightPerServing': {'amount': 184, 'unit': 'g'}},
#   'summary': 'Need a <b>gluten free, primal, and vegetarian side dish</b>? Celery Root and Mushroom Stuffing could be a tremendous recipe to try. One portion of this dish contains about <b>3g of protein</b>, <b>10g of fat</b>, and a total of <b>138 calories</b>. For <b>$1.03 per serving</b>, this recipe <b>covers 7%</b> of your daily requirements of vitamins and minerals. This recipe serves 8. It can be enjoyed any time, but it is especially good for <b>Thanksgiving</b>. This recipe is liked by 1 foodies and cooks. Head to the store and pick up batard, mushroom broth, cremini mushrooms, and a few other things to make it today. From preparation to the plate, this recipe takes around <b>2 hours</b>. All things considered, we decided this recipe <b>deserves a spoonacular score of 24%</b>. This score is not so amazing. Try <a href="https://spoonacular.com/recipes/leek-celery-root-stuffing-94606">Leek-Celery Root Stuffing</a>, <a href="https://spoonacular.com/recipes/celery-root-persimmon-and-swiss-chard-stuffing-20355">Celery Root, Persimmon, And Swiss Chard "stuffing</a>, and <a href="https://spoonacular.com/recipes/cornish-hens-with-plum-and-leek-stuffing-and-celery-root-12400">Cornish Hens with Plum-and-Leek Stuffing and Celery Root</a> for similar recipes.',
#   'cuisines': [],
#   'dishTypes': ['side dish'],
#   'diets': ['gluten free', 'lacto ovo vegetarian', 'primal'],
#   'occasions': ['thanksgiving'],
#   'winePairing': {},
#   'instructions': 'Heat the oven to 350°F and arrange a rack in the middle. Coat a 9-by-13-inch baking dish with butter; set aside.Spread bread cubes in a single layer on a baking sheet and toast until dry and lightly browned, about 15 minutes. Remove from the oven, let cool slightly, and transfer to a large bowl; set aside.Meanwhile, heat 1 tablespoon of the oil in a large frying pan over medium-high heat until shimmering. Add mushrooms and cook, stirring rarely, until browned, about 6 minutes. Remove from heat and transfer to the bowl with the bread cubes; set aside.Using a vegetable peeler, peel celery root and cut into 1/2-inch cubes. (Peel and cut the celery root at the last minute, because it will oxidize when exposed to air.) Return the frying pan to medium heat and add butter and remaining 2 tablespoons oil. When butter has melted, add celery root, onion, sage, and thyme and season generously with salt and pepper. Cook, stirring occasionally, until onion just begins to soften, about 6 to 8 minutes. Transfer vegetables to the bowl of bread cubes and mushrooms.Evenly drizzle wine around the bowl, add egg, and stir to evenly coat bread cubes and vegetables. Drizzle half of the mushroom broth over the mixture and stir to evenly combine. Drizzle in the remaining broth and stir until all bread cubes are evenly moistened. Season with additional salt and pepper as needed.Transfer stuffing to the prepared baking dish, slightly compacting it. Cover with foil and bake for 30 minutes. Remove foil and continue to bake until bread cubes on top are crispy and browned, about 30 minutes more.',
#   'analyzedInstructions': [{'name': '',
#     'steps': [{'number': 1,
#       'step': 'Heat the oven to 350°F and arrange a rack in the middle. Coat a 9-by-13-inch baking dish with butter; set aside.',
#       'ingredients': [{'id': 1001,
#         'name': 'butter',
#         'localizedName': 'butter',
#         'image': 'butter-sliced.jpg'}],
#       'equipment': [{'id': 404646,
#         'name': 'baking pan',
#         'localizedName': 'baking pan',
#         'image': 'roasting-pan.jpg'},
#        {'id': 404784,
#         'name': 'oven',
#         'localizedName': 'oven',
#         'image': 'oven.jpg',
#         'temperature': {'number': 350.0, 'unit': 'Fahrenheit'}}]},
#      {'number': 2,
#       'step': 'Spread bread cubes in a single layer on a baking sheet and toast until dry and lightly browned, about 15 minutes.',
#       'ingredients': [{'id': 10018064,
#         'name': 'bread cubes',
#         'localizedName': 'bread cubes',
#         'image': 'croutons.png'},
#        {'id': 0, 'name': 'spread', 'localizedName': 'spread', 'image': ''},
#        {'id': 18070,
#         'name': 'toast',
#         'localizedName': 'toast',
#         'image': 'toast'}],
#       'equipment': [{'id': 404727,
#         'name': 'baking sheet',
#         'localizedName': 'baking sheet',
#         'image': 'baking-sheet.jpg'}],
#       'length': {'number': 15, 'unit': 'minutes'}},
#      {'number': 3,
#       'step': 'Remove from the oven, let cool slightly, and transfer to a large bowl; set aside.Meanwhile, heat 1 tablespoon of the oil in a large frying pan over medium-high heat until shimmering.',
#       'ingredients': [{'id': 4582,
#         'name': 'cooking oil',
#         'localizedName': 'cooking oil',
#         'image': 'vegetable-oil.jpg'}],
#       'equipment': [{'id': 404645,
#         'name': 'frying pan',
#         'localizedName': 'frying pan',
#         'image': 'pan.png'},
#        {'id': 404783,
#         'name': 'bowl',
#         'localizedName': 'bowl',
#         'image': 'bowl.jpg'},
#        {'id': 404784,
#         'name': 'oven',
#         'localizedName': 'oven',
#         'image': 'oven.jpg'}]},
#      {'number': 4,
#       'step': 'Add mushrooms and cook, stirring rarely, until browned, about 6 minutes.',
#       'ingredients': [{'id': 11260,
#         'name': 'mushrooms',
#         'localizedName': 'mushrooms',
#         'image': 'mushrooms.png'}],
#       'equipment': [],
#       'length': {'number': 6, 'unit': 'minutes'}},
#      {'number': 5,
#       'step': 'Remove from heat and transfer to the bowl with the bread cubes; set aside.Using a vegetable peeler, peel celery root and cut into 1/2-inch cubes. (Peel and cut the celery root at the last minute, because it will oxidize when exposed to air.) Return the frying pan to medium heat and add butter and remaining 2 tablespoons oil. When butter has melted, add celery root, onion, sage, and thyme and season generously with salt and pepper. Cook, stirring occasionally, until onion just begins to soften, about 6 to 8 minutes.',
#       'ingredients': [{'id': 1102047,
#         'name': 'salt and pepper',
#         'localizedName': 'salt and pepper',
#         'image': 'salt-and-pepper.jpg'},
#        {'id': 10018064,
#         'name': 'bread cubes',
#         'localizedName': 'bread cubes',
#         'image': 'croutons.png'},
#        {'id': 11141,
#         'name': 'celeriac',
#         'localizedName': 'celeriac',
#         'image': 'celeriac.jpg'},
#        {'id': 11583,
#         'name': 'vegetable',
#         'localizedName': 'vegetable',
#         'image': 'mixed-vegetables.png'},
#        {'id': 1001,
#         'name': 'butter',
#         'localizedName': 'butter',
#         'image': 'butter-sliced.jpg'},
#        {'id': 11282,
#         'name': 'onion',
#         'localizedName': 'onion',
#         'image': 'brown-onion.png'},
#        {'id': 2049,
#         'name': 'thyme',
#         'localizedName': 'thyme',
#         'image': 'thyme.jpg'},
#        {'id': 99226,
#         'name': 'sage',
#         'localizedName': 'sage',
#         'image': 'fresh-sage.png'},
#        {'id': 4582,
#         'name': 'cooking oil',
#         'localizedName': 'cooking oil',
#         'image': 'vegetable-oil.jpg'}],
#       'equipment': [{'id': 404693,
#         'name': 'peeler',
#         'localizedName': 'peeler',
#         'image': 'peeler.png'},
#        {'id': 404645,
#         'name': 'frying pan',
#         'localizedName': 'frying pan',
#         'image': 'pan.png'},
#        {'id': 404783,
#         'name': 'bowl',
#         'localizedName': 'bowl',
#         'image': 'bowl.jpg'}],
#       'length': {'number': 6, 'unit': 'minutes'}},
#      {'number': 6,
#       'step': 'Transfer vegetables to the bowl of bread cubes and mushrooms.Evenly drizzle wine around the bowl, add egg, and stir to evenly coat bread cubes and vegetables.',
#       'ingredients': [{'id': 10018064,
#         'name': 'bread cubes',
#         'localizedName': 'bread cubes',
#         'image': 'croutons.png'},
#        {'id': 11583,
#         'name': 'vegetable',
#         'localizedName': 'vegetable',
#         'image': 'mixed-vegetables.png'},
#        {'id': 11260,
#         'name': 'mushrooms',
#         'localizedName': 'mushrooms',
#         'image': 'mushrooms.png'},
#        {'id': 14084,
#         'name': 'wine',
#         'localizedName': 'wine',
#         'image': 'red-wine.jpg'},
#        {'id': 1123,
#         'name': 'egg',
#         'localizedName': 'egg',
#         'image': 'egg.png'}],
#       'equipment': [{'id': 404783,
#         'name': 'bowl',
#         'localizedName': 'bowl',
#         'image': 'bowl.jpg'}]},
#      {'number': 7,
#       'step': 'Drizzle half of the mushroom broth over the mixture and stir to evenly combine.',
#       'ingredients': [{'id': 11260,
#         'name': 'mushrooms',
#         'localizedName': 'mushrooms',
#         'image': 'mushrooms.png'},
#        {'id': 1006615,
#         'name': 'broth',
#         'localizedName': 'broth',
#         'image': 'chicken-broth.png'}],
#       'equipment': []},
#      {'number': 8,
#       'step': 'Drizzle in the remaining broth and stir until all bread cubes are evenly moistened. Season with additional salt and pepper as needed.',
#       'ingredients': [{'id': 1102047,
#         'name': 'salt and pepper',
#         'localizedName': 'salt and pepper',
#         'image': 'salt-and-pepper.jpg'},
#        {'id': 10018064,
#         'name': 'bread cubes',
#         'localizedName': 'bread cubes',
#         'image': 'croutons.png'},
#        {'id': 1006615,
#         'name': 'broth',
#         'localizedName': 'broth',
#         'image': 'chicken-broth.png'}],
#       'equipment': []},
#      {'number': 9,
#       'step': 'Transfer stuffing to the prepared baking dish, slightly compacting it. Cover with foil and bake for 30 minutes.',
#       'ingredients': [{'id': 18082,
#         'name': 'stuffing',
#         'localizedName': 'stuffing',
#         'image': 'stuffing-mix.png'}],
#       'equipment': [{'id': 404646,
#         'name': 'baking pan',
#         'localizedName': 'baking pan',
#         'image': 'roasting-pan.jpg'},
#        {'id': 404784,
#         'name': 'oven',
#         'localizedName': 'oven',
#         'image': 'oven.jpg'},
#        {'id': 404765,
#         'name': 'aluminum foil',
#         'localizedName': 'aluminum foil',
#         'image': 'aluminum-foil.png'}],
#       'length': {'number': 30, 'unit': 'minutes'}},
#      {'number': 10,
#       'step': 'Remove foil and continue to bake until bread cubes on top are crispy and browned, about 30 minutes more.',
#       'ingredients': [{'id': 10018064,
#         'name': 'bread cubes',
#         'localizedName': 'bread cubes',
#         'image': 'croutons.png'}],
#       'equipment': [{'id': 404784,
#         'name': 'oven',
#         'localizedName': 'oven',
#         'image': 'oven.jpg'},
#        {'id': 404765,
#         'name': 'aluminum foil',
#         'localizedName': 'aluminum foil',
#         'image': 'aluminum-foil.png'}],
#       'length': {'number': 30, 'unit': 'minutes'}}]}],
#   'originalId': None},
#  {'vegetarian': False,
#   'vegan': False,
#   'glutenFree': False,
#   'dairyFree': True,
#   'veryHealthy': False,
#   'cheap': False,
#   'veryPopular': False,
#   'sustainable': False,
#   'weightWatcherSmartPoints': 9,
#   'gaps': 'no',
#   'lowFodmap': False,
#   'aggregateLikes': 0,
#   'spoonacularScore': 43.0,
#   'healthScore': 10.0,
#   'creditsText': 'Epicurious',
#   'sourceName': 'Epicurious',
#   'pricePerServing': 130.52,
#   'extendedIngredients': [{'id': 1002030,
#     'aisle': 'Spices and Seasonings',
#     'image': 'pepper.jpg',
#     'consistency': 'solid',
#     'name': 'black pepper',
#     'original': '1/2 teaspoon freshly ground black pepper',
#     'originalString': '1/2 teaspoon freshly ground black pepper',
#     'originalName': 'freshly ground black pepper',
#     'amount': 0.5,
#     'unit': 'teaspoon',
#     'meta': ['black', 'freshly ground'],
#     'metaInformation': ['black', 'freshly ground'],
#     'measures': {'us': {'amount': 0.5,
#       'unitShort': 'tsps',
#       'unitLong': 'teaspoons'},
#      'metric': {'amount': 0.5, 'unitShort': 'tsps', 'unitLong': 'teaspoons'}}},
#    {'id': 11124,
#     'aisle': 'Produce',
#     'image': 'sliced-carrot.png',
#     'consistency': 'solid',
#     'name': 'carrots',
#     'original': '4 carrots, peeled and cut into chunks',
#     'originalString': '4 carrots, peeled and cut into chunks',
#     'originalName': 'carrots, peeled and cut into chunks',
#     'amount': 4.0,
#     'unit': '',
#     'meta': ['peeled', 'cut into chunks'],
#     'metaInformation': ['peeled', 'cut into chunks'],
#     'measures': {'us': {'amount': 4.0, 'unitShort': '', 'unitLong': ''},
#      'metric': {'amount': 4.0, 'unitShort': '', 'unitLong': ''}}},
#    {'id': 6172,
#     'aisle': 'Canned and Jarred',
#     'image': 'chicken-broth.png',
#     'consistency': 'liquid',
#     'name': 'chicken stock',
#     'original': '6 to 9 cups good chicken stock',
#     'originalString': '6 to 9 cups good chicken stock',
#     'originalName': 'good chicken stock',
#     'amount': 6.0,
#     'unit': 'cups',
#     'meta': ['good'],
#     'metaInformation': ['good'],
#     'measures': {'us': {'amount': 6.0,
#       'unitShort': 'cups',
#       'unitLong': 'cups'},
#      'metric': {'amount': 1.42, 'unitShort': 'l', 'unitLong': 'liters'}}},
#    {'id': 1123,
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'image': 'egg.png',
#     'consistency': 'solid',
#     'name': 'eggs',
#     'original': '3 eggs',
#     'originalString': '3 eggs',
#     'originalName': 'eggs',
#     'amount': 3.0,
#     'unit': '',
#     'meta': [],
#     'metaInformation': [],
#     'measures': {'us': {'amount': 3.0, 'unitShort': '', 'unitLong': ''},
#      'metric': {'amount': 3.0, 'unitShort': '', 'unitLong': ''}}},
#    {'id': 11297,
#     'aisle': 'Produce;Spices and Seasonings',
#     'image': 'parsley.jpg',
#     'consistency': 'solid',
#     'name': 'fresh parsley leaves',
#     'original': 'Chopped fresh parsley leaves for garnish',
#     'originalString': 'Chopped fresh parsley leaves for garnish',
#     'originalName': 'Chopped fresh parsley for garnish',
#     'amount': 1.0,
#     'unit': 'leaves',
#     'meta': ['fresh', 'chopped', 'for garnish'],
#     'metaInformation': ['fresh', 'chopped', 'for garnish'],
#     'measures': {'us': {'amount': 1.0,
#       'unitShort': 'leaf',
#       'unitLong': 'leave'},
#      'metric': {'amount': 1.0, 'unitShort': 'leaf', 'unitLong': 'leave'}}},
#    {'id': 18217,
#     'aisle': 'Ethnic Foods;Baking',
#     'image': 'matzo.jpg',
#     'consistency': 'solid',
#     'name': 'matzoh meal',
#     'original': '1 cup matzoh meal, approximately',
#     'originalString': '1 cup matzoh meal, approximately',
#     'originalName': 'matzoh meal, approximately',
#     'amount': 1.0,
#     'unit': 'cup',
#     'meta': [],
#     'metaInformation': [],
#     'measures': {'us': {'amount': 1.0, 'unitShort': 'cup', 'unitLong': 'cup'},
#      'metric': {'amount': 236.588,
#       'unitShort': 'ml',
#       'unitLong': 'milliliters'}}},
#    {'id': 4053,
#     'aisle': 'Oil, Vinegar, Salad Dressing',
#     'image': 'olive-oil.jpg',
#     'consistency': 'liquid',
#     'name': 'olive oil',
#     'original': '1/4 cup melted rendered chicken fat or canola or extra-virgin olive oil',
#     'originalString': '1/4 cup melted rendered chicken fat or canola or extra-virgin olive oil',
#     'originalName': 'melted rendered chicken fat or canola or extra-virgin olive oil',
#     'amount': 0.25,
#     'unit': 'cup',
#     'meta': ['extra-virgin', 'melted'],
#     'metaInformation': ['extra-virgin', 'melted'],
#     'measures': {'us': {'amount': 0.25,
#       'unitShort': 'cups',
#       'unitLong': 'cups'},
#      'metric': {'amount': 59.147,
#       'unitShort': 'ml',
#       'unitLong': 'milliliters'}}},
#    {'id': 11282,
#     'aisle': 'Produce',
#     'image': 'brown-onion.png',
#     'consistency': 'solid',
#     'name': 'onion',
#     'original': '1/4 cup minced or grated onion',
#     'originalString': '1/4 cup minced or grated onion',
#     'originalName': 'minced or grated onion',
#     'amount': 0.25,
#     'unit': 'cup',
#     'meta': ['minced', 'grated'],
#     'metaInformation': ['minced', 'grated'],
#     'measures': {'us': {'amount': 0.25,
#       'unitShort': 'cups',
#       'unitLong': 'cups'},
#      'metric': {'amount': 59.147,
#       'unitShort': 'ml',
#       'unitLong': 'milliliters'}}},
#    {'id': 2047,
#     'aisle': 'Spices and Seasonings',
#     'image': 'salt.jpg',
#     'consistency': 'solid',
#     'name': 'salt',
#     'original': '1/2 teaspoon salt',
#     'originalString': '1/2 teaspoon salt',
#     'originalName': 'salt',
#     'amount': 0.5,
#     'unit': 'teaspoon',
#     'meta': [],
#     'metaInformation': [],
#     'measures': {'us': {'amount': 0.5,
#       'unitShort': 'tsps',
#       'unitLong': 'teaspoons'},
#      'metric': {'amount': 0.5,
#       'unitShort': 'tsps',
#       'unitLong': 'teaspoons'}}}],
#   'id': 119451,
#   'title': 'Chicken Soup with Matzoh Balls',
#   'readyInMinutes': 45,
#   'servings': 6,
#   'sourceUrl': 'http://www.epicurious.com/recipes/food/views/Chicken-Soup-with-Matzoh-Balls-237828',
# ...
#       {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Choline', 'amount': 0.1, 'unit': 'mg'},
#       {'name': 'Protein', 'amount': 0.01, 'unit': 'g'},
#       {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Calories', 'amount': 1.97, 'unit': 'cal'},
#       {'name': 'Calcium', 'amount': 0.19, 'unit': 'mg'},
#       {'name': 'Iron', 'amount': 0.01, 'unit': 'mg'},
#       {'name': 'Selenium', 'amount': 0.01, 'unit': 'µg'},
#       {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Potassium', 'amount': 3.47, 'unit': 'mg'},
#       {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin A', 'amount': 1.36, 'unit': 'IU'},
#       {'name': 'Sugar', 'amount': 0.44, 'unit': 'g'},
#       {'name': 'Phosphorus', 'amount': 0.23, 'unit': 'mg'}]},
#     {'name': 'vanilla',
#      'amount': 0.08,
#      'unit': 'tsp',
#      'nutrients': [{'name': 'Sodium', 'amount': 0.03, 'unit': 'mg'},
#       {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Alcohol', 'amount': 0.11, 'unit': 'g'},
#       {'name': 'Magnesium', 'amount': 0.04, 'unit': 'mg'},
#       {'name': 'Folate', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Carbohydrates', 'amount': 0.04, 'unit': 'g'},
#       {'name': 'Vitamin K', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Net Carbohydrates', 'amount': 0.04, 'unit': 'g'},
#       {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Calories', 'amount': 0.93, 'unit': 'cal'},
#       {'name': 'Calcium', 'amount': 0.04, 'unit': 'mg'},
#       {'name': 'Iron', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Selenium', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Potassium', 'amount': 0.48, 'unit': 'mg'},
#       {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#       {'name': 'Sugar', 'amount': 0.04, 'unit': 'g'},
#       {'name': 'Phosphorus', 'amount': 0.02, 'unit': 'mg'}]},
#     {'name': 'white vinegar',
#      'amount': 0.04,
#      'unit': 'tsp',
#      'nutrients': [{'name': 'Sodium', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Magnesium', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Folate', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Vitamin K', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Net Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Choline', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Calories', 'amount': 0.03, 'unit': 'cal'},
#       {'name': 'Calcium', 'amount': 0.01, 'unit': 'mg'},
#       {'name': 'Iron', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Selenium', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Potassium', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#       {'name': 'Trans Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Phosphorus', 'amount': 0.01, 'unit': 'mg'}]},
#     {'name': 'white whole wheat flour',
#      'amount': 0.04,
#      'unit': 'cup',
#      'nutrients': [{'name': 'Sodium', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Magnesium', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Folate', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Fiber', 'amount': 0.46, 'unit': 'g'},
#       {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Carbohydrates', 'amount': 3.23, 'unit': 'g'},
#       {'name': 'Vitamin K', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Net Carbohydrates', 'amount': 2.77, 'unit': 'g'},
#       {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Protein', 'amount': 0.62, 'unit': 'g'},
#       {'name': 'Fluoride', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Calories', 'amount': 15.37, 'unit': 'cal'},
#       {'name': 'Calcium', 'amount': 3.08, 'unit': 'mg'},
#       {'name': 'Iron', 'amount': 0.11, 'unit': 'mg'},
#       {'name': 'Selenium', 'amount': 0.0, 'unit': 'µg'},
#       {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Potassium', 'amount': 5.08, 'unit': 'mg'},
#       {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Fat', 'amount': 0.08, 'unit': 'g'},
#       {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#       {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#       {'name': 'Trans Fat', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#       {'name': 'Phosphorus', 'amount': 0.0, 'unit': 'mg'}]}],
#    'caloricBreakdown': {'percentProtein': 9.34,
#     'percentFat': 22.48,
#     'percentCarbs': 68.18},
#    'weightPerServing': {'amount': 45, 'unit': 'g'}},
#   'summary': 'Skinny Red Velvet Cupcakes might be just the dessert you are searching for. This recipe makes 26 servings with <b>102 calories</b>, <b>2g of protein</b>, and <b>3g of fat</b> each. For <b>25 cents per serving</b>, this recipe <b>covers 2%</b> of your daily requirements of vitamins and minerals. 666 people were impressed by this recipe. It can be enjoyed any time, but it is especially good for <b>valentin day</b>. From preparation to the plate, this recipe takes around <b>45 minutes</b>. Many people really liked this American dish. A mixture of egg, food coloring, sugar, and a handful of other ingredients are all it takes to make this recipe so scrumptious. All things considered, we decided this recipe <b>deserves a spoonacular score of 12%</b>. This score is not so excellent. Try <a href="https://spoonacular.com/recipes/skinny-mini-red-velvet-cupcakes-485151">Skinny Mini Red Velvet Cupcakes</a>, <a href="https://spoonacular.com/recipes/red-velvet-cake-roll-912616">Red Velvet Cake Roll</a>, and <a href="https://spoonacular.com/recipes/red-velvet-cupcakes-with-white-chocolate-frosting-red-velvet-week-474841">Red Velvet Cupcakes with White Chocolate Frosting {Red Velvet Week}</a> for similar recipes.',
#   'cuisines': ['American'],
#   'dishTypes': ['antipasti',
#    'starter',
#    'snack',
#    'appetizer',
#    'antipasto',
#    "hor d'oeuvre"],
#   'diets': [],
#   'occasions': ["valentine's day"],
#   'winePairing': {'pairedWines': [], 'pairingText': '', 'productMatches': []},
#   'instructions': "Preheat oven to 350. Line cupcake tins with liners. In a large mixing bowl, stir together flours, salt, cocoa, and baking powder. In another large bowl beat sugar, applesauce and butter. Beat in eggs and vanilla. In a separate bowl mix baking soda and vinegar. Add half of the dry ingredients into the egg mixture, mix well. Add buttermilk, red food coloring and mix well. Add the remaining dry ingredients and fold in vinegar and baking soda. Pour in prepared cupcake liners 3/4 of the way. Bake 20-25 minutes or until a toothpick inserted comes out clean. Cool, then frost with low fat cream cheese frosting. Makes 26 cupcakes.Low Fat Cream Cheese Frosting8 oz 1/3 fat Philadelphia Cream Cheese1 cup powdered sugar1 tsp vanilla extractBeat together cream cheese, powdered sugar and vanilla until smooth.Print This4 PP 4 SP Baked Breads and Cakes Dessert Mother's Day Brunch Recipes Valentine's Day Recipesposted February 11, 2010 by Gina116 Comments",
#   'analyzedInstructions': [{'name': '',
#     'steps': [{'number': 1,
#       'step': 'Preheat oven to 35',
#       'ingredients': [],
#       'equipment': [{'id': 404784,
#         'name': 'oven',
#         'localizedName': 'oven',
#         'image': 'oven.jpg'}]},
#      {'number': 2,
#       'step': 'Line cupcake tins with liners. In a large mixing bowl, stir together flours, salt, cocoa, and baking powder. In another large bowl beat sugar, applesauce and butter. Beat in eggs and vanilla. In a separate bowl mix baking soda and vinegar.',
#       'ingredients': [{'id': 18369,
#         'name': 'baking powder',
#         'localizedName': 'baking powder',
#         'image': 'white-powder.jpg'},
#        {'id': 18372,
#         'name': 'baking soda',
#         'localizedName': 'baking soda',
#         'image': 'white-powder.jpg'},
#        {'id': 9019,
#         'name': 'applesauce',
#         'localizedName': 'applesauce',
#         'image': 'applesauce.png'},
#        {'id': 18139,
#         'name': 'cupcakes',
#         'localizedName': 'cupcakes',
#         'image': 'plain-cupcake.jpg'},
#        {'id': 1052050,
#         'name': 'vanilla',
#         'localizedName': 'vanilla',
#         'image': 'vanilla.jpg'},
#        {'id': 2053,
#         'name': 'vinegar',
#         'localizedName': 'vinegar',
#         'image': 'vinegar-(white).jpg'},
#        {'id': 1001,
#         'name': 'butter',
#         'localizedName': 'butter',
#         'image': 'butter-sliced.jpg'},
#        {'id': 19165,
#         'name': 'cocoa powder',
#         'localizedName': 'cocoa powder',
#         'image': 'cocoa-powder.png'},
#        {'id': 19335,
#         'name': 'sugar',
#         'localizedName': 'sugar',
#         'image': 'sugar-in-bowl.png'},
#        {'id': 1123, 'name': 'egg', 'localizedName': 'egg', 'image': 'egg.png'},
#        {'id': 2047,
#         'name': 'salt',
#         'localizedName': 'salt',
#         'image': 'salt.jpg'}],
#       'equipment': [{'id': 405907,
#         'name': 'mixing bowl',
#         'localizedName': 'mixing bowl',
#         'image': 'mixing-bowl.jpg'}]},
#      {'number': 3,
#       'step': 'Add half of the dry ingredients into the egg mixture, mix well.',
#       'ingredients': [{'id': 1123,
#         'name': 'egg',
#         'localizedName': 'egg',
#         'image': 'egg.png'}],
#       'equipment': []},
#      {'number': 4,
#       'step': 'Add buttermilk, red food coloring and mix well.',
#       'ingredients': [{'id': 1451111,
#         'name': 'red food color',
#         'localizedName': 'red food color',
#         'image': 'food-coloring.png'},
#        {'id': 1230,
#         'name': 'buttermilk',
#         'localizedName': 'buttermilk',
#         'image': 'buttermilk.jpg'}],
#       'equipment': []},
#      {'number': 5,
#       'step': 'Add the remaining dry ingredients and fold in vinegar and baking soda.',
#       'ingredients': [{'id': 18372,
#         'name': 'baking soda',
#         'localizedName': 'baking soda',
#         'image': 'white-powder.jpg'},
#        {'id': 2053,
#         'name': 'vinegar',
#         'localizedName': 'vinegar',
#         'image': 'vinegar-(white).jpg'}],
#       'equipment': []},
#      {'number': 6,
#       'step': 'Pour in prepared cupcake liners 3/4 of the way.',
#       'ingredients': [{'id': 18139,
#         'name': 'cupcakes',
#         'localizedName': 'cupcakes',
#         'image': 'plain-cupcake.jpg'}],
#       'equipment': [{'id': 404676,
#         'name': 'muffin liners',
#         'localizedName': 'muffin liners',
#         'image': 'muffin-or-cupcake-forms.png'}]},
#      {'number': 7,
#       'step': 'Bake 20-25 minutes or until a toothpick inserted comes out clean. Cool, then frost with low fat cream cheese frosting. Makes 26 cupcakes.Low Fat Cream Cheese Frosting8 oz 1/3 fat Philadelphia Cream Cheese1 cup powdered sugar1 tsp vanilla extract',
#       'ingredients': [{'id': 19228,
#         'name': 'cream cheese frosting',
#         'localizedName': 'cream cheese frosting',
#         'image': 'frosting-or-icing.png'},
#        {'id': 2050,
#         'name': 'vanilla extract',
#         'localizedName': 'vanilla extract',
#         'image': 'vanilla-extract.jpg'},
#        {'id': 18139,
#         'name': 'cupcakes',
#         'localizedName': 'cupcakes',
#         'image': 'plain-cupcake.jpg'},
#        {'id': 1053,
#         'name': 'cream',
#         'localizedName': 'cream',
#         'image': 'fluid-cream.jpg'}],
#       'equipment': [{'id': 404644,
#         'name': 'toothpicks',
#         'localizedName': 'toothpicks',
#         'image': 'toothpicks.jpg'},
#        {'id': 404784,
#         'name': 'oven',
#         'localizedName': 'oven',
#         'image': 'oven.jpg'}],
#       'length': {'number': 25, 'unit': 'minutes'}},
#      {'number': 8,
#       'step': 'Beat together cream cheese, powdered sugar and vanilla until smooth.Print This4 PP 4 SP',
#       'ingredients': [{'id': 19336,
#         'name': 'powdered sugar',
#         'localizedName': 'powdered sugar',
#         'image': 'powdered-sugar.jpg'},
#        {'id': 1017,
#         'name': 'cream cheese',
#         'localizedName': 'cream cheese',
#         'image': 'cream-cheese.jpg'},
#        {'id': 1052050,
#         'name': 'vanilla',
#         'localizedName': 'vanilla',
#         'image': 'vanilla.jpg'}],
#       'equipment': []},
#      {'number': 9,
#       'step': "Baked Breads and Cakes Dessert Mother's Day Brunch Recipes Valentine's Day Recipesposted February 11, 2010 by Gina116 Comments",
#       'ingredients': [],
#       'equipment': []}]}],
#   'originalId': None}]
