# %%
import json, requests
from pprint import pprint
import pandas as pd
from config import api_key
import numpy as np
import random

# %%
recipe_base = f"https://api.spoonacular.com/recipes/"
recipe_url_tail = "/information?includeNutrition=true"
# recipe_url_base =f"https://api.spoonacular.com/recipes/information?includeNutrition=true/"
recipe_id = "66135"
recipe_query = f"{recipe_base}{recipe_id}{recipe_url_tail}&apiKey={api_key}"
print(recipe_query)
# Out:
# https://api.spoonacular.com/recipes/66135/information?includeNutrition=true&apiKey=655b2ca78d0b4f769402f9bd14d4064a

# %%
s = requests.Session()
response = s.get(recipe_query).json()
# ## pretty print the response 
pprint(response)
# # response
# Out:
# {'aggregateLikes': 0,
#  'analyzedInstructions': [],
#  'cheap': False,
#  'creditsText': None,
#  'cuisines': [],
#  'dairyFree': False,
#  'diets': ['gluten free', 'lacto ovo vegetarian'],
#  'dishTypes': ['lunch', 'main course', 'main dish', 'dinner'],
#  'extendedIngredients': [{'aisle': 'Baking',
#                           'amount': 1.0,
#                           'consistency': 'solid',
#                           'id': 18371,
#                           'image': 'white-powder.jpg',
#                           'measures': {'metric': {'amount': 1.0,
#                                                   'unitLong': 'teaspoon',
#                                                   'unitShort': 'tsp'},
#                                        'us': {'amount': 1.0,
#                                               'unitLong': 'teaspoon',
#                                               'unitShort': 'tsp'}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'aluminum free baking powder',
#                           'original': '1 tsp. aluminum-free baking powder',
#                           'originalName': 'aluminum-free baking powder',
#                           'originalString': '1 tsp. aluminum-free baking '
#                                             'powder',
#                           'unit': 'tsp'},
#                          {'aisle': 'Canned and Jarred',
#                           'amount': 2.0,
#                           'consistency': 'solid',
#                           'id': 9019,
#                           'image': 'applesauce.png',
#                           'measures': {'metric': {'amount': 2.0,
#                                                   'unitLong': 'Tbsps',
#                                                   'unitShort': 'Tbsps'},
#                                        'us': {'amount': 2.0,
#                                               'unitLong': 'Tbsps',
#                                               'unitShort': 'Tbsps'}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'applesauce',
#                           'original': '2 Tbsp. applesauce (replaced 2 Tbsp. '
#                                       'butter)',
#                           'originalName': 'applesauce (replaced 2 Tbsp. '
#                                           'butter)',
#                           'originalString': '2 Tbsp. applesauce (replaced 2 '
#                                             'Tbsp. butter)',
#                           'unit': 'Tbsp'},
#                          {'aisle': 'Baking',
#                           'amount': 0.5,
#                           'consistency': 'solid',
#                           'id': 18372,
#                           'image': 'white-powder.jpg',
#                           'measures': {'metric': {'amount': 0.5,
#                                                   'unitLong': 'teaspoons',
#                                                   'unitShort': 'tsps'},
#                                        'us': {'amount': 0.5,
#                                               'unitLong': 'teaspoons',
#                                               'unitShort': 'tsps'}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'baking soda',
#                           'original': '½ tsp. baking soda',
#                           'originalName': 'baking soda',
#                           'originalString': '½ tsp. baking soda',
#                           'unit': 'tsp'},
#                          {'aisle': 'Baking',
#                           'amount': 0.5,
#                           'consistency': 'solid',
#                           'id': 19335,
#                           'image': 'sugar-in-bowl.png',
#                           'measures': {'metric': {'amount': 118.294,
#                                                   'unitLong': 'milliliters',
#                                                   'unitShort': 'ml'},
#                                        'us': {'amount': 0.5,
#                                               'unitLong': 'cups',
#                                               'unitShort': 'cups'}},
#                           'meta': ['raw',
#                                    'white',
#                                    'organic',
#                                    '(replaced 1 cup sugar)'],
#                           'metaInformation': ['raw',
#                                               'white',
#                                               'organic',
#                                               '(replaced 1 cup sugar)'],
#                           'name': 'cane sugar',
#                           'original': '½ cup organic raw cane sugar or Sucanat '
#                                       '(replaced 1 cup white sugar)',
#                           'originalName': 'organic raw cane sugar or Sucanat '
#                                           '(replaced 1 cup white sugar)',
#                           'originalString': '½ cup organic raw cane sugar or '
#                                             'Sucanat (replaced 1 cup white '
#                                             'sugar)',
#                           'unit': 'cup'},
#                          {'aisle': 'Milk, Eggs, Other Dairy',
#                           'amount': 2.0,
#                           'consistency': 'solid',
#                           'id': 1124,
#                           'image': 'egg-white.jpg',
#                           'measures': {'metric': {'amount': 2.0,
#                                                   'unitLong': '',
#                                                   'unitShort': ''},
#                                        'us': {'amount': 2.0,
#                                               'unitLong': '',
#                                               'unitShort': ''}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'egg whites',
#                           'original': '2 egg whites',
#                           'originalName': 'egg whites',
#                           'originalString': '2 egg whites',
#                           'unit': ''},
#                          {'aisle': 'Health Foods;Baking',
#                           'amount': 1.0,
#                           'consistency': 'solid',
#                           'id': 12220,
#                           'image': 'flax-seeds.png',
#                           'measures': {'metric': {'amount': 1.0,
#                                                   'unitLong': 'Tbsp',
#                                                   'unitShort': 'Tbsp'},
#                                        'us': {'amount': 1.0,
#                                               'unitLong': 'Tbsp',
#                                               'unitShort': 'Tbsp'}},
#                           'meta': ['mixed',
#                                    'with 3 tbsp. water (replaced 1 large egg)'],
#                           'metaInformation': ['mixed',
#                                               'with 3 tbsp. water (replaced 1 '
#                                               'large egg)'],
#                           'name': 'ground flax seed',
#                           'original': '1 Tbsp. ground flax seed mixed with 3 '
#                                       'Tbsp. water (replaced 1 large egg)',
#                           'originalName': 'ground flax seed mixed with 3 Tbsp. '
#                                           'water (replaced 1 large egg)',
#                           'originalString': '1 Tbsp. ground flax seed mixed '
#                                             'with 3 Tbsp. water (replaced 1 '
#                                             'large egg)',
#                           'unit': 'Tbsp'},
#                          {'aisle': 'Produce',
#                           'amount': 2.0,
#                           'consistency': 'liquid',
#                           'id': 9152,
#                           'image': 'lemon-juice.jpg',
#                           'measures': {'metric': {'amount': 2.0,
#                                                   'unitLong': 'Tbsps',
#                                                   'unitShort': 'Tbsps'},
#                                        'us': {'amount': 2.0,
#                                               'unitLong': 'Tbsps',
#                                               'unitShort': 'Tbsps'}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'lemon juice',
#                           'original': '2 Tbsp. lemon juice',
#                           'originalName': 'lemon juice',
#                           'originalString': '2 Tbsp. lemon juice',
#                           'unit': 'Tbsp'},
#                          {'aisle': 'Produce',
#                           'amount': 1.0,
#                           'consistency': 'solid',
#                           'id': 9156,
#                           'image': 'zest-lemon.jpg',
#                           'measures': {'metric': {'amount': 1.0,
#                                                   'unitLong': '',
#                                                   'unitShort': ''},
#                                        'us': {'amount': 1.0,
#                                               'unitLong': '',
#                                               'unitShort': ''}},
#                           'meta': ['organic', 'finely grated'],
#                           'metaInformation': ['organic', 'finely grated'],
#                           'name': 'lemon zest',
#                           'original': 'Finely grated zest of 1 organic lemon',
#                           'originalName': 'Finely grated zest of organic lemon',
#                           'originalString': 'Finely grated zest of 1 organic '
#                                             'lemon',
#                           'unit': ''},
#                          {'aisle': 'Cereal',
#                           'amount': 2.0,
#                           'consistency': 'liquid',
#                           'id': 19911,
#                           'image': 'maple-syrup.png',
#                           'measures': {'metric': {'amount': 2.0,
#                                                   'unitLong': 'Tbsps',
#                                                   'unitShort': 'Tbsps'},
#                                        'us': {'amount': 2.0,
#                                               'unitLong': 'Tbsps',
#                                               'unitShort': 'Tbsps'}},
#                           'meta': ['pure'],
#                           'metaInformation': ['pure'],
#                           'name': 'maple syrup',
#                           'original': '2 Tbsp. pure maple syrup',
#                           'originalName': 'pure maple syrup',
#                           'originalString': '2 Tbsp. pure maple syrup',
#                           'unit': 'Tbsp'},
#                          {'aisle': 'Produce',
#                           'amount': 1.5,
#                           'consistency': 'solid',
#                           'id': 9302,
#                           'image': 'raspberries.jpg',
#                           'measures': {'metric': {'amount': 354.882,
#                                                   'unitLong': 'milliliters',
#                                                   'unitShort': 'ml'},
#                                        'us': {'amount': 1.5,
#                                               'unitLong': 'cups',
#                                               'unitShort': 'cups'}},
#                           'meta': ['frozen', '(increased fruit by)'],
#                           'metaInformation': ['frozen', '(increased fruit by)'],
#                           'name': 'raspberries',
#                           'original': '1 ½ cups raspberries frozen; keep '
#                                       'frozen until ready to use (increased '
#                                       'fruit by ½ cup)',
#                           'originalName': 'raspberries frozen; keep frozen '
#                                           'until ready to use (increased fruit '
#                                           'by ½ cup)',
#                           'originalString': '1 ½ cups raspberries frozen; keep '
#                                             'frozen until ready to use '
#                                             '(increased fruit by ½ cup)',
#                           'unit': 'cups'},
#                          {'aisle': 'Spices and Seasonings',
#                           'amount': 0.5,
#                           'consistency': 'solid',
#                           'id': 2047,
#                           'image': 'salt.jpg',
#                           'measures': {'metric': {'amount': 0.5,
#                                                   'unitLong': 'teaspoons',
#                                                   'unitShort': 'tsps'},
#                                        'us': {'amount': 0.5,
#                                               'unitLong': 'teaspoons',
#                                               'unitShort': 'tsps'}},
#                           'meta': [],
#                           'metaInformation': [],
#                           'name': 'salt',
#                           'original': '½ tsp. salt',
#                           'originalName': 'salt',
#                           'originalString': '½ tsp. salt',
#                           'unit': 'tsp'},
#                          {'aisle': 'Milk, Eggs, Other Dairy',
#                           'amount': 3.0,
#                           'consistency': 'solid',
#                           'id': 1145,
#                           'image': 'butter-sliced.jpg',
#                           'measures': {'metric': {'amount': 3.0,
#                                                   'unitLong': 'Tbsps',
#                                                   'unitShort': 'Tbsps'},
#                                        'us': {'amount': 3.0,
#                                               'unitLong': 'Tbsps',
#                                               'unitShort': 'Tbsps'}},
#                           'meta': ['unsalted',
#                                    'organic',
#                                    'at room temperature'],
#                           'metaInformation': ['unsalted',
#                                               'organic',
#                                               'at room temperature'],
#                           'name': 'unsalted butter',
#                           'original': '3 Tbsp. unsalted organic butter at room '
#                                       'temperature',
#                           'originalName': 'unsalted organic butter at room '
#                                           'temperature',
#                           'originalString': '3 Tbsp. unsalted organic butter '
#                                             'at room temperature',
#                           'unit': 'Tbsp'},
#                          {'aisle': 'Baking',
#                           'amount': 2.0,
#                           'consistency': 'liquid',
#                           'id': 2050,
#                           'image': 'vanilla-extract.jpg',
#                           'measures': {'metric': {'amount': 2.0,
#                                                   'unitLong': 'teaspoons',
#                                                   'unitShort': 'tsps'},
#                                        'us': {'amount': 2.0,
#                                               'unitLong': 'teaspoons',
#                                               'unitShort': 'tsps'}},
#                           'meta': ['pure',
#                                    '(increased 1 tsp. vanilla to enhance '
#                                    'sweetness)'],
#                           'metaInformation': ['pure',
#                                               '(increased 1 tsp. vanilla to '
#                                               'enhance sweetness)'],
#                           'name': 'vanilla extract',
#                           'original': '2 tsp. pure vanilla extract (increased '
#                                       '1 tsp. vanilla to enhance sweetness)',
#                           'originalName': 'pure vanilla extract (increased 1 '
#                                           'tsp. vanilla to enhance sweetness)',
#                           'originalString': '2 tsp. pure vanilla extract '
#                                             '(increased 1 tsp. vanilla to '
#                                             'enhance sweetness)',
#                           'unit': 'tsp'},
#                          {'aisle': 'Milk, Eggs, Other Dairy',
#                           'amount': 1.0,
#                           'consistency': 'liquid',
#                           'id': 1119,
#                           'image': 'vanilla-yogurt.png',
#                           'measures': {'metric': {'amount': 236.588,
#                                                   'unitLong': 'milliliters',
#                                                   'unitShort': 'ml'},
#                                        'us': {'amount': 1.0,
#                                               'unitLong': 'cup',
#                                               'unitShort': 'cup'}},
#                           'meta': ['organic'],
#                           'metaInformation': ['organic'],
#                           'name': 'vanilla yogurt',
#                           'original': '1 cup organic vanilla yogurt',
#                           'originalName': 'organic vanilla yogurt',
#                           'originalString': '1 cup organic vanilla yogurt',
#                           'unit': 'cup'},
#                          {'aisle': 'Gluten Free;Health Foods',
#                           'amount': 2.25,
#                           'consistency': 'solid',
#                           'id': 20132,
#                           'image': 'brown-flour.jpg',
#                           'measures': {'metric': {'amount': 532.323,
#                                                   'unitLong': 'milliliters',
#                                                   'unitShort': 'ml'},
#                                        'us': {'amount': 2.25,
#                                               'unitLong': 'cups',
#                                               'unitShort': 'cups'}},
#                           'meta': ['whole-wheat', 'whole', 'white'],
#                           'metaInformation': ['whole-wheat', 'whole', 'white'],
#                           'name': 'whole grain oat flour',
#                           'original': '2 ¼ cups spelt, kamut, or whole grain '
#                                       'whole-wheat flour (replaced 2 ¼ cups '
#                                       'white cake flour)',
#                           'originalName': 'spelt, kamut, or whole grain '
#                                           'whole-wheat flour (replaced 2 ¼ '
#                                           'cups white cake flour)',
#                           'originalString': '2 ¼ cups spelt, kamut, or whole '
#                                             'grain whole-wheat flour (replaced '
#                                             '2 ¼ cups white cake flour)',
#                           'unit': 'cups'}],
#  'gaps': 'no',
#  'glutenFree': True,
#  'healthScore': 14.0,
#  'id': 66135,
#  'image': 'https://spoonacular.com/recipeImages/66135-556x370.jpg',
#  'imageType': 'jpg',
#  'instructions': None,
#  'lowFodmap': False,
#  'nutrition': {'caloricBreakdown': {'percentCarbs': 63.33,
#                                     'percentFat': 25.99,
#                                     'percentProtein': 10.68},
#                'ingredients': [{'amount': 0.25,
#                                 'name': 'aluminum free baking powder',
#                                 'nutrients': [{'amount': 1.13,
#                                                'name': 'Sodium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Caffeine',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin D',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin E',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Alcohol',
#                                                'unit': 'g'},
#                                               {'amount': 0.36,
#                                                'name': 'Magnesium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Folate',
#                                                'unit': 'µg'},
#                                               {'amount': 0.03,
#                                                'name': 'Fiber',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Folic Acid',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin C',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Copper',
#                                                'unit': 'mg'},
#                                               {'amount': 0.59,
#                                                'name': 'Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin K',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B6',
#                                                'unit': 'mg'},
#                                               {'amount': 0.56,
#                                                'name': 'Net Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B1',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B2',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B3',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B5',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Choline',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Protein',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B12',
#                                                'unit': 'µg'},
#                                               {'amount': 1.21,
#                                                'name': 'Calories',
#                                                'unit': 'cal'},
#                                               {'amount': 54.15,
#                                                'name': 'Calcium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.1,
#                                                'name': 'Iron',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Selenium',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Cholesterol',
#                                                'unit': 'mg'},
#                                               {'amount': 0.01,
#                                                'name': 'Zinc',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Saturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 126.25,
#                                                'name': 'Potassium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Mono Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Poly Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.01,
#                                                'name': 'Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.01,
#                                                'name': 'Manganese',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin A',
#                                                'unit': 'IU'},
#                                               {'amount': 0.0,
#                                                'name': 'Sugar',
#                                                'unit': 'g'},
#                                               {'amount': 85.86,
#                                                'name': 'Phosphorus',
#                                                'unit': 'mg'}],
#                                 'unit': 'tsp'},
#                                {'amount': 0.5,
#                                 'name': 'applesauce',
#                                 'nutrients': [{'amount': 0.15,
#                                                'name': 'Sodium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Caffeine',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin D',
#                                                'unit': 'µg'},
#                                               {'amount': 0.01,
#                                                'name': 'Vitamin E',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Alcohol',
#                                                'unit': 'g'},
#                                               {'amount': 0.23,
#                                                'name': 'Magnesium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.23,
#                                                'name': 'Folate',
#                                                'unit': 'µg'},
#                                               {'amount': 0.08,
#                                                'name': 'Fiber',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Folic Acid',
#                                                'unit': 'µg'},
#                                               {'amount': 0.08,
#                                                'name': 'Vitamin C',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Copper',
#                                                'unit': 'mg'},
#                                               {'amount': 0.85,
#                                                'name': 'Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.04,
#                                                'name': 'Vitamin K',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B6',
#                                                'unit': 'mg'},
#                                               {'amount': 0.76,
#                                                'name': 'Net Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B1',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B2',
#                                                'unit': 'mg'},
#                                               {'amount': 0.01,
#                                                'name': 'Vitamin B3',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B5',
#                                                'unit': 'mg'},
#                                               {'amount': 0.17,
#                                                'name': 'Choline',
#                                                'unit': 'mg'},
#                                               {'amount': 0.01,
#                                                'name': 'Protein',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B12',
#                                                'unit': 'µg'},
#                                               {'amount': 3.15,
#                                                'name': 'Calories',
#                                                'unit': 'cal'},
#                                               {'amount': 0.3,
#                                                'name': 'Calcium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.02,
#                                                'name': 'Iron',
#                                                'unit': 'mg'},
#                                               {'amount': 0.02,
#                                                'name': 'Selenium',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Cholesterol',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Zinc',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Saturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 5.55,
#                                                'name': 'Potassium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Mono Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Poly Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.01,
#                                                'name': 'Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Manganese',
#                                                'unit': 'mg'},
#                                               {'amount': 2.17,
#                                                'name': 'Vitamin A',
#                                                'unit': 'IU'},
#                                               {'amount': 0.7,
#                                                'name': 'Sugar',
#                                                'unit': 'g'},
#                                               {'amount': 0.38,
#                                                'name': 'Phosphorus',
#                                                'unit': 'mg'}],
#                                 'unit': 'Tbsp'},
#                                {'amount': 0.13,
#                                 'name': 'baking soda',
#                                 'nutrients': [{'amount': 157.32,
#                                                'name': 'Sodium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Caffeine',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin D',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin E',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Alcohol',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Magnesium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Folate',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Fiber',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Folic Acid',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin C',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Copper',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin K',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B6',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Net Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B1',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B2',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B3',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B5',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Choline',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Protein',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B12',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Calories',
#                                                'unit': 'cal'},
#                                               {'amount': 0.0,
#                                                'name': 'Calcium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Iron',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Selenium',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Cholesterol',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Zinc',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Saturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Potassium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Mono Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Poly Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Manganese',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin A',
#                                                'unit': 'IU'},
#                                               {'amount': 0.0,
#                                                'name': 'Sugar',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Phosphorus',
#                                                'unit': 'mg'}],
#                                 'unit': 'tsp'},
#                                {'amount': 0.13,
#                                 'name': 'cane sugar',
#                                 'nutrients': [{'amount': 0.25,
#                                                'name': 'Sodium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Caffeine',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin D',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin E',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Alcohol',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Magnesium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Folate',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Fiber',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Folic Acid',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin C',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Copper',
#                                                'unit': 'mg'},
#                                               {'amount': 25.0,
#                                                'name': 'Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin K',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B6',
#                                                'unit': 'mg'},
#                                               {'amount': 25.0,
#                                                'name': 'Net Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B1',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B2',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B3',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B5',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Choline',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Protein',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Fluoride',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B12',
#                                                'unit': 'µg'},
#                                               {'amount': 96.75,
#                                                'name': 'Calories',
#                                                'unit': 'cal'},
#                                               {'amount': 0.25,
#                                                'name': 'Calcium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.01,
#                                                'name': 'Iron',
#                                                'unit': 'mg'},
#                                               {'amount': 0.15,
#                                                'name': 'Selenium',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Cholesterol',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Zinc',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Saturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.5,
#                                                'name': 'Potassium',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Mono Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Poly Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
# ...
#                                               {'amount': 39.96,
#                                                'name': 'Net Carbohydrates',
#                                                'unit': 'g'},
#                                               {'amount': 0.47,
#                                                'name': 'Vitamin B1',
#                                                'unit': 'mg'},
#                                               {'amount': 0.08,
#                                                'name': 'Vitamin B2',
#                                                'unit': 'mg'},
#                                               {'amount': 0.99,
#                                                'name': 'Vitamin B3',
#                                                'unit': 'mg'},
#                                               {'amount': 0.14,
#                                                'name': 'Vitamin B5',
#                                                'unit': 'mg'},
#                                               {'amount': 20.18,
#                                                'name': 'Choline',
#                                                'unit': 'mg'},
#                                               {'amount': 9.9,
#                                                'name': 'Protein',
#                                                'unit': 'g'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin B12',
#                                                'unit': 'µg'},
#                                               {'amount': 272.7,
#                                                'name': 'Calories',
#                                                'unit': 'cal'},
#                                               {'amount': 37.13,
#                                                'name': 'Calcium',
#                                                'unit': 'mg'},
#                                               {'amount': 2.7,
#                                                'name': 'Iron',
#                                                'unit': 'mg'},
#                                               {'amount': 22.95,
#                                                'name': 'Selenium',
#                                                'unit': 'µg'},
#                                               {'amount': 0.0,
#                                                'name': 'Cholesterol',
#                                                'unit': 'mg'},
#                                               {'amount': 2.16,
#                                                'name': 'Zinc',
#                                                'unit': 'mg'},
#                                               {'amount': 1.08,
#                                                'name': 'Saturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 250.43,
#                                                'name': 'Potassium',
#                                                'unit': 'mg'},
#                                               {'amount': 1.93,
#                                                'name': 'Mono Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 2.25,
#                                                'name': 'Poly Unsaturated Fat',
#                                                'unit': 'g'},
#                                               {'amount': 6.16,
#                                                'name': 'Fat',
#                                                'unit': 'g'},
#                                               {'amount': 2.71,
#                                                'name': 'Manganese',
#                                                'unit': 'mg'},
#                                               {'amount': 0.0,
#                                                'name': 'Vitamin A',
#                                                'unit': 'IU'},
#                                               {'amount': 0.54,
#                                                'name': 'Sugar',
#                                                'unit': 'g'},
#                                               {'amount': 305.1,
#                                                'name': 'Phosphorus',
#                                                'unit': 'mg'}],
#                                 'unit': 'cups'}],
#                'nutrients': [{'amount': 582.59,
#                               'percentOfDailyNeeds': 29.13,
#                               'title': 'Calories',
#                               'unit': 'cal'},
#                              {'amount': 17.0,
#                               'percentOfDailyNeeds': 26.15,
#                               'title': 'Fat',
#                               'unit': 'g'},
#                              {'amount': 7.16,
#                               'percentOfDailyNeeds': 44.73,
#                               'title': 'Saturated Fat',
#                               'unit': 'g'},
#                              {'amount': 93.22,
#                               'percentOfDailyNeeds': 31.07,
#                               'title': 'Carbohydrates',
#                               'unit': 'g'},
#                              {'amount': 84.91,
#                               'percentOfDailyNeeds': 30.88,
#                               'title': 'Net Carbohydrates',
#                               'unit': 'g'},
#                              {'amount': 43.3,
#                               'percentOfDailyNeeds': 48.11,
#                               'title': 'Sugar',
#                               'unit': 'g'},
#                              {'amount': 25.96,
#                               'percentOfDailyNeeds': 8.65,
#                               'title': 'Cholesterol',
#                               'unit': 'mg'},
#                              {'amount': 531.33,
#                               'percentOfDailyNeeds': 23.1,
#                               'title': 'Sodium',
#                               'unit': 'mg'},
#                              {'amount': 0.72,
#                               'percentOfDailyNeeds': 4.01,
#                               'title': 'Alcohol',
#                               'unit': 'g'},
#                              {'amount': 15.72,
#                               'percentOfDailyNeeds': 31.43,
#                               'title': 'Protein',
#                               'unit': 'g'},
#                              {'amount': 3.33,
#                               'percentOfDailyNeeds': 166.37,
#                               'title': 'Manganese',
#                               'unit': 'mg'},
#                              {'amount': 509.32,
#                               'percentOfDailyNeeds': 50.93,
#                               'title': 'Phosphorus',
#                               'unit': 'mg'},
#                              {'amount': 30.0,
#                               'percentOfDailyNeeds': 42.85,
#                               'title': 'Selenium',
#                               'unit': 'µg'},
#                              {'amount': 0.56,
#                               'percentOfDailyNeeds': 37.48,
#                               'title': 'Vitamin B1',
#                               'unit': 'mg'},
#                              {'amount': 8.31,
#                               'percentOfDailyNeeds': 33.23,
#                               'title': 'Fiber',
#                               'unit': 'g'},
#                              {'amount': 132.48,
#                               'percentOfDailyNeeds': 33.12,
#                               'title': 'Magnesium',
#                               'unit': 'mg'},
#                              {'amount': 0.44,
#                               'percentOfDailyNeeds': 25.68,
#                               'title': 'Vitamin B2',
#                               'unit': 'mg'},
#                              {'amount': 231.76,
#                               'percentOfDailyNeeds': 23.18,
#                               'title': 'Calcium',
#                               'unit': 'mg'},
#                              {'amount': 17.21,
#                               'percentOfDailyNeeds': 20.86,
#                               'title': 'Vitamin C',
#                               'unit': 'mg'},
#                              {'amount': 3.08,
#                               'percentOfDailyNeeds': 20.52,
#                               'title': 'Zinc',
#                               'unit': 'mg'},
#                              {'amount': 0.39,
#                               'percentOfDailyNeeds': 19.42,
#                               'title': 'Copper',
#                               'unit': 'mg'},
#                              {'amount': 668.55,
#                               'percentOfDailyNeeds': 19.1,
#                               'title': 'Potassium',
#                               'unit': 'mg'},
#                              {'amount': 3.38,
#                               'percentOfDailyNeeds': 18.78,
#                               'title': 'Iron',
#                               'unit': 'mg'},
#                              {'amount': 42.87,
#                               'percentOfDailyNeeds': 10.72,
#                               'title': 'Folate',
#                               'unit': 'µg'},
#                              {'amount': 0.16,
#                               'percentOfDailyNeeds': 7.93,
#                               'title': 'Vitamin B6',
#                               'unit': 'mg'},
#                              {'amount': 1.16,
#                               'percentOfDailyNeeds': 7.72,
#                               'title': 'Vitamin E',
#                               'unit': 'mg'},
#                              {'amount': 1.47,
#                               'percentOfDailyNeeds': 7.33,
#                               'title': 'Vitamin B3',
#                               'unit': 'mg'},
#                              {'amount': 0.71,
#                               'percentOfDailyNeeds': 7.06,
#                               'title': 'Vitamin B5',
#                               'unit': 'mg'},
#                              {'amount': 6.63,
#                               'percentOfDailyNeeds': 6.31,
#                               'title': 'Vitamin K',
#                               'unit': 'µg'},
#                              {'amount': 310.71,
#                               'percentOfDailyNeeds': 6.21,
#                               'title': 'Vitamin A',
#                               'unit': 'IU'},
#                              {'amount': 0.36,
#                               'percentOfDailyNeeds': 5.94,
#                               'title': 'Vitamin B12',
#                               'unit': 'µg'},
#                              {'amount': 0.16,
#                               'percentOfDailyNeeds': 1.07,
#                               'title': 'Vitamin D',
#                               'unit': 'µg'}],
#                'properties': [{'amount': 41.15,
#                                'title': 'Glycemic Index',
#                                'unit': ''},
#                               {'amount': 20.63,
#                                'title': 'Glycemic Load',
#                                'unit': ''}],
#                'weightPerServing': {'amount': 258, 'unit': 'g'}},
#  'occasions': [],
#  'originalId': None,
#  'pricePerServing': 204.21,
#  'readyInMinutes': 45,
#  'servings': 4,
#  'sourceName': None,
#  'sourceUrl': 'http://www.mynewroots.blogspot.com/2008/05/pound-for-pound.html',
#  'spoonacularScore': 50.0,
#  'summary': 'Lemon Raspberry Pound Cake might be just the dessert you are '
#             'searching for. This gluten free and vegetarian recipe serves 4 '
#             'and costs <b>$2.04 per serving</b>. One serving contains <b>583 '
#             'calories</b>, <b>16g of protein</b>, and <b>17g of fat</b>. 1 '
#             'person has made this recipe and would make it again. If you have '
#             'ground flax seed, lemon zest, cane sugar, and a few other '
#             'ingredients on hand, you can make it. From preparation to the '
#             'plate, this recipe takes roughly <b>45 minutes</b>. All things '
#             'considered, we decided this recipe <b>deserves a spoonacular '
#             'score of 54%</b>. This score is solid. Similar recipes are <a '
#             'href="https://spoonacular.com/recipes/lemon-raspberry-pound-cake-631390">Lemon '
#             'Raspberry Pound Cake</a>, <a '
#             'href="https://spoonacular.com/recipes/raspberry-pound-cake-truffles-236834">Raspberry '
#             'Pound Cake Truffles</a>, and <a '
#             'href="https://spoonacular.com/recipes/chocolate-raspberry-pound-cake-50290">Chocolate '
#             'Raspberry Pound Cake</a>.',
#  'sustainable': False,
#  'title': 'Lemon Raspberry Pound Cake',
#  'vegan': False,
#  'vegetarian': True,
#  'veryHealthy': False,
#  'veryPopular': False,
#  'weightWatcherSmartPoints': 22,
#  'winePairing': {'pairedWines': ['cream sherry', 'moscato dasti', 'port'],
#                  'pairingText': "Cream Sherry, Moscato d'Asti, and Port are "
#                                 'great choices for Dessert. A common wine '
#                                 'pairing rule is to make sure your wine is '
#                                 'sweeter than your food. Delicate desserts go '
#                                 "well with Moscato d'Asti, nutty desserts with "
#                                 'cream sherry, and caramel or chocolate '
#                                 'desserts pair well with port. The NV Johnson '
#                                 'Estate Cream Sherry with a 5 out of 5 star '
#                                 'rating seems like a good match. It costs '
#                                 'about 19 dollars per bottle.',
#                  'productMatches': [{'averageRating': 1.0,
#                                      'description': 'Very aromatic with notes '
#                                                     'of hazelnut, vanilla, and '
#                                                     'a touch of oak followed '
#                                                     'by sweet raisins and a '
#                                                     'touch of yeast. Clean '
#                                                     'lasting finish. Good now '
#                                                     'but will reward those '
#                                                     'allow it to age"". A '
#                                                     'favorite pre-prandial '
#                                                     'beverage. Consider it '
#                                                     'with nuts before dinner '
#                                                     'as an aperitif, or after '
#                                                     'dinner with dessert, '
#                                                     'especially chocolates and '
#                                                     'fruit-based desserts. '
#                                                     'Also wonderful on cold '
#                                                     'afternoons, served with '
#                                                     'biscotti to dip in '
#                                                     '""Italian-style"". "',
#                                      'id': 430626,
#                                      'imageUrl': 'https://spoonacular.com/productImages/430626-312x231.jpg',
#                                      'link': 'https://www.amazon.com/Johnson-Estate-Cream-Sherry-750/dp/B00D3GQSRW?tag=spoonacular-20',
#                                      'price': '$19.49',
#                                      'ratingCount': 2.0,
#                                      'score': 0.8571428571428572,
#                                      'title': 'NV Johnson Estate Cream '
#                                               'Sherry'}]}}

# %%
nutrient = response['nutrition']['nutrients']
nutrient
# Out:
# [{'title': 'Calories',
#   'amount': 582.59,
#   'unit': 'cal',
#   'percentOfDailyNeeds': 29.13},
#  {'title': 'Fat', 'amount': 17.0, 'unit': 'g', 'percentOfDailyNeeds': 26.15},
#  {'title': 'Saturated Fat',
#   'amount': 7.16,
#   'unit': 'g',
#   'percentOfDailyNeeds': 44.73},
#  {'title': 'Carbohydrates',
#   'amount': 93.22,
#   'unit': 'g',
#   'percentOfDailyNeeds': 31.07},
#  {'title': 'Net Carbohydrates',
#   'amount': 84.91,
#   'unit': 'g',
#   'percentOfDailyNeeds': 30.88},
#  {'title': 'Sugar', 'amount': 43.3, 'unit': 'g', 'percentOfDailyNeeds': 48.11},
#  {'title': 'Cholesterol',
#   'amount': 25.96,
#   'unit': 'mg',
#   'percentOfDailyNeeds': 8.65},
#  {'title': 'Sodium',
#   'amount': 531.33,
#   'unit': 'mg',
#   'percentOfDailyNeeds': 23.1},
#  {'title': 'Alcohol',
#   'amount': 0.72,
#   'unit': 'g',
#   'percentOfDailyNeeds': 4.01},
#  {'title': 'Protein',
#   'amount': 15.72,
#   'unit': 'g',
#   'percentOfDailyNeeds': 31.43},
#  {'title': 'Manganese',
#   'amount': 3.33,
#   'unit': 'mg',
#   'percentOfDailyNeeds': 166.37},
#  {'title': 'Phosphorus',
#   'amount': 509.32,
#   'unit': 'mg',
#   'percentOfDailyNeeds': 50.93},
#  {'title': 'Selenium',
#   'amount': 30.0,
#   'unit': 'µg',
#   'percentOfDailyNeeds': 42.85},
#  {'title': 'Vitamin B1',
#   'amount': 0.56,
#   'unit': 'mg',
#   'percentOfDailyNeeds': 37.48},
#  {'title': 'Fiber', 'amount': 8.31, 'unit': 'g', 'percentOfDailyNeeds': 33.23},
#  {'title': 'Magnesium',
#   'amount': 132.48,
#   'unit': 'mg',
#   'percentOfDailyNeeds': 33.12},
#  {'title': 'Vitamin B2',
#   'amount': 0.44,
#   'unit': 'mg',
#   'percentOfDailyNeeds': 25.68},
#  {'title': 'Calcium',
#   'amount': 231.76,
#   'unit': 'mg',
#   'percentOfDailyNeeds': 23.18},
#  {'title': 'Vitamin C',
#   'amount': 17.21,
#   'unit': 'mg',
#   'percentOfDailyNeeds': 20.86},
#  {'title': 'Zinc', 'amount': 3.08, 'unit': 'mg', 'percentOfDailyNeeds': 20.52},
#  {'title': 'Copper',
#   'amount': 0.39,
#   'unit': 'mg',
#   'percentOfDailyNeeds': 19.42},
#  {'title': 'Potassium',
#   'amount': 668.55,
#   'unit': 'mg',
#   'percentOfDailyNeeds': 19.1},
#  {'title': 'Iron', 'amount': 3.38, 'unit': 'mg', 'percentOfDailyNeeds': 18.78},
#  {'title': 'Folate',
#   'amount': 42.87,
#   'unit': 'µg',
#   'percentOfDailyNeeds': 10.72},
#  {'title': 'Vitamin B6',
#   'amount': 0.16,
#   'unit': 'mg',
#   'percentOfDailyNeeds': 7.93},
#  {'title': 'Vitamin E',
#   'amount': 1.16,
#   'unit': 'mg',
#   'percentOfDailyNeeds': 7.72},
#  {'title': 'Vitamin B3',
#   'amount': 1.47,
#   'unit': 'mg',
#   'percentOfDailyNeeds': 7.33},
#  {'title': 'Vitamin B5',
#   'amount': 0.71,
#   'unit': 'mg',
#   'percentOfDailyNeeds': 7.06},
#  {'title': 'Vitamin K',
#   'amount': 6.63,
#   'unit': 'µg',
#   'percentOfDailyNeeds': 6.31},
#  {'title': 'Vitamin A',
#   'amount': 310.71,
#   'unit': 'IU',
#   'percentOfDailyNeeds': 6.21},
#  {'title': 'Vitamin B12',
#   'amount': 0.36,
#   'unit': 'µg',
#   'percentOfDailyNeeds': 5.94},
#  {'title': 'Vitamin D',
#   'amount': 0.16,
#   'unit': 'µg',
#   'percentOfDailyNeeds': 1.07}]

# %%
# ingredients = list(range(len(response['nutrition']['ingredients'])))
# ingredients

# for i in ingredients:
#     names = response['nutrition']['ingredients'][i]['name']
#     print(names)

# Extract desired data from the stored json response 
# summary = response['summary']
# title = response['title']
# prepTime = response['readyInMinutes']
# image = response['image']
# pairedWine = response['winePairing']['pairedWines']
# pairingDesc = response['winePairing']['pairingText']
# id_number = response['id']
# serving = response['servings']
# likes = response['aggregateLikes']
# sourceurl = response['sourceUrl']
# nutrition = response['nutrition']['caloricBreakdown']
# nutrition

# food_names = response['nutrition']['ingredients'][i for i in ingredients]['name']

# %%
# url_base = f"https://api.spoonacular.com/recipes/"
# url_tail = "/information?includeNutrition=true"
# key = f"&apiKey={api_key}"

# for num in random_num:
#     params = f'{num}'

#     response = s.get(url_base + params + url_tail + key).json()

# %%
# # create empty dataframe to collect dish pairings from list of wines 
# columns = ['Recipe_ID']
# recipe_df = pd.DataFrame(columns=columns)
# recipe_df
# dish_pairing_df['wine'] = wine_selections
# dish_pairing_df

# %%
# # build a list of random ID numbers to test API call
# recipe_num = [random.randrange(1,200000,1) for i in range(5)]
# recipe_num

# %%
# create a function for the lists, divide by 150, set in a try/catch statement

# %%
# recipe_df['Recipe_ID'] = recipe_num
# recipe_df

# %%
# recipe_df['Spoon_ID'] = ''
# recipe_df['Title'] = ''
# recipe_df['PrepTime'] = ''
# recipe_df['Summary'] = ''
# recipe_df['CaloricBreakdown'] = ''
# recipe_df['Servings'] = ''
# recipe_df['Likes'] = ''
# recipe_df['SourceURL'] = ''
# recipe_df['ImageURL'] = ''
# recipe_df['WinePairing'] = ''
# recipe_df['WineDescription'] = ''
# recipe_df

# %%
url_base = f"https://api.spoonacular.com/recipes/"
url_tail = "/information?includeNutrition=true"
key = f"&apiKey={api_key}"

# recipe_query = f"{url_base}{meal_id}{recipe_url_tail}&apiKey={key}"

s = requests.Session()
# response = s.get(recipe_query).json()
# response

# %%
# columns = ["Spoon_ID","Title","PrepTime","Summary","CaloricBreakdown","Servings","Likes","SourceURL","ImageURL","WinePairing","WineDescription"]
# nutrition = []
# recipe_df = pd.DataFrame(columns=columns)

# recipe_df["Recipe_ID"]=recipe_num

# for index, row in recipe_df.iterrows():
#     meal_id = row['Recipe_ID']
#     params = f'{meal_id}'

#     response = s.get(url_base + params + url_tail + key).json()  
#     if response.status_code=200:
#         recipe_data=response.json()
    
#     try:
#         recipe_df.at[index,"Spoon_ID"] = response['id'] 
#         recipe_df.at[index,"Title"] = response['title']
#         recipe_df.at[index,"PrepTime"] = response['readyInMinutes']
#         recipe_df.at[index,"Summary"] = response['summary']
#         recipe_df.at[index,"CaloricBreakdown"] = response['nutrition']['caloricBreakdown']
#         recipe_df.at[index,"Servings"] = response['servings']
#         recipe_df.at[index,"Likes"] = response['aggregateLikes']
#         recipe_df.at[index,"SourceURL"] = response['sourceURL']
#         recipe_df.at[index,"ImageURL"] = response['image']
#         recipe_df.at[index,"WinePairing"] = response['winePairing']['pairedWines']
#         recipe_df.at[index,"WineDescription"] = response['winePairing']['pairingText']
#         nutrition.append(response['nutrition']['caloricBreakdown'])

#     except (KeyError, IndexError, ValueError):
#         recipe_df.at[index,"Spoon_ID"] = "ID does not exist"
#         recipe_df.at[index,"Title"] = "no title available"
#         recipe_df.at[index,"PrepTime"] = "no prep time available"
#         recipe_df.at[index,"Summary"] = "no summary avaialble"
#         recipe_df.at[index,"CaloricBreakdown"] = "no calorie information available"
#         recipe_df.at[index,"Servings"] = "no servings available"
#         recipe_df.at[index,"Likes"] = "noone likes this dish"
#         recipe_df.at[index,"SourceURL"] = "no source URL available"
#         recipe_df.at[index,"ImageURL"] = "no image URL available"
#         recipe_df.at[index,"WinePairing"] = "no wine pairing available"
#         recipe_df.at[index,"WineDescription"] = "no wine description available"

# %%
# recipe_df['CaloricBreakdown'] = nutrition
# recipe_df

# %%
# build a list of random ID numbers to fetch a variety of recipes from API call 
# this was done because consecutive ID numbers retrieves recipes of the same main ingredient
recipe_num= [random.randrange(1,200000,1) for i in range(6000)]
recipe_num
print(len(recipe_num))
res = []
[res.append(x) for x in recipe_num if x not in res]
print(len(res))
# Out:
# 6000
# 5900

# %%
## create a function that divides the recipe id list 'res' into sets of 150 for API calls
## This function was not successful
# def divide_my_list(recipe_id_list):
#     api_id_list = np.array_split(recipe_id_list, 40)
    
#     for id_list in api_id_list:
#         print(list(id_list))

# %%
# create a function that divides the recipe id list 'res' into sets of 150 for API calls
def divide_list(l, n): 
    
    # looping till length l 
    for i in range(0, len(l), n):  
        yield l[i:i + n] 

n = 150  
x = list(divide_list(res, n)) 
recipe_list_1 = x[0]
# recipe_list_1
recipe_list_1 = x[0]
recipe_list_2 = x[1]
recipe_list_3 = x[2]
recipe_list_4 = x[3]

full_list = recipe_list_1 + recipe_list_2 + recipe_list_3 + recipe_list_4
full_list
# Out:
# [19655,
#  174717,
#  159899,
#  142656,
#  33331,
#  197136,
#  35726,
#  1370,
#  120665,
#  71426,
#  67030,
#  55193,
#  53427,
#  123921,
#  5422,
#  93337,
#  58236,
#  45655,
#  105251,
#  104904,
#  59022,
#  52398,
#  53277,
#  191725,
#  179762,
#  96029,
#  112165,
#  67813,
#  31071,
#  50687,
#  130691,
#  68286,
#  87913,
#  163650,
#  15473,
#  34011,
#  154957,
#  120809,
#  146147,
#  21741,
#  113098,
#  127348,
#  126978,
#  180781,
#  2246,
#  19915,
#  138841,
#  181704,
#  80343,
#  159408,
#  105571,
#  48081,
#  92112,
#  108990,
#  55340,
#  80612,
#  56973,
#  6362,
#  132373,
#  146093,
#  32045,
#  124082,
#  184922,
#  145619,
#  136433,
#  146137,
#  116213,
#  122144,
#  183720,
#  27677,
#  66928,
#  140326,
#  111516,
#  77269,
#  116644,
#  148738,
#  162970,
#  188601,
#  3532,
#  36999,
#  29984,
#  138352,
#  19553,
#  35482,
#  148385,
#  31074,
#  107492,
#  161248,
#  39150,
#  175658,
#  50389,
#  76324,
#  122501,
#  107375,
#  198576,
#  47776,
#  177329,
#  40558,
#  184752,
#  84206,
#  81636,
#  155022,
#  29001,
#  166180,
#  141921,
#  21123,
#  176605,
#  160487,
#  57645,
#  188777,
#  61375,
#  165495,
#  189996,
#  119297,
#  163060,
#  170133,
#  111286,
#  153405,
#  49937,
#  69924,
#  144579,
#  173113,
#  111285,
#  122607,
#  170069,
#  12828,
#  80518,
#  41121,
#  56667,
#  168728,
#  42774,
#  55007,
#  78597,
#  56049,
#  82353,
#  13065,
#  3744,
#  150214,
#  87212,
#  119085,
#  122088,
#  3202,
#  153075,
#  124957,
#  82,
#  26612,
#  166604,
#  86940,
#  93210,
#  122753,
#  183562,
#  185199,
#  30406,
#  73334,
#  48981,
#  89116,
#  40621,
#  169433,
#  195602,
#  40336,
#  92549,
#  134352,
#  78885,
#  170751,
#  140451,
#  52419,
#  4808,
#  97251,
#  12673,
#  28319,
#  42856,
#  91232,
#  178291,
#  1591,
#  109814,
#  126204,
#  182641,
#  59498,
#  46515,
#  29489,
#  133962,
#  72402,
#  120720,
#  37134,
#  178315,
#  179264,
#  32013,
#  39774,
#  157877,
#  143028,
#  169031,
#  198625,
#  11032,
#  16051,
#  68507,
#  53290,
#  177871,
#  121450,
#  92135,
#  194203,
#  183026,
#  116845,
#  163821,
#  28948,
#  195239,
#  28543,
#  40156,
#  174351,
#  126884,
#  136351,
#  23030,
#  20685,
#  130203,
#  159249,
#  40302,
#  157706,
#  29149,
#  80471,
#  74633,
#  42,
#  193453,
#  63309,
#  196564,
#  28870,
#  110495,
#  71519,
#  117429,
#  80619,
#  79794,
#  101601,
#  28282,
#  166369,
#  148543,
#  87141,
#  70887,
#  16625,
#  4612,
#  128969,
#  61397,
#  83610,
#  181153,
#  104166,
#  199827,
#  145169,
#  105346,
#  34550,
#  45353,
#  194874,
#  14275,
#  157352,
#  134744,
#  85448,
#  145326,
#  129122,
#  42723,
#  140752,
#  33438,
#  55210,
#  27637,
#  106455,
#  54449,
#  187150,
#  59410,
#  1508,
#  85926,
#  113009,
#  176438,
#  176316,
#  168267,
#  39207,
#  113939,
#  88268,
#  102986,
#  9551,
#  119063,
#  58990,
#  60586,
#  50176,
#  80277,
#  136371,
#  173045,
#  25807,
#  1103,
#  196994,
#  174452,
#  76660,
#  151449,
#  186174,
#  42426,
#  24997,
#  181248,
#  61636,
#  52381,
#  29606,
#  123487,
#  96448,
#  79363,
#  75008,
#  117472,
#  57247,
#  6594,
#  10934,
#  60816,
#  71737,
#  88175,
#  25299,
#  27634,
#  6815,
#  70216,
#  73579,
#  64900,
#  57050,
#  3842,
#  166465,
#  65939,
#  16023,
#  68711,
#  116796,
#  35719,
#  165,
#  122875,
#  143671,
#  31032,
#  18984,
#  84887,
#  9519,
#  187511,
#  191452,
#  41446,
#  66801,
#  33646,
#  111071,
#  140820,
#  67863,
#  191574,
#  124927,
#  156446,
#  78045,
#  162123,
#  190766,
#  154828,
#  23829,
#  46607,
#  99395,
#  147166,
#  93523,
#  196628,
#  32943,
#  67968,
#  197888,
#  57941,
#  16873,
#  30358,
#  113037,
#  54182,
#  136382,
#  93660,
#  197816,
#  100966,
#  12980,
#  132995,
#  190482,
#  57632,
#  182536,
#  143586,
#  14428,
#  174303,
#  78293,
#  95601,
#  71869,
#  5893,
#  154253,
#  148005,
#  96286,
#  114806,
#  47261,
#  174134,
#  190317,
#  129641,
#  195154,
#  60589,
#  194646,
#  126310,
#  1157,
#  133187,
#  152458,
#  155055,
#  173706,
#  1164,
#  151606,
#  134566,
#  149325,
#  112390,
#  188089,
#  113717,
#  199627,
#  94281,
#  192172,
#  54339,
#  31578,
#  59239,
#  105355,
#  70849,
#  163741,
#  358,
#  729,
#  17658,
#  186573,
#  84029,
#  169526,
#  150931,
#  95522,
#  153057,
#  106196,
#  148846,
#  125457,
#  148180,
#  88655,
#  183148,
#  153306,
#  109871,
#  127603,
#  38046,
#  95543,
#  134469,
#  5153,
#  198529,
#  117605,
#  50071,
#  63617,
#  14327,
#  170263,
#  75406,
#  140000,
#  39029,
#  20812,
#  28060,
#  89799,
#  155416,
#  167016,
#  148953,
#  112537,
#  137487,
#  18725,
#  93299,
#  11021,
#  41566,
#  177076,
#  144367,
#  86862,
#  12121,
#  44874,
#  64175,
#  142126,
#  129397,
#  117427,
#  67203,
#  191434,
#  103463,
#  22501,
#  149670,
#  95540,
#  76986,
#  143150,
#  100168,
#  118578,
#  7357,
#  125006,
#  57787,
#  193796,
#  77490,
#  185457,
#  82536,
#  5741,
#  180548,
#  145115,
#  99401,
#  145854,
#  23013,
#  145051,
#  97039,
#  188483,
#  105760,
#  115196,
#  12872,
#  172444,
#  46323,
#  113472,
#  195190,
#  69574,
#  103185,
#  12513,
#  52842,
#  189426,
#  154044,
#  175026,
#  191805,
#  116841,
#  35438,
#  41572,
#  66317,
#  31483,
#  133436,
#  189645,
#  111110,
#  34086,
#  160258,
#  165518,
#  32772,
#  6345,
#  155550,
#  35322,
#  130760,
#  75835,
#  25697,
#  120699,
#  193134,
#  35794,
#  125311,
#  91519,
#  20563,
#  39265,
#  1602,
#  94595,
#  107683,
#  116192,
#  71282,
#  150824,
#  48231,
#  32881,
#  181433,
#  150195,
#  135594,
#  169701,
#  28084,
#  178492,
#  121466,
#  101275,
#  63367,
#  28680,
#  147249,
#  5042,
#  24715,
#  143356,
#  194032,
#  41205,
#  140572,
#  59548,
#  129739,
#  154082,
#  138515,
#  29311,
#  52210,
#  187855,
#  154572,
#  46672,
#  68770,
#  199775,
#  117955,
#  90033,
#  155370,
#  33481,
#  175451,
#  56022,
#  83463,
#  83527,
#  170207,
#  154040,
#  72766,
#  177586,
#  103880,
#  38540,
#  179503,
#  186728,
#  37333,
#  48154,
#  148120,
#  29365,
#  43973,
#  107493,
#  149452,
#  99472,
#  12866,
#  80177,
#  108902,
#  121506,
#  91649,
#  172375,
#  125388,
#  126282,
#  83152,
#  46274,
#  93157,
#  37454,
#  192009,
#  86303,
#  152057,
#  6517,
#  35824,
#  174470]

# %%
data = []
# data_2 = []
import numpy as np
import time
# Recipe Dataframe Components
rec_data_comps = ['id', 'title', 'readyInMinutes', 'nutrition>caloricBreakdown>percentProtein', 'nutrition>caloricBreakdown>percentFat','nutrition>caloricBreakdown>percentCarbs','nutrition'>'nutrients','servings','image','sourceUrl','summary',
                  'aggregateLikes','spoonacularScore','winePairing>pairedWines', 'winePairing>pairingText']
def rec_comp_check(comp, recipe_data):
    try:
        comp_path = comp.split(">")
        for c in comp_path:
            recipe_data = recipe_data[c]
        datum = recipe_data
    except:
        datum = np.nan
    return datum
for num in full_list: # may need to fix what you iterate over

    params = f'{num}'
    response = s.get(url_base + params + url_tail + key)
    if response.status_code == 200:
        recipe_data = response.json()
        my_big_dict ={"My ID": num}
        for comp in rec_data_comps:
            my_big_dict[comp] = rec_comp_check(comp, recipe_data)
        data.append(my_big_dict)
    else:
        print(f'{num} failed to return a good API response')
        print(response)
pd.DataFrame(data)
# Out:
# 5422 failed to return a good API response
# <Response [404]>
# 34011 failed to return a good API response
# <Response [404]>
# 154957 failed to return a good API response
# <Response [404]>
# 159408 failed to return a good API response
# <Response [404]>
# 148738 failed to return a good API response
# <Response [404]>
# 148385 failed to return a good API response
# <Response [404]>
# 107492 failed to return a good API response
# <Response [404]>
# 161248 failed to return a good API response
# <Response [404]>
# 198576 failed to return a good API response
# <Response [404]>
# 47776 failed to return a good API response
# <Response [404]>
# 155022 failed to return a good API response
# <Response [404]>
# 153405 failed to return a good API response
# <Response [404]>
# 69924 failed to return a good API response
# <Response [404]>
# 122607 failed to return a good API response
# <Response [404]>
# 82353 failed to return a good API response
# <Response [404]>
# 153075 failed to return a good API response
# <Response [404]>
# 122753 failed to return a good API response
# <Response [404]>
# 42856 failed to return a good API response
# <Response [404]>
# 32013 failed to return a good API response
# <Response [404]>
# 169031 failed to return a good API response
# <Response [404]>
# 28948 failed to return a good API response
# <Response [404]>
# 101601 failed to return a good API response
# <Response [404]>
# 85448 failed to return a good API response
# <Response [404]>
# 88268 failed to return a good API response
# <Response [404]>
# 151449 failed to return a good API response
# <Response [404]>
# 24997 failed to return a good API response
# <Response [404]>
# 96448 failed to return a good API response
# <Response [404]>
# 25299 failed to return a good API response
# <Response [404]>
# 6815 failed to return a good API response
# <Response [404]>
# 73579 failed to return a good API response
# <Response [404]>
# 57050 failed to return a good API response
# <Response [404]>
# 165 failed to return a good API response
# <Response [404]>
# 18984 failed to return a good API response
# <Response [404]>
# 156446 failed to return a good API response
# <Response [404]>
# 154828 failed to return a good API response
# <Response [404]>
# 46607 failed to return a good API response
# <Response [404]>
# 147166 failed to return a good API response
# <Response [404]>
# 32943 failed to return a good API response
# <Response [404]>
# 12980 failed to return a good API response
# <Response [404]>
# 57632 failed to return a good API response
# <Response [404]>
# 78293 failed to return a good API response
# <Response [404]>
# 154253 failed to return a good API response
# <Response [404]>
# 195154 failed to return a good API response
# <Response [404]>
# 152458 failed to return a good API response
# <Response [404]>
# 155055 failed to return a good API response
# <Response [404]>
# 134566 failed to return a good API response
# <Response [404]>
# 59239 failed to return a good API response
# <Response [404]>
# 358 failed to return a good API response
# <Response [404]>
# 729 failed to return a good API response
# <Response [404]>
# 150931 failed to return a good API response
# <Response [404]>
# 153057 failed to return a good API response
# <Response [404]>
# 153306 failed to return a good API response
# <Response [404]>
# 127603 failed to return a good API response
# <Response [404]>
# 50071 failed to return a good API response
# <Response [404]>
# 28060 failed to return a good API response
# <Response [404]>
# 155416 failed to return a good API response
# <Response [404]>
# 148953 failed to return a good API response
# <Response [404]>
# 142126 failed to return a good API response
# <Response [404]>
# 57787 failed to return a good API response
# <Response [404]>
# 82536 failed to return a good API response
# <Response [404]>
# 5741 failed to return a good API response
# <Response [404]>
# 99401 failed to return a good API response
# <Response [404]>
# 145854 failed to return a good API response
# <Response [404]>
# 41572 failed to return a good API response
# <Response [404]>
# 31483 failed to return a good API response
# <Response [404]>
# 34086 failed to return a good API response
# <Response [404]>
# 35322 failed to return a good API response
# <Response [404]>
# 130760 failed to return a good API response
# <Response [404]>
# 120699 failed to return a good API response
# <Response [404]>
# 20563 failed to return a good API response
# <Response [404]>
# 107683 failed to return a good API response
# <Response [404]>
# 150824 failed to return a good API response
# <Response [404]>
# 48231 failed to return a good API response
# <Response [404]>
# 32881 failed to return a good API response
# <Response [404]>
# 150195 failed to return a good API response
# <Response [404]>
# 5042 failed to return a good API response
# <Response [404]>
# 154082 failed to return a good API response
# <Response [404]>
# 154572 failed to return a good API response
# <Response [404]>
# 68770 failed to return a good API response
# <Response [404]>
# 90033 failed to return a good API response
# <Response [404]>
# 154040 failed to return a good API response
# <Response [404]>
# 72766 failed to return a good API response
# <Response [404]>
# 37333 failed to return a good API response
# <Response [404]>
# 29365 failed to return a good API response
# <Response [404]>
# 152057 failed to return a good API response
# <Response [404]>
# 6517 failed to return a good API response
# <Response [404]>
#       My ID      id                                          title  \
# 0     19655   19655                    Cheddar And Spinach Souffle
# 1    174717  174717                           Homemade Turkey Soup
# 2    159899  159899                     Homemade Marshmallow Crème
# 3    142656  142656                    Coleslaw with a Difference!
# 4     33331   33331  Spring Vegetable Fricassee With Saffron Cream
# ..      ...     ...                                            ...
# 509   37454   37454                        Edamame Succotash Salad
# 510  192009  192009                                       Cioppino
# 511   86303   86303            Cod Patties With Two Dipping Sauces
# 512   35824   35824          Reeses Peanut Butter Surprise Cookies
# 513  174470  174470                    Chipotle Chicken Drummettes
#
#      readyInMinutes  nutrition>caloricBreakdown>percentProtein  \
# 0                45                                      18.34
# 1               175                                      57.80
# 2                30                                       2.47
# 3                10                                       2.99
# 4                45                                       6.66
# ..              ...                                        ...
# 509            1722                                      18.61
# 510              60                                      39.45
# 511              40                                      26.47
# 512              45                                       4.95
# 513              70                                      26.79
#
#      nutrition>caloricBreakdown>percentFat  \
# 0                                    57.87
# 1                                    33.61
# 2                                     0.35
# 3                                    84.72
# 4                                    70.32
# ..                                     ...
# 509                                  34.78
# 510                                  25.64
# 511                                  54.15
# 512                                  38.17
# 513                                  49.87
#
#      nutrition>caloricBreakdown>percentCarbs  servings  \
# 0                                      23.79         4
# 1                                       8.59        10
# 2                                      97.18        10
# 3                                      12.29         4
# 4                                      23.02         4
# ..                                       ...       ...
# 509                                    46.61        10
# 510                                    34.91         8
# 511                                    19.38         4
# 512                                    56.88         8
# 513                                    23.34        20
#
#                                                  image  \
# 0    https://spoonacular.com/recipeImages/19655-556...
# 1    https://spoonacular.com/recipeImages/174717-55...
# 2    https://spoonacular.com/recipeImages/159899-55...
# 3    https://spoonacular.com/recipeImages/142656-55...
# 4    https://spoonacular.com/recipeImages/33331-556...
# ..                                                 ...
# 509  https://spoonacular.com/recipeImages/37454-556...
# 510  https://spoonacular.com/recipeImages/192009-55...
# 511  https://spoonacular.com/recipeImages/86303-556...
# 512  https://spoonacular.com/recipeImages/35824-556...
# 513  https://spoonacular.com/recipeImages/174470-55...
#
#                                              sourceUrl  \
# 0    http://www.runningwithtweezers.com/hay_hay_gue...
# 1    http://www.BettyCrocker.com/recipes/homemade-t...
# 2    http://www.chow.com/recipes/30296-homemade-mar...
# 3    http://allrecipes.com/Recipe/Coleslaw-with-a-D...
# 4    http://www.bonappetit.com/recipes/2006/04/spri...
# ..                                                 ...
# 509  http://www.epicurious.com/recipes/food/views/E...
# 510  http://www.epicurious.com:80/recipes/food/view...
# 511  http://www.food.com/recipe/cod-patties-with-tw...
# 512  http://withstyle.me/2011/02/23/reeses-peanut-b...
# 513  https://www.bettycrocker.com/recipes/chipotle-...
#
#                                                summary  aggregateLikes  \
# 0    Cheddar And Spinach Souffle might be just the ...               0
# 1    Homemade Turkey Soup might be just the main co...               0
# 2    You can never have too many side dish recipes,...               0
# 3    Coleslaw with a Difference! is a <b>gluten fre...               0
# 4    This gluten free, primal, and vegetarian recip...               1
# ..                                                 ...             ...
# 509  Need a <b>gluten free and vegan side dish</b>?...               0
# 510  Cioppino is a <b>dairy free and pescatarian</b...               0
# 511  Cod Patties With Two Dipping Sauces might be j...               0
# 512  Reeses Peanut Butter Surprise Cookies might be...             438
# 513  Chipotle Chicken Drummettes requires around <b...               2
#
#                            winePairing>pairedWines  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 509          [riesling, sparkling wine, zinfandel]
# 510                                            NaN
# 511  [pinot grigio, gruener veltliner, pinot noir]
# 512                                            NaN
# 513                                            NaN
#
#                                winePairing>pairingText
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 509  Riesling, Sparkling Wine, and Zinfandel are gr...
# 510                                                NaN
# 511  Cod works really well with Pinot Grigio, Gruen...
# 512                                                NaN
# 513                                                NaN
#
# [514 rows x 14 columns]

# %%
dataFrame_1 = pd.DataFrame(data)
dataFrame_1
# Out:
#       My ID      id                                          title  \
# 0     19655   19655                    Cheddar And Spinach Souffle
# 1    174717  174717                           Homemade Turkey Soup
# 2    159899  159899                     Homemade Marshmallow Crème
# 3    142656  142656                    Coleslaw with a Difference!
# 4     33331   33331  Spring Vegetable Fricassee With Saffron Cream
# ..      ...     ...                                            ...
# 509   37454   37454                        Edamame Succotash Salad
# 510  192009  192009                                       Cioppino
# 511   86303   86303            Cod Patties With Two Dipping Sauces
# 512   35824   35824          Reeses Peanut Butter Surprise Cookies
# 513  174470  174470                    Chipotle Chicken Drummettes
#
#      readyInMinutes  nutrition>caloricBreakdown>percentProtein  \
# 0                45                                      18.34
# 1               175                                      57.80
# 2                30                                       2.47
# 3                10                                       2.99
# 4                45                                       6.66
# ..              ...                                        ...
# 509            1722                                      18.61
# 510              60                                      39.45
# 511              40                                      26.47
# 512              45                                       4.95
# 513              70                                      26.79
#
#      nutrition>caloricBreakdown>percentFat  \
# 0                                    57.87
# 1                                    33.61
# 2                                     0.35
# 3                                    84.72
# 4                                    70.32
# ..                                     ...
# 509                                  34.78
# 510                                  25.64
# 511                                  54.15
# 512                                  38.17
# 513                                  49.87
#
#      nutrition>caloricBreakdown>percentCarbs  servings  \
# 0                                      23.79         4
# 1                                       8.59        10
# 2                                      97.18        10
# 3                                      12.29         4
# 4                                      23.02         4
# ..                                       ...       ...
# 509                                    46.61        10
# 510                                    34.91         8
# 511                                    19.38         4
# 512                                    56.88         8
# 513                                    23.34        20
#
#                                                  image  \
# 0    https://spoonacular.com/recipeImages/19655-556...
# 1    https://spoonacular.com/recipeImages/174717-55...
# 2    https://spoonacular.com/recipeImages/159899-55...
# 3    https://spoonacular.com/recipeImages/142656-55...
# 4    https://spoonacular.com/recipeImages/33331-556...
# ..                                                 ...
# 509  https://spoonacular.com/recipeImages/37454-556...
# 510  https://spoonacular.com/recipeImages/192009-55...
# 511  https://spoonacular.com/recipeImages/86303-556...
# 512  https://spoonacular.com/recipeImages/35824-556...
# 513  https://spoonacular.com/recipeImages/174470-55...
#
#                                              sourceUrl  \
# 0    http://www.runningwithtweezers.com/hay_hay_gue...
# 1    http://www.BettyCrocker.com/recipes/homemade-t...
# 2    http://www.chow.com/recipes/30296-homemade-mar...
# 3    http://allrecipes.com/Recipe/Coleslaw-with-a-D...
# 4    http://www.bonappetit.com/recipes/2006/04/spri...
# ..                                                 ...
# 509  http://www.epicurious.com/recipes/food/views/E...
# 510  http://www.epicurious.com:80/recipes/food/view...
# 511  http://www.food.com/recipe/cod-patties-with-tw...
# 512  http://withstyle.me/2011/02/23/reeses-peanut-b...
# 513  https://www.bettycrocker.com/recipes/chipotle-...
#
#                                                summary  aggregateLikes  \
# 0    Cheddar And Spinach Souffle might be just the ...               0
# 1    Homemade Turkey Soup might be just the main co...               0
# 2    You can never have too many side dish recipes,...               0
# 3    Coleslaw with a Difference! is a <b>gluten fre...               0
# 4    This gluten free, primal, and vegetarian recip...               1
# ..                                                 ...             ...
# 509  Need a <b>gluten free and vegan side dish</b>?...               0
# 510  Cioppino is a <b>dairy free and pescatarian</b...               0
# 511  Cod Patties With Two Dipping Sauces might be j...               0
# 512  Reeses Peanut Butter Surprise Cookies might be...             438
# 513  Chipotle Chicken Drummettes requires around <b...               2
#
#                            winePairing>pairedWines  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 509          [riesling, sparkling wine, zinfandel]
# 510                                            NaN
# 511  [pinot grigio, gruener veltliner, pinot noir]
# 512                                            NaN
# 513                                            NaN
#
#                                winePairing>pairingText
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 509  Riesling, Sparkling Wine, and Zinfandel are gr...
# 510                                                NaN
# 511  Cod works really well with Pinot Grigio, Gruen...
# 512                                                NaN
# 513                                                NaN
#
# [514 rows x 14 columns]

# %%
data_Frame_2 = pd.DataFrame(data_2)
data_Frame_2
# Out:
#       My ID      id                                              title  \
# 0     70592   70592                           Emily's Famous Apple Pie
# 1     49667   49667                                     Banana Pudding
# 2     46632   46632                           Roasted Fish on Rosemary
# 3     73757   73757                                         Pizza Dogs
# 4    161552  161552                        Asiago Sun-Dried Tomato Dip
# ..      ...     ...                                                ...
# 390  175941  175941                     Cheddar Bread Breakfast Panini
# 391   84425   84425                    Meyer Lemon Curd + Cream Scones
# 392  126209  126209                               Berry Berry Cool Pie
# 393   78712   78712  Potato & Chorizo Omelette Recipe (with Kinda P...
# 394  179964  179964                                Peppermint Barktini
#
#      readyInMinutes  nutrition>caloricBreakdown>percentProtein  \
# 0                60                                       2.17
# 1                45                                       9.66
# 2                45                                      56.33
# 3                30                                      12.15
# 4                50                                      13.74
# ..              ...                                        ...
# 390             170                                      23.50
# 391              15                                       7.65
# 392              45                                       7.32
# 393              24                                      18.54
# 394              10                                       2.60
#
#      nutrition>caloricBreakdown>percentFat  \
# 0                                     1.77
# 1                                    23.48
# 2                                    34.17
# 3                                    53.88
# 4                                    71.64
# ..                                     ...
# 390                                  71.08
# 391                                  53.62
# 392                                  36.44
# 393                                  48.82
# 394                                  35.04
#
#      nutrition>caloricBreakdown>percentCarbs  servings  \
# 0                                      96.06        10
# 1                                      66.86        10
# 2                                       9.50         2
# 3                                      33.97         1
# 4                                      14.62        32
# ..                                       ...       ...
# 390                                     5.42         8
# 391                                    38.73         1
# 392                                    56.24        10
# 393                                    32.64         2
# 394                                    62.36         2
#
#                                                  image  \
# 0    https://spoonacular.com/recipeImages/70592-556...
# 1    https://spoonacular.com/recipeImages/49667-556...
# 2    https://spoonacular.com/recipeImages/46632-556...
# 3    https://spoonacular.com/recipeImages/73757-556...
# 4    https://spoonacular.com/recipeImages/161552-55...
# ..                                                 ...
# 390  https://spoonacular.com/recipeImages/175941-55...
# 391  https://spoonacular.com/recipeImages/84425-556...
# 392  https://spoonacular.com/recipeImages/126209-55...
# 393  https://spoonacular.com/recipeImages/78712-556...
# 394  https://spoonacular.com/recipeImages/179964-55...
#
#                                              sourceUrl  \
# 0    http://allrecipes.com/Recipe/Emilys-Famous-App...
# 1    http://www.myrecipes.com/recipe/banana-pudding...
# 2    http://www.myrecipes.com/recipe/roasted-fish-o...
# 3          http://www.recipezaar.com/Pizza-Dogs-180225
# 4    http://www.BettyCrocker.com/recipes/asiago-sun...
# ..                                                 ...
# 390  http://www.BettyCrocker.com/recipes/cheddar-br...
# 391  http://www.honeyandjam.com/2011/03/meyer-lemon...
# 392  http://www.myrecipes.com/recipe/berry-berry-co...
# 393  http://www.jamieoliver.com/recipes/egg-recipes...
# 394  https://www.bettycrocker.com/recipes/peppermin...
#
#                                                summary  aggregateLikes  \
# 0    Emily's Famous Apple Pie is an American recipe...              23
# 1    You can never have too many dessert recipes, s...               0
# 2    Roasted Fish on Rosemary is a <b>caveman, glut...               0
# 3    Pizza Dogs requires approximately <b>30 minute...               0
# 4    Asiago Sun-Dried Tomato Dip might be just the ...               0
# ..                                                 ...             ...
# 390  You can never have too many main course recipe...              23
# 391  The recipe Meyer Lemon Curd + Cream Scones cou...              71
# 392  For <b>89 cents per serving</b>, this recipe <...               0
# 393  Need a <b>gluten free, dairy free, and whole 3...             158
# 394  Peppermint Barktini might be just the beverage...              55
#
#                            winePairing>pairedWines  \
# 0                                               []
# 1                                              NaN
# 2    [pinot grigio, gruener veltliner, pinot noir]
# 3            [riesling, gewurztraminer, rose wine]
# 4                                               []
# ..                                             ...
# 390                                             []
# 391                                            NaN
# 392                                            NaN
# 393                                            NaN
# 394                                            NaN
#
#                                winePairing>pairingText
# 0
# 1                                                  NaN
# 2    Pinot Grigio, Gruener Veltliner, and Pinot Noi...
# 3    Hot Dogs on the menu? Try pairing with Rieslin...
# 4
# ..                                                 ...
# 390
# 391                                                NaN
# 392                                                NaN
# 393                                                NaN
# 394                                                NaN
#
# [395 rows x 14 columns]

# %%
frames = [dataFrame_1, data_Frame_2]
result = pd.concat(frames)
result
# Out:
#       My ID      id                                              title  \
# 0     19655   19655                        Cheddar And Spinach Souffle
# 1    174717  174717                               Homemade Turkey Soup
# 2    159899  159899                         Homemade Marshmallow Crème
# 3    142656  142656                        Coleslaw with a Difference!
# 4     33331   33331      Spring Vegetable Fricassee With Saffron Cream
# ..      ...     ...                                                ...
# 390  175941  175941                     Cheddar Bread Breakfast Panini
# 391   84425   84425                    Meyer Lemon Curd + Cream Scones
# 392  126209  126209                               Berry Berry Cool Pie
# 393   78712   78712  Potato & Chorizo Omelette Recipe (with Kinda P...
# 394  179964  179964                                Peppermint Barktini
#
#      readyInMinutes  nutrition>caloricBreakdown>percentProtein  \
# 0                45                                      18.34
# 1               175                                      57.80
# 2                30                                       2.47
# 3                10                                       2.99
# 4                45                                       6.66
# ..              ...                                        ...
# 390             170                                      23.50
# 391              15                                       7.65
# 392              45                                       7.32
# 393              24                                      18.54
# 394              10                                       2.60
#
#      nutrition>caloricBreakdown>percentFat  \
# 0                                    57.87
# 1                                    33.61
# 2                                     0.35
# 3                                    84.72
# 4                                    70.32
# ..                                     ...
# 390                                  71.08
# 391                                  53.62
# 392                                  36.44
# 393                                  48.82
# 394                                  35.04
#
#      nutrition>caloricBreakdown>percentCarbs  servings  \
# 0                                      23.79         4
# 1                                       8.59        10
# 2                                      97.18        10
# 3                                      12.29         4
# 4                                      23.02         4
# ..                                       ...       ...
# 390                                     5.42         8
# 391                                    38.73         1
# 392                                    56.24        10
# 393                                    32.64         2
# 394                                    62.36         2
#
#                                                  image  \
# 0    https://spoonacular.com/recipeImages/19655-556...
# 1    https://spoonacular.com/recipeImages/174717-55...
# 2    https://spoonacular.com/recipeImages/159899-55...
# 3    https://spoonacular.com/recipeImages/142656-55...
# 4    https://spoonacular.com/recipeImages/33331-556...
# ..                                                 ...
# 390  https://spoonacular.com/recipeImages/175941-55...
# 391  https://spoonacular.com/recipeImages/84425-556...
# 392  https://spoonacular.com/recipeImages/126209-55...
# 393  https://spoonacular.com/recipeImages/78712-556...
# 394  https://spoonacular.com/recipeImages/179964-55...
#
#                                              sourceUrl  \
# 0    http://www.runningwithtweezers.com/hay_hay_gue...
# 1    http://www.BettyCrocker.com/recipes/homemade-t...
# 2    http://www.chow.com/recipes/30296-homemade-mar...
# 3    http://allrecipes.com/Recipe/Coleslaw-with-a-D...
# 4    http://www.bonappetit.com/recipes/2006/04/spri...
# ..                                                 ...
# 390  http://www.BettyCrocker.com/recipes/cheddar-br...
# 391  http://www.honeyandjam.com/2011/03/meyer-lemon...
# 392  http://www.myrecipes.com/recipe/berry-berry-co...
# 393  http://www.jamieoliver.com/recipes/egg-recipes...
# 394  https://www.bettycrocker.com/recipes/peppermin...
#
#                                                summary  aggregateLikes  \
# 0    Cheddar And Spinach Souffle might be just the ...               0
# 1    Homemade Turkey Soup might be just the main co...               0
# 2    You can never have too many side dish recipes,...               0
# 3    Coleslaw with a Difference! is a <b>gluten fre...               0
# 4    This gluten free, primal, and vegetarian recip...               1
# ..                                                 ...             ...
# 390  You can never have too many main course recipe...              23
# 391  The recipe Meyer Lemon Curd + Cream Scones cou...              71
# 392  For <b>89 cents per serving</b>, this recipe <...               0
# 393  Need a <b>gluten free, dairy free, and whole 3...             158
# 394  Peppermint Barktini might be just the beverage...              55
#
#     winePairing>pairedWines winePairing>pairingText
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
# ..                      ...                     ...
# 390                      []
# 391                     NaN                     NaN
# 392                     NaN                     NaN
# 393                     NaN                     NaN
# 394                     NaN                     NaN
#
# [909 rows x 14 columns]

# %%
data2 = []

for num in recipe_num: # may need to fix what you iterate over
    params = f'{num}'
    response = s.get(url_base + params + url_tail + key)
    if response.status_code == 200:
        recipe_data = response.json()
        
        data2.append(recipe_data)
pd.DataFrame(data2)

# %%
result.to_csv('recipe_data.csv')

# %%
import pymongo
# recipe_record = collection.insert_one

conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

db = client.classDB

# %%
# db.collection.insert(result.to_dict())

# %%
data = db.Recipe_Data.find()
data
