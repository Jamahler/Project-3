# %%
import json, requests
from pprint import pprint
import pandas as pd
from config import api_key

# %%
recipe_url_base =f"https://api.spoonacular.com/recipes/716429/information?includeNutrition=true"
# recipe_id = "716429"
recipe_query = f"{recipe_url_base}&apiKey={api_key}"

# %%
s = requests.Session()
response = s.get(recipe_query)
pprint(response.json())
# Out:
# {'aggregateLikes': 209,
#  'analyzedInstructions': [],
#  'cheap': False,
#  'creditsText': 'Full Belly Sisters',
#  'cuisines': [],
#  'dairyFree': False,
#  'diets': [],
#  'dishTypes': ['lunch', 'main course', 'main dish', 'dinner'],
#  'extendedIngredients': [{'aisle': 'Milk, Eggs, Other Dairy',
#                           'amount': 1.0,
#                           'consistency': 'solid',
#                           'id': 1001,
#                           'image': 'butter-sliced.jpg',
#                           'measures': {'metric': {'amount': 1.0,
#                                                   'unitLong': 'Tbsp',
#                                                   'unitShort': 'Tbsp'},
#                                        'us': {'amount': 1.0,
#                                               'unitLong': 'Tbsp',
#                                               'unitShort': 'Tbsp'}},
#                           'meta': [],
# ...
