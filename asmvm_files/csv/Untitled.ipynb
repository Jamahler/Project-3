# %%
import json
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv('dish_pairing_for_wine.csv')
df
# Out:
#      Unnamed: 0            wine  \
# 0             0      white_wine
# 1             1  dry_white_wine
# 2             2       assyrtiko
# 3             3     pinot_blanc
# 4             4         cortese
# ..          ...             ...
# 102         102          sherry
# 103         103    cream_sherry
# 104         104      dry_sherry
# 105         105        vermouth
# 106         106            mead
#
#                                                pairing  \
# 0              ['pho', 'stew', 'crab', 'carp', 'fish']
# 1            ['stew', 'crab', 'carp', 'fish', 'clams']
# 2    ['gyros', 'greek', 'souvlaki', 'moussaka', 'sp...
# 3            ['stew', 'crab', 'carp', 'fish', 'clams']
# 4            ['stew', 'crab', 'carp', 'fish', 'clams']
# ..                                                 ...
# 102  ['turnover', 'gazpacho', 'onion tart', 'chocol...
# 103  ['turnover', 'hand pies', 'onion tart', 'pastr...
# 104                                       ['gazpacho']
# ...

# %%
df.to_json(r'wine_pairing.json', orient='records')
