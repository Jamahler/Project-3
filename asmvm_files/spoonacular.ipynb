# %%
# import dependencies for web scraping 
import requests
from bs4 import BeautifulSoup as bs
from bs4 import NavigableString
import pandas as pd

# %%
# URL for scraping
wineURL = "https://spoonacular.com/food-api/docs#Wine-Guide"

# %%
# Retrieve page with the requests module
response = requests.get(wineURL)

# %%
# Create BeautifulSoup object and parse with 'html.parser'
soup = bs(response.text, 'html.parser')

# %%
# examine website elements with chrome dev tools and extract the list of wines
# remove white space and store wines in an interable list
results = soup.find_all('pre')[-1].text.strip().replace('\n','').replace('-','')
wines = results.split()
wines

wine_selection = []
for wine in wines:
    wine_selection.append(wine)

# %%
# obtain length of wine list
wine_selections = wine_selection[1:110]
len(wine_selections)
# Out:
# 109

# %%
# import dependencies for API call to spoonacular API
import json
from pprint import pprint
import pandas as pd
from config import api_key

# %%
# create URL params for GET requests
wine_url = "https://api.spoonacular.com/food/wine/pairing"
wine_url_base ="https://api.spoonacular.com/food/wine/dishes?"
wine = "sparkling_rose"
wine_query = f"{wine_url_base}&apiKey={api_key}&wine={wine}"

# %%
# Perform a GET request and test the API call with one wine pairing
s = requests.Session()
response = s.get(wine_query)
pprint(response.json())

# response = requests.get(wine_query).json()
# response
# Out:
# {'pairings': ['chole', 'tacos', 'curry', 'sushi', 'nachos'],
#  'text': ' It goes especially well with chole, tacos, curry, sushi, and '
#          'nachos.'}

# %%
# print(json.dumps(response, indent=4, sort_keys=True))

# %%
# create empty dataframe to collect dish pairings from list of wines 
columns = ['wine']
dish_pairing_df = pd.DataFrame(columns=columns)
dish_pairing_df['wine'] = wine_selections
dish_pairing_df
# Out:
#                wine
# 0        white_wine
# 1    dry_white_wine
# 2         assyrtiko
# 3       pinot_blanc
# 4           cortese
# ..              ...
# 104      dry_sherry
# 105        vermouth
# 106    dry_vermouth
# 107      fruit_wine
# 108            mead
#
# [109 rows x 1 columns]

# %%
# add columns based on the Keys in the API response
dish_pairing_df['pairing'] = ''
dish_pairing_df['description'] = ''
dish_pairing_df
# Out:
#                wine pairing description
# 0        white_wine
# 1    dry_white_wine
# 2         assyrtiko
# 3       pinot_blanc
# 4           cortese
# ..              ...     ...         ...
# 104      dry_sherry
# 105        vermouth
# 106    dry_vermouth
# 107      fruit_wine
# 108            mead
#
# [109 rows x 3 columns]

# %%
# reference columns with .loc to append wine pairing data; for use later
# dish_pairing_df.loc[index,"pairing"]

# %%
# build URL, run API request, loop through the wine_selections list and print json response
get_dish_pairing = f"{wine_url_base}&apiKey={api_key}&wine="

# for wine in wine_selections:
#     wine_response = requests.get(get_dish_pairing + wine).json()
#     print(wine_response)
# Out:
# {'text': ' It goes especially well with pho, stew, crab, carp, and fish.', 'pairings': ['pho', 'stew', 'crab', 'carp', 'fish']}
# {'text': ' It goes especially well with stew, crab, carp, fish, and clams.', 'pairings': ['stew', 'crab', 'carp', 'fish', 'clams']}
# {'text': 'Assyrtiko is a dry white wine which is crisp and light bodied. It goes especially well with gyros, greek, souvlaki, moussaka, and spanakopita.', 'pairings': ['gyros', 'greek', 'souvlaki', 'moussaka', 'spanakopita']}
# {'status': 'failure', 'message': 'No dish pairings found for wine pinot_blanc'}
# {'status': 'failure', 'message': 'No dish pairings found for wine cortese'}
# {'status': 'failure', 'message': 'No dish pairings found for wine roussanne'}
# {'text': 'Moschofilero is a dry white wine which is crisp and light bodied. It goes especially well with gyros, greek, souvlaki, moussaka, and spanakopita.', 'pairings': ['gyros', 'greek', 'souvlaki', 'moussaka', 'spanakopita']}
# {'text': 'Muscadet is a dry white wine which is crisp and light bodied. It goes especially well with crab, clams, shrimp, lobster, and cockles.', 'pairings': ['crab', 'clams', 'shrimp', 'lobster', 'cockles']}
# {'text': 'Viognier is a dry white wine which is smooth and medium bodied. It goes especially well with mackerel.', 'pairings': ['mackerel']}
# {'text': 'Verdicchio is a dry white wine which is crisp and light bodied. It goes especially well with pizza, calzone, ravioli, gnocchi, and risotto.', 'pairings': ['pizza', 'calzone', 'ravioli', 'gnocchi', 'risotto']}
# {'status': 'failure', 'message': 'No dish pairings found for wine greco'}
# {'status': 'failure', 'message': 'No dish pairings found for wine marsanne'}
# {'text': 'White Burgundy is a dry white wine which is bold and full bodied. It goes especially well with stew, chili, jjigae, quiche, and french.', 'pairings': ['stew', 'chili', 'jjigae', 'quiche', 'french']}
# {'text': 'Chardonnay is a dry white wine which is bold and full bodied. It goes especially well with crab, clams, salad, shrimp, and salmon.', 'pairings': ['crab', 'clams', 'salad', 'shrimp', 'salmon']}
# {'text': 'Gruener Veltliner is a dry white wine which is crisp and light bodied. It goes especially well with cod, sole, crab, tuna, and hake.', 'pairings': ['cod', 'sole', 'crab', 'tuna', 'hake']}
# {'status': 'failure', 'message': 'No dish pairings found for wine white_rioja'}
# {'text': 'Frascati is a dry white wine which is crisp and light bodied. It goes especially well with pasta carbonara and spaghetti carbonara.', 'pairings': ['pasta carbonara', 'spaghetti carbonara']}
# {'text': 'Gavi is a dry white wine which is crisp and light bodied. It goes especially well with caesar salad.', 'pairings': ['caesar salad']}
# {'status': 'failure', 'message': 'No dish pairings found for wine l_acadie_blanc'}
# {'text': 'Trebbiano is a dry white wine which is crisp and light bodied. It goes especially well with pizza, calzone, ravioli, gnocchi, and risotto.', 'pairings': ['pizza', 'calzone', 'ravioli', 'gnocchi', 'risotto']}
# {'text': 'Sauvignon Blanc is a dry white wine which is smooth and medium bodied. It goes especially well with gumbo, salad, sushi, cajun, and shrimp.', 'pairings': ['gumbo', 'salad', 'sushi', 'cajun', 'shrimp']}
# {'status': 'failure', 'message': 'No dish pairings found for wine catarratto'}
# {'text': 'Albarino is a dry white wine which is crisp and light bodied. It goes especially well with gumbo, cajun, paella, po boy, and spanish.', 'pairings': ['gumbo', 'cajun', 'paella', 'po boy', 'spanish']}
# {'status': 'failure', 'message': 'No dish pairings found for wine arneis'}
# {'text': 'Verdejo is a dry white wine which is crisp and light bodied. It goes especially well with gazpacho.', 'pairings': ['gazpacho']}
# {'text': 'Vermentino is a dry white wine which is crisp and light bodied. It goes especially well with shrimp scampi.', 'pairings': ['shrimp scampi']}
# {'status': 'failure', 'message': 'No dish pairings found for wine soave'}
# {'text': 'Pinot Grigio is a dry white wine which is crisp and light bodied. It goes especially well with cod, sole, crab, tuna, and hake.', 'pairings': ['cod', 'sole', 'crab', 'tuna', 'hake']}
# {'status': 'failure', 'message': 'No dish pairings found for wine dry_riesling'}
# {'status': 'failure', 'message': 'No dish pairings found for wine torrontes'}
# {'status': 'failure', 'message': 'No dish pairings found for wine mueller_thurgau'}
# {'status': 'failure', 'message': 'No dish pairings found for wine grechetto'}
# {'text': 'Gewurztraminer is a white wine which is aromatic and vibrant. It goes especially well with pho, thai, sushi, asian, and jjigae.', 'pairings': ['pho', 'thai', 'sushi', 'asian', 'jjigae']}
# {'text': 'Chenin Blanc is a white wine which is aromatic and vibrant. It goes especially well with pho, thai, sushi, asian, and jjigae.', 'pairings': ['pho', 'thai', 'sushi', 'asian', 'jjigae']}
# {'status': 'failure', 'message': 'No dish pairings found for wine white_bordeaux'}
# {'status': 'failure', 'message': 'No dish pairings found for wine semillon'}
# {'text': 'Riesling is a white wine which is crisp and light bodied. It goes especially well with pho, crab, thai, clams, and chole.', 'pairings': ['pho', 'crab', 'thai', 'clams', 'chole']}
# {'status': 'failure', 'message': 'No dish pairings found for wine sauternes'}
# {'status': 'failure', 'message': 'No dish pairings found for wine sylvaner'}
# {'status': 'failure', 'message': 'No dish pairings found for wine lillet_blanc'}
# {'text': ' It goes especially well with stew, crab, tuna, carp, and fish.', 'pairings': ['stew', 'crab', 'tuna', 'carp', 'fish']}
# {'text': ' It goes especially well with stew, crab, tuna, carp, and fish.', 'pairings': ['stew', 'crab', 'tuna', 'carp', 'fish']}
# {'status': 'failure', 'message': 'No dish pairings found for wine petite_sirah'}
# {'text': 'Zweigelt is a dry red wine which is light and fruity. It goes especially well with goulash.', 'pairings': ['goulash']}
# {'status': 'failure', 'message': 'No dish pairings found for wine baco_noir'}
# {'status': 'failure', 'message': 'No dish pairings found for wine bonarda'}
# {'status': 'failure', 'message': 'No dish pairings found for wine cabernet_franc'}
# {'status': 'failure', 'message': 'No dish pairings found for wine bairrada'}
# {'text': 'Barbera Wine is a dry red wine which is light and fruity. It goes especially well with pizza and chicken parmesan.', 'pairings': ['pizza', 'chicken parmesan']}
# {'text': 'Primitivo is a dry red wine which is bold and full bodied. It goes especially well with beef stroganoff.', 'pairings': ['beef stroganoff']}
# {'text': 'Pinot Noir is a dry red wine which is light and fruity. It goes especially well with cod, sole, crab, tuna, and hake.', 'pairings': ['cod', 'sole', 'crab', 'tuna', 'hake']}
# {'text': 'Nebbiolo is a dry red wine which is bold and full bodied. It goes especially well with baked ziti.', 'pairings': ['baked ziti']}
# {'status': 'failure', 'message': 'No dish pairings found for wine dolcetto'}
# {'status': 'failure', 'message': 'No dish pairings found for wine tannat'}
# {'status': 'failure', 'message': 'No dish pairings found for wine negroamaro'}
# {'text': 'Red Burgundy is a dry red wine which is light and fruity. It goes especially well with coq au vin and beef bourguignon.', 'pairings': ['coq au vin', 'beef bourguignon']}
# {'status': 'failure', 'message': 'No dish pairings found for wine corvina'}
# {'text': 'Rioja is a dry red wine which is light and fruity. It goes especially well with goulash.', 'pairings': ['goulash']}
# {'status': 'failure', 'message': 'No dish pairings found for wine cotes_du_rhone'}
# {'text': 'Grenache is a dry red wine which is smooth and medium bodied. It goes especially well with chili, paella, spanish, and empanada.', 'pairings': ['chili', 'paella', 'spanish', 'empanada']}
# {'text': 'Malbec is a dry red wine which is bold and full bodied. It goes especially well with stew, steak, chili, jjigae, and burger.', 'pairings': ['stew', 'steak', 'chili', 'jjigae', 'burger']}
# {'text': 'Zinfandel is a dry red wine which is bold and full bodied. It goes especially well with burger, brisket, cioppino, meatloaf, and rib tips.', 'pairings': ['burger', 'brisket', 'cioppino', 'meatloaf', 'rib tips']}
# {'text': 'Sangiovese is a dry red wine which is smooth and medium bodied. It goes especially well with steak, pizza, lasagne, italian, and cioppino.', 'pairings': ['steak', 'pizza', 'lasagne', 'italian', 'cioppino']}
# {'status': 'failure', 'message': 'No dish pairings found for wine carignan'}
# {'status': 'failure', 'message': 'No dish pairings found for wine carmenere'}
# {'status': 'failure', 'message': 'No dish pairings found for wine cesanese'}
# {'text': 'Cabernet Sauvignon is a dry red wine which is bold and full bodied. It goes especially well with stew, steak, chili, jjigae, and cholent.', 'pairings': ['stew', 'steak', 'chili', 'jjigae', 'cholent']}
# {'status': 'failure', 'message': 'No dish pairings found for wine aglianico'}
# {'text': 'Tempranillo is a dry red wine which is smooth and medium bodied. It goes especially well with paella, brisket, spanish, empanada, and soy burger.', 'pairings': ['paella', 'brisket', 'spanish', 'empanada', 'soy burger']}
# {'text': 'Shiraz is a dry red wine which is bold and full bodied. It goes especially well with chili, pizza, brisket, goulash, and rib tips.', 'pairings': ['chili', 'pizza', 'brisket', 'goulash', 'rib tips']}
# {'status': 'failure', 'message': 'No dish pairings found for wine mourvedre'}
# {'text': 'Merlot is a dry red wine which is smooth and medium bodied. It goes especially well with tuna, steak, burger, prime rib, and beef ribs.', 'pairings': ['tuna', 'steak', 'burger', 'prime rib', 'beef ribs']}
# {'text': 'Nero D Avola is a dry red wine which is bold and full bodied. It goes especially well with beef stroganoff and spaghetti and meatballs.', 'pairings': ['beef stroganoff', 'spaghetti and meatballs']}
# {'text': 'Bordeaux is a dry red wine which is smooth and medium bodied. It goes especially well with quiche, french, souffle, coq au vin, and duck confit.', 'pairings': ['quiche', 'french', 'souffle', 'coq au vin', 'duck confit']}
# {'status': 'failure', 'message': 'No dish pairings found for wine marsala'}
# {'text': ' It goes especially well with turnover, hand pies, onion tart, pastry pillows, and souffle dessert.', 'pairings': ['turnover', 'hand pies', 'onion tart', 'pastry pillows', 'souffle dessert']}
# {'text': 'Gamay is a red wine which is light and fruity. It goes especially well with coq au vin, turkey burgers, and french onion soup.', 'pairings': ['coq au vin', 'turkey burgers', 'french onion soup']}
# {'text': ' It goes especially well with german, rouladen, and schnitzel.', 'pairings': ['german', 'rouladen', 'schnitzel']}
# {'status': 'failure', 'message': 'No dish pairings found for wine concord_wine'}
# {'text': ' It goes especially well with macaroni and cheese.', 'pairings': ['macaroni and cheese']}
# {'text': 'Pinotage is a red wine which is bold and full bodied. It goes especially well with bobotie, african, bunny chow, jollof rice, and piri piri chicken.', 'pairings': ['bobotie', 'african', 'bunny chow', 'jollof rice', 'piri piri chicken']}
# {'text': 'Agiorgitiko is a red wine which is bold and full bodied. It goes especially well with gyros, greek, souvlaki, moussaka, and spanakopita.', 'pairings': ['gyros', 'greek', 'souvlaki', 'moussaka', 'spanakopita']}
# {'text': ' It goes especially well with turnover, onion tart, chocolate souffle, and vanilla ricotta souffle.', 'pairings': ['turnover', 'onion tart', 'chocolate souffle', 'vanilla ricotta souffle']}
# {'status': 'failure', 'message': 'No dish pairings found for wine pedro_ximenez'}
# {'text': 'Moscato is a dessert wine which is aromatic and vibrant. It goes especially well with turnover, onion tart, chocolate souffle, and vanilla ricotta souffle.', 'pairings': ['turnover', 'onion tart', 'chocolate souffle', 'vanilla ricotta souffle']}
# {'status': 'failure', 'message': 'No dish pairings found for wine late_harvest'}
# {'status': 'failure', 'message': 'No dish pairings found for wine ice_wine'}
# {'status': 'failure', 'message': 'No dish pairings found for wine white_port'}
# {'status': 'failure', 'message': 'No dish pairings found for wine lambrusco_dolce'}
# {'status': 'failure', 'message': 'No dish pairings found for wine madeira'}
# {'status': 'failure', 'message': 'No dish pairings found for wine banyuls'}
# {'status': 'failure', 'message': 'No dish pairings found for wine vin_santo'}
# {'text': ' It goes especially well with turnover, hand pies, onion tart, pastry pillows, and souffle dessert.', 'pairings': ['turnover', 'hand pies', 'onion tart', 'pastry pillows', 'souffle dessert']}
# {'text': ' It goes especially well with tuna, chole, gumbo, sushi, and cajun.', 'pairings': ['tuna', 'chole', 'gumbo', 'sushi', 'cajun']}
# {'text': ' It goes especially well with chole, tacos, curry, sushi, and nachos.', 'pairings': ['chole', 'tacos', 'curry', 'sushi', 'nachos']}
# {'text': ' It goes especially well with cod, sole, crab, tuna, and hake.', 'pairings': ['cod', 'sole', 'crab', 'tuna', 'hake']}
# {'text': ' It goes especially well with chili, crabcakes, and grilled cheese sandwich.', 'pairings': ['chili', 'crabcakes', 'grilled cheese sandwich']}
# {'status': 'failure', 'message': 'No dish pairings found for wine cremant'}
# {'text': ' It goes especially well with quiche, french, ceviche, souffle, and coq au vin.', 'pairings': ['quiche', 'french', 'ceviche', 'souffle', 'coq au vin']}
# {'status': 'failure', 'message': 'No dish pairings found for wine prosecco'}
# {'status': 'failure', 'message': 'No dish pairings found for wine spumante'}
# {'text': ' It goes especially well with chole, tacos, curry, sushi, and nachos.', 'pairings': ['chole', 'tacos', 'curry', 'sushi', 'nachos']}
# {'text': ' It goes especially well with turnover, gazpacho, onion tart, chocolate souffle, and vanilla ricotta souffle.', 'pairings': ['turnover', 'gazpacho', 'onion tart', 'chocolate souffle', 'vanilla ricotta souffle']}
# {'text': ' It goes especially well with turnover, hand pies, onion tart, pastry pillows, and souffle dessert.', 'pairings': ['turnover', 'hand pies', 'onion tart', 'pastry pillows', 'souffle dessert']}
# {'text': ' It goes especially well with gazpacho.', 'pairings': ['gazpacho']}
# {'status': 'failure', 'message': 'No dish pairings found for wine vermouth'}
# {'status': 'failure', 'message': 'No dish pairings found for wine dry_vermouth'}
# {'status': 'failure', 'message': 'No dish pairings found for wine fruit_wine'}
# {'status': 'failure', 'message': 'No dish pairings found for wine mead'}

# %%
# loop through the wine options, make the API request, and extract the results to the pandas dataframe
# params = {}
for index, row in dish_pairing_df.iterrows():
    wine_option = row['wine']
#     params['wine'] = wine_option

    response = requests.get(get_dish_pairing + wine_option).json()   
    
    try:
        dish_pairing_df.loc[index,"pairing"] = response['pairings']
        dish_pairing_df.loc[index,"description"] = response['text']
    except (KeyError, IndexError):
        dish_pairing_df.loc[index,"pairing"] = response['status']
        dish_pairing_df.loc[index,"description"] = response['message']

# %%
# display results
dish_pairing_df
# Out:
#                wine                                          pairing  \
# 0        white_wine                    [pho, stew, crab, carp, fish]
# 1    dry_white_wine                  [stew, crab, carp, fish, clams]
# 2         assyrtiko  [gyros, greek, souvlaki, moussaka, spanakopita]
# 3       pinot_blanc                                          failure
# 4           cortese                                          failure
# ..              ...                                              ...
# 104      dry_sherry                                       [gazpacho]
# 105        vermouth                                          failure
# 106    dry_vermouth                                          failure
# 107      fruit_wine                                          failure
# 108            mead                                          failure
#
#                                            description
# 0     It goes especially well with pho, stew, crab,...
# 1     It goes especially well with stew, crab, carp...
# 2    Assyrtiko is a dry white wine which is crisp a...
# 3          No dish pairings found for wine pinot_blanc
# 4              No dish pairings found for wine cortese
# ..                                                 ...
# 104             It goes especially well with gazpacho.
# 105           No dish pairings found for wine vermouth
# 106       No dish pairings found for wine dry_vermouth
# 107         No dish pairings found for wine fruit_wine
# 108               No dish pairings found for wine mead
#
# [109 rows x 3 columns]

# %%
# identify wines with now pairings
no_pairings = dish_pairing_df.loc[(dish_pairing_df['pairing'] == 'failure')]
no_pairings
# Out:
#                 wine  pairing                                      description
# 3        pinot_blanc  failure      No dish pairings found for wine pinot_blanc
# 4            cortese  failure          No dish pairings found for wine cortese
# 5          roussanne  failure        No dish pairings found for wine roussanne
# 10             greco  failure            No dish pairings found for wine greco
# 11          marsanne  failure         No dish pairings found for wine marsanne
# 15       white_rioja  failure      No dish pairings found for wine white_rioja
# 18    l_acadie_blanc  failure   No dish pairings found for wine l_acadie_blanc
# 21        catarratto  failure       No dish pairings found for wine catarratto
# 23            arneis  failure           No dish pairings found for wine arneis
# 26             soave  failure            No dish pairings found for wine soave
# 28      dry_riesling  failure     No dish pairings found for wine dry_riesling
# 29         torrontes  failure        No dish pairings found for wine torrontes
# 30   mueller_thurgau  failure  No dish pairings found for wine mueller_thurgau
# 31         grechetto  failure        No dish pairings found for wine grechetto
# 34    white_bordeaux  failure   No dish pairings found for wine white_bordeaux
# 35          semillon  failure         No dish pairings found for wine semillon
# 37         sauternes  failure        No dish pairings found for wine sauternes
# 38          sylvaner  failure         No dish pairings found for wine sylvaner
# 39      lillet_blanc  failure     No dish pairings found for wine lillet_blanc
# 42      petite_sirah  failure     No dish pairings found for wine petite_sirah
# 44         baco_noir  failure        No dish pairings found for wine baco_noir
# 45           bonarda  failure          No dish pairings found for wine bonarda
# 46    cabernet_franc  failure   No dish pairings found for wine cabernet_franc
# 47          bairrada  failure         No dish pairings found for wine bairrada
# 52          dolcetto  failure         No dish pairings found for wine dolcetto
# 53            tannat  failure           No dish pairings found for wine tannat
# 54        negroamaro  failure       No dish pairings found for wine negroamaro
# 56           corvina  failure          No dish pairings found for wine corvina
# 58    cotes_du_rhone  failure   No dish pairings found for wine cotes_du_rhone
# 63          carignan  failure         No dish pairings found for wine carignan
# 64         carmenere  failure        No dish pairings found for wine carmenere
# 65          cesanese  failure         No dish pairings found for wine cesanese
# 67         aglianico  failure        No dish pairings found for wine aglianico
# 70         mourvedre  failure        No dish pairings found for wine mourvedre
# 74           marsala  failure          No dish pairings found for wine marsala
# 78      concord_wine  failure     No dish pairings found for wine concord_wine
# 83     pedro_ximenez  failure    No dish pairings found for wine pedro_ximenez
# 85      late_harvest  failure     No dish pairings found for wine late_harvest
# 86          ice_wine  failure         No dish pairings found for wine ice_wine
# 87        white_port  failure       No dish pairings found for wine white_port
# 88   lambrusco_dolce  failure  No dish pairings found for wine lambrusco_dolce
# 89           madeira  failure          No dish pairings found for wine madeira
# 90           banyuls  failure          No dish pairings found for wine banyuls
# 91         vin_santo  failure        No dish pairings found for wine vin_santo
# 97           cremant  failure          No dish pairings found for wine cremant
# 99          prosecco  failure         No dish pairings found for wine prosecco
# 100         spumante  failure         No dish pairings found for wine spumante
# 105         vermouth  failure         No dish pairings found for wine vermouth
# 106     dry_vermouth  failure     No dish pairings found for wine dry_vermouth
# 107       fruit_wine  failure       No dish pairings found for wine fruit_wine
# 108             mead  failure             No dish pairings found for wine mead

# %%
# there are 51 out of 109 wines with no listed pairings (47 percent of the list)
no_pairings.count()
# Out:
# wine           51
# pairing        51
# description    51
# dtype: int64

# %%
dry_white_wines = no_pairings.loc[3:39]
dry_white_wines
dry_red_wines = no_pairings.loc[42:70]
dry_red_wines
red_wines = no_pairings.loc[74:78]
red_wines
dessert_wines = no_pairings.loc[83:91]
dessert_wines
sparkling_wines = no_pairings.loc[97:100]
sparkling_wines
# Out:
#          wine  pairing                               description
# 97    cremant  failure   No dish pairings found for wine cremant
# 99   prosecco  failure  No dish pairings found for wine prosecco
# 100  spumante  failure  No dish pairings found for wine spumante

# %%
pwd
# Out:
# 'C:\\Users\\a_mcr\\Desktop\\Bootcamp\\Group_Projects\\Project-3\\asmvm_files'

# %%
dish_pairing_df.to_csv('dish_pairing_for_wine.csv')
